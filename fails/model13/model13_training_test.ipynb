# %% [markdown]
# # Machine Learning Final Proyect - Nopales
# ### David Villanueva Guzmán - U6110618
# ### Alvaro Cámara Guerra - U6110583

# %% [markdown]
# ### Import Required Libraries

# %%
import sys
print(sys.executable)
import torch
print(torch.__version__)
print(torch.cuda.is_available())

# import torch.multiprocessing as mp
# mp.set_start_method("spawn", force=True)
# Out:
# c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Scripts\python.exe
# 2.10.0.dev20251210+cu128
# True

# %%
import torch, kornia, platform

print("Torch:", torch.__version__)
print("CUDA version in torch:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")
print("Kornia:", kornia.__version__)
print("Python:", platform.python_version())
# Out:
# Torch: 2.10.0.dev20251210+cu128
# CUDA version in torch: 12.8
# CUDA available: True
# Device: NVIDIA GeForce RTX 5060 Laptop GPU
# Kornia: 0.8.2
# Python: 3.11.9

# %%
# !nvidia-smi
# Out:
# Sat Dec 13 23:46:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 573.24                 Driver Version: 573.24         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   58C    P2             41W /   85W |    1223MiB /   8151MiB |     56%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            3164    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           11968    C+G   ...cw5n1h2txyewy\WidgetBoard.exe      N/A      |
# |    0   N/A  N/A           12836    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           16840    C+G   ...s\Win64\EpicGamesLauncher.exe      N/A      |
# |    0   N/A  N/A           32560      C   ...in\versions\3.11.9\python.exe      N/A      |
# |    0   N/A  N/A           42888      C   ...in\versions\3.11.9\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install "numpy<2.0" --force-reinstall
# !pip install kornia
import warnings
warnings.filterwarnings("ignore")

# %%
# For data processing
# !pip install pandas
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Integrate google drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ### Load the Dataset
# Milan Dataset --

# %%
# Import Multiclass and Binary annotations
file_path_MC = r"C:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\Labs\FP\annotations_multiclass.csv"
file_path_BIN = r"C:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\Labs\FP\annotations_binary.csv"
# file_path_MC = '/content/drive/MyDrive/IFRoS/ML Labs/MILAN-dataset/annotations_multiclass.csv'
# file_path_BIN = '/content/drive/MyDrive/IFRoS/ML Labs/MILAN-dataset/annotations_binary.csv'

# Get dataframes of annotations
df_MC = pd.read_csv(file_path_MC)
df_MC.drop(columns=["Unnamed: 2", "Unnamed: 3"], inplace=True)

print(df_MC.head(10))
# Out:
#   file_prefix printError_physicalDefect
# 0  001_516_01                       0_0
# 1  001_516_02                       0_1
# 2  001_516_03                       0_0
# 3  001_516_04                       0_0
# 4  001_516_05                       0_0
# 5  001_516_06                       0_0
# 6  001_516_07                       0_0
# 7  001_516_08                       0_0
# 8  001_516_09                       0_0
# 9  001_516_10                       1_0

# %% [markdown]
# #### Data Preprocessing

# %%
mapping = {
    "0_0": 0,
    "0_1": 1,
    "1_0": 2,
    "1_1": 3
}

df_MC["printError_physicalDefect_int"] = df_MC["printError_physicalDefect"].map(mapping)

# Count occurrences of each class
print_counts = df_MC["printError_physicalDefect_int"].value_counts().sort_index()

# Create the figure
fig, ax = plt.subplots(figsize=(7, 5))

# Define x positions for side-by-side bars
x = range(len(print_counts))  # same class positions (e.g. 0 and 1)
width = 0.5  # bar width

# Plot bars
bars1 = ax.bar([i - width/2 for i in x], print_counts, width, color='#1f77b4', alpha=0.8)

# Add text labels on top of bars
for bar in bars1:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, height + 10, f'{int(height)}',
            ha='center', va='bottom', fontsize=9, fontweight='bold')

# Customize axes
ax.set_xlabel("Class")
ax.set_ylabel("Counts")
ax.set_title("Distribution of Print and Physical Errors")
ax.set_xticks(x)
ax.set_xticklabels(print_counts.index)  # e.g. 0 and 1 only
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

print(df_MC)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#      file_prefix printError_physicalDefect  printError_physicalDefect_int
# 0     001_516_01                       0_0                              0
# 1     001_516_02                       0_1                              1
# 2     001_516_03                       0_0                              0
# 3     001_516_04                       0_0                              0
# 4     001_516_05                       0_0                              0
# ...          ...                       ...                            ...
# 1375  002_100_11                       0_1                              1
# 1376  002_100_12                       0_0                              0
# 1377  002_100_13                       0_0                              0
# 1378  002_100_14                       0_0                              0
# 1379  002_100_15                       1_0                              2
#
# [1380 rows x 3 columns]

# %% [markdown]
# ### Binary annotations

# %%
# Lista de strings a buscar en el nombre de la imagen

# Filtrar solo filas donde la segunda columna sea exactamente '0_0'
df_MC["binary"] = (df_MC["printError_physicalDefect_int"] != 0).astype(int)

# Count occurrences of each class
print_counts = df_MC["binary"].value_counts().sort_index()

# Create the figure
fig, ax = plt.subplots(figsize=(7, 5))

# Define x positions for side-by-side bars
x = range(len(print_counts))  # same class positions (e.g. 0 and 1)
width = 0.5  # bar width

# Plot bars
bars1 = ax.bar([i - width/2 for i in x], print_counts, width, label='Print Error', color='#1f77b4', alpha=0.8)

# Add text labels on top of bars
for bar in bars1:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, height + 10, f'{int(height)}',
            ha='center', va='bottom', fontsize=9, fontweight='bold')

# Customize axes
ax.set_xlabel("Class")
ax.set_ylabel("Counts")
ax.set_title("Distribution of Print and Physical Errors")
ax.set_xticks(x)
ax.set_xticklabels(print_counts.index)  # e.g. 0 and 1 only
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
# Export the binary annotations
df_MC[["file_prefix", "binary"]].to_csv("output.csv", index=False)

# %% [markdown]
# ### Data reduction

# %% [markdown]
# #### Unzip images inside google drive

# %%
extract_path = r"C:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\Labs\FP\drive-download-20251113T114126Z-1-001\arrays"

# %% [markdown]
# #### Define NPYImageDataset class to load the images

# %%
import os
import torch
from torch.utils.data import Dataset
import numpy as np

class NPYImageDataset(Dataset):
    def __init__(self, root_dir, names, labels, transform=None):
        """
        root_dir : Folder with .npy files
        names    : List like ['003_045_012', '002_047_12', ...]
        labels   : Array-like with class labels aligned with 'names'
        transform: torchvision transform
        """
        self.root_dir = root_dir
        self.names = names
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.names)

    def __getitem__(self, idx):
        name = self.names[idx]
        filename = f"{name}.npy"
        path = os.path.join(self.root_dir, filename)

        if not os.path.exists(path):
            raise FileNotFoundError(f"File not found: {path}")

        img = np.load(path)                                   # (H, W, C)
        img = torch.from_numpy(img).permute(2, 0, 1).float()  # (C, H, W)

        if self.transform:
            img = self.transform(img)

        label = torch.tensor(self.labels[idx]).long()

        return img, label

# %%
all_names = df_MC["file_prefix"].values      # list of .npy filenames
all_labels = df_MC["binary"].values       # 0 / 1 labels

# %%
from sklearn.model_selection import train_test_split

# All indices as ints
indices = np.arange(len(all_names))

# Train set
train_idx, temp_idx = train_test_split(
    indices,
    test_size=0.30,
    stratify=all_labels,
    random_state=42
)

# Validation and test set
temp_labels = all_labels[temp_idx]
val_idx, test_idx = train_test_split(
    temp_idx,
    test_size=0.30,
    stratify=temp_labels,
    random_state=42
)

# %%
# Apply split to names and labels
train_names = all_names[train_idx]
val_names   = all_names[val_idx]
test_names  = all_names[test_idx]

train_labels = all_labels[train_idx]
val_labels   = all_labels[val_idx]
test_labels  = all_labels[test_idx]

# %% [markdown]
# ### Exporting the test dataset into a new directory

# %%
# Expor the test dataset into a new folder for testing
import shutil
import pandas as pd
import stat
import time

EXPORT_DIR = r"C:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\Labs\FP\test"
EXPORT_ARRAYS = os.path.join(EXPORT_DIR, "arrays")

# -------- Remove previous export completely --------
def remove_readonly(func, path, exc):
    os.chmod(path, stat.S_IWRITE)
    func(path)

for _ in range(5):
    try:
        shutil.rmtree(EXPORT_DIR, onerror=remove_readonly)
        break
    except PermissionError:
        print("Directory locked, retrying...")
        time.sleep(0.3)

os.makedirs(EXPORT_ARRAYS, exist_ok=True)

print("\nExporting test dataset to:", EXPORT_ARRAYS)

# Folder containing ALL 1380 original .npy images
# Collect paths and labels for CSV
csv_rows = []
for name, label in zip(test_names, test_labels):
    src = os.path.join(extract_path, f"{name}.npy")
    dst = os.path.join(EXPORT_ARRAYS, f"{name}.npy")

    if not os.path.exists(src):
        raise FileNotFoundError(f"Missing .npy file: {src}")

    shutil.copy(src, dst)
    csv_rows.append([name, int(label)])

print(f"Copied {len(csv_rows)} test images.")

# Save labels CSV
csv_path = os.path.join(EXPORT_DIR, "labels.csv")
df = pd.DataFrame(csv_rows, columns=["file_prefix", "binary"])
df.to_csv(csv_path, index=False)

print(f"Saved labels to: {csv_path}")
print("\nTest dataset export complete.\n")
# Out:
# Exporting test dataset to: C:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\Labs\FP\test\arrays
# Copied 125 test images.
# Saved labels to: C:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\Labs\FP\test\labels.csv
#
# Test dataset export complete.

# %% [markdown]
# #### Data transforming

# %%
import torchvision.transforms.v2 as transforms
import torch
import kornia.augmentation as K

def scale_image(x):
    return x / 255.0

train_transform = transforms.Compose([
    # Input comes as (C,H,W) torch tensor from NPY
    # Scale to [0,1]
    transforms.Lambda(scale_image),
    transforms.ToDtype(torch.float32),

    # Normalize all 6 channels
    transforms.Normalize(
        mean=[0.5]*6,
        std=[0.5]*6
    )
])

val_transform = transforms.Compose([
    transforms.Lambda(scale_image),
    transforms.ToDtype(torch.float32),

    transforms.Normalize(
        mean=[0.5]*6,
        std=[0.5]*6
    )
])

test_transform = transforms.Compose([
    transforms.Lambda(scale_image),
    transforms.ToDtype(torch.float32),

    transforms.Normalize(
        mean=[0.5]*6,
        std=[0.5]*6
    )
])


# kornia_augment = torch.nn.Sequential(
#     # --- Moderate geometric jitter ---
#     K.RandomHorizontalFlip(p=0.4),
#     K.RandomRotation(degrees=3.0, p=0.3),
#     K.RandomAffine(
#         degrees=0,
#         translate=(0.04, 0.04),
#         scale=(0.96, 1.04),
#         p=0.35
#     ),

#     # --- Stronger photometric jitter ---
#     K.RandomBrightness(brightness=(0.90, 1.10), p=0.4),
#     K.RandomContrast(contrast=(0.85, 1.15), p=0.4),
#     # K.RandomGamma(gamma=(0.8, 1.3), p=0.3),

#     # --- Light noise and blur ---
#     K.RandomGaussianNoise(mean=0, std=0.01, p=0.3),
#     K.RandomGaussianBlur(kernel_size=(3,3), sigma=(0.05, 0.25), p=0.2),

#     # --- KEY regularizer: Random erasing ---
#     K.RandomErasing(scale=(0.005, 0.05), ratio=(0.3, 3.3), p=0.35),
# )
kornia_augment = torch.nn.Sequential(
    K.RandomHorizontalFlip(p=0.4),
    K.RandomRotation(degrees=2.0, p=0.3),
    K.RandomAffine(
        degrees=0,
        translate=(0.02, 0.02),
        scale=(0.98, 1.02),
        p=0.3
    ),
    K.RandomBrightness((0.92, 1.08), p=0.4),
    K.RandomContrast((0.88, 1.12), p=0.4),
    K.RandomGaussianNoise(0, 0.008, p=0.25),
    K.RandomGaussianBlur((3,3), (0.05, 0.2), p=0.1),
    K.RandomErasing(scale=(0.003, 0.03), ratio=(0.3, 3.3), p=0.2)
)

# %%
train_dataset = NPYImageDataset(
    root_dir=extract_path,
    names=train_names,
    labels=train_labels,
    transform=train_transform
)

val_dataset = NPYImageDataset(
    root_dir=extract_path,
    names=val_names,
    labels=val_labels,
    transform=val_transform
)

test_dataset = NPYImageDataset(
    root_dir=extract_path,
    names=test_names,
    labels=test_labels,
    transform=val_transform
)

# %%
batch_size = 8

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0, # Changed from 4 to 0 for debugging
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0, # Changed from 4 to 0 for debugging
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0, # Changed from commented out to 0 for debugging
    pin_memory=True
)

# %% [markdown]
# #### Visuazlie a sample

# %%
# Visualize ONE sample directly from the DATASET (no batching issues)

import matplotlib.pyplot as plt

# Get one raw sample from the dataset
img, label = train_dataset[0]
print("label = ",label)
img = kornia_augment(img)

print("Type:", type(img))
print("Shape:", img.shape)      # Expected: (1, 6, H, W)
print("Label:", label)

# Undo normalization for visualization
# Since you used: Normalize(mean=[0.5]*6, std=[0.5]*6)
img_vis = img[0, :3] * 0.5 + 0.5   # Take first 3 channels from the first image in batch as pseudo-RGB
img_vis = img_vis.clamp(0, 1)  # Safety clamp

# Show image
plt.imshow(img_vis.permute(1, 2, 0))
plt.title("Train Sample (Pseudo-RGB)")
plt.axis("off")
plt.show()
# Out:
# label =  tensor(1)
# Type: <class 'torch.Tensor'>
# Shape: torch.Size([1, 6, 310, 310])
# Label: tensor(1)

# %% [markdown]
# ### Data splitting using multiclass

# %%
# def count_labels(loader):
#     count_0 = 0
#     count_1 = 0

#     for _, labels in loader:
#         labels = labels.cpu().numpy()
#         count_0 += (labels == 0).sum()
#         count_1 += (labels == 1).sum()

#     total = count_0 + count_1
#     perc_0 = 100 * count_0 / total
#     perc_1 = 100 * count_1 / total

#     return count_0, count_1, perc_0, perc_1


# # Train
# c0, c1, p0, p1 = count_labels(train_loader)
# print(f"\nTrain -> Class 0: {c0} ({p0:.2f}%) | Class 1: {c1} ({p1:.2f}%)")

# # Validation
# c0, c1, p0, p1 = count_labels(val_loader)
# print(f"Val   -> Class 0: {c0} ({p0:.2f}%) | Class 1: {c1} ({p1:.2f}%)")

# # Test
# c0, c1, p0, p1 = count_labels(test_loader)
# print(f"Test  -> Class 0: {c0} ({p0:.2f}%) | Class 1: {c1} ({p1:.2f}%)")

# %% [markdown]
# ### Setting the Device

# %% [markdown]
# ### Define structure

# %%
# Import pretrained model ResNet50
import torchvision.models as models
import numpy as np
import torch.nn as nn

# Hyperparameters
dropout_rate = 0.25
num_classes = 2

# Imported model
imported_model = models.resnet34(pretrained=True, progress = True)

# Freeze layers
# frozen_layers = ("conv1", "layer1", "layer2")
frozen_layers = ("layer1")
for name, param in imported_model.named_parameters():
    if name.startswith(frozen_layers):
        param.requires_grad = False
    else:
        param.requires_grad = True

old_weight = imported_model.conv1.weight  # [64, 3, 7, 7]
old_conv = imported_model.conv1
new_conv = nn.Conv2d(
    in_channels=6,             # change from 3 to 6
    out_channels=old_conv.out_channels,
    kernel_size=old_conv.kernel_size,
    stride=old_conv.stride,
    padding=old_conv.padding,
    bias=old_conv.bias
  )
with torch.no_grad():
    new_conv.weight[:, :3].copy_(old_weight)
    new_conv.weight[:, 3:].copy_(old_weight.clone())
imported_model.conv1 = new_conv

imported_model.fc = nn.Sequential(
    nn.Linear(512, 256),
    nn.BatchNorm1d(256),
    nn.LeakyReLU(),

    nn.Linear(256, 128),
    nn.BatchNorm1d(128),
    nn.LeakyReLU(),

    nn.Dropout(dropout_rate),
    nn.Linear(128, 2) 
)


# For resrnet34
layer_groups = {
    "conv1": ["conv1", "bn1"],
    "layer1": ["layer1"],
    "layer2": ["layer2"],
    "layer3": ["layer3"],
    "layer4": ["layer4"],
    "head":   ["fc"],   # classifier
}

# %% [markdown]
# ### Train the model

# %% [markdown]
# ### Train and Validation Fucntions

# %%
import torch, kornia, platform
# Define device foor runtime
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("Torch:", torch.__version__)
print("CUDA version in torch:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")
print("Kornia:", kornia.__version__)
print("Python:", platform.python_version())
print(device)
# Out:
# Torch: 2.10.0.dev20251210+cu128
# CUDA version in torch: 12.8
# CUDA available: True
# Device: NVIDIA GeForce RTX 5060 Laptop GPU
# Kornia: 0.8.2
# Python: 3.11.9
# cuda

# %%
# ============================================
# FOCAL LOSS - Para datasets desbalanceados
# ============================================
import torch
import torch.nn as nn
import torch.nn.functional as F

class FocalLoss(nn.Module):
    """
    Focal Loss para clasificación binaria/multiclase con desbalance.

    Parámetros:
    -----------
    alpha : tensor o None
        Peso para cada clase. Ej: [0.3, 0.7] da más peso a clase 1
    gamma : float
        Factor de enfoque. Típicamente 2.0
        - gamma=0 equivale a CrossEntropyLoss
        - gamma>0 reduce la pérdida para ejemplos bien clasificados
    label_smoothing : float
        Suavizado de etiquetas (0.0 a 0.2 típicamente)
    """
    def __init__(self, alpha=None, gamma=2.0, label_smoothing=0.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha  # será un tensor en GPU
        self.gamma = gamma
        self.label_smoothing = label_smoothing
        self.reduction = reduction

    def forward(self, inputs, targets):
        """
        inputs: logits del modelo, shape (N, C) donde C=num_classes
        targets: etiquetas, shape (N,) con valores 0 o 1
        """
        # Calcular log-softmax para estabilidad numérica
        log_probs = F.log_softmax(inputs, dim=1)

        # Obtener log_prob de la clase correcta para cada muestra
        # targets.unsqueeze(1) -> (N, 1)
        # gather selecciona el log_prob correspondiente a la clase correcta
        ce_loss = F.nll_loss(log_probs, targets, reduction='none')

        # Probabilidad de la clase correcta
        probs = torch.exp(log_probs)
        pt = probs.gather(1, targets.unsqueeze(1)).squeeze(1)

        # Focal weight: (1 - pt)^gamma
        focal_weight = (1 - pt) ** self.gamma

        # Aplicar focal weight
        focal_loss = focal_weight * ce_loss

        # Aplicar alpha (peso por clase) si está definido
        if self.alpha is not None:
            alpha_t = self.alpha.gather(0, targets)
            focal_loss = alpha_t * focal_loss

        # Reducción
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
# Optimizer and Criterion
def compute_class_stats_from_loader(loader):
    total_per_class = torch.zeros(2)

    for _, labels in loader:
        for c in [0, 1]:
            total_per_class[c] += (labels == c).sum()

    N0 = int(total_per_class[0].item())  # non-defective
    N1 = int(total_per_class[1].item())  # defective

    return N0, N1


# Class distribution
N0, N1 = compute_class_stats_from_loader(train_loader)
print("Non-defective:", N0)
print("Defective:", N1)

# Calculate the weights
beta = 0.999
w0 = (1 - beta) / (1 - beta**N0)
w1 = (1 - beta) / (1 - beta**N1)

weights = torch.tensor([w0, w1]).to(device)
# criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.035)

# gamma controla cuánto enfocarse en ejemplos difíciles
# gamma=2.0 es el valor típico del paper original
alpha = torch.tensor([0.35, 0.65]).to(device)  # suma = 1.0
criterion = FocalLoss(
    alpha=alpha,
    gamma=2.0,
    label_smoothing=0.05  
)

# Define optimizer
optimizer = torch.optim.AdamW(imported_model.parameters(), lr=1e-4, weight_decay=5e-5)

# Parse model to the GPU
imported_model = imported_model.to(device)
# Out:
# Non-defective: 603
# Defective: 363

# %%
def mixup_data(x, y, alpha=0.4):
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(x.device)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

# %%
#train function
from sklearn.metrics import average_precision_score, f1_score
import torch.nn.functional as F
import numpy as np

def Train(model, train_loader, optimizer, alpha = 0.4):
    model.train()

    running_loss = 0.0
    all_probs = []
    all_labels = []

    # Iterate over all the batches inside the train loader
    for i, (images, labels) in enumerate(train_loader):

        # Move augmented batch to GPU for training
        images = images.to(device)
        labels = labels.to(device)

        # Data augmentation with kornia in the GPU 
        images = kornia_augment(images)

        #mixup
        # images, y_a, y_b, lam = mixup_data(images, labels, alpha = alpha)

        # Initialize backpropagation and optimization
        optimizer.zero_grad()

        # Forward pass
        outputs = model(images)

        # If MixUp active, compute mixed loss — works with CrossEntropy
        # if lam is not None:
        #     loss = lam * criterion(outputs, y_a) + (1 - lam) * criterion(outputs, y_b)
        # else:
        #     loss = criterion(outputs, labels)
        loss = criterion(outputs, labels)

        # Backpropagation
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Convert logits → probability of positive class
        probs = F.softmax(outputs, dim=1)[:, 1]

        all_probs.extend(probs.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

    # Compute AUC-PR for the full epoch
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)

    # AUC-PR
    if len(np.unique(all_labels)) > 1:
        auc_pr = average_precision_score(all_labels, all_probs)
    else:
        auc_pr = 0.0

    # Average loss
    avg_loss = running_loss / len(train_loader)

    # Binary predictions for F1
    preds = (all_probs >= 0.5).astype(int)

    # F1-score
    f1 = f1_score(all_labels, preds)

    return avg_loss, auc_pr, f1

#validation function
def Validate(model, val_loader):
    model.eval()

    running_loss = 0.0
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            running_loss += loss.item()

            # Convert logits → probability of positive class
            probs = F.softmax(outputs, dim=1)[:, 1]

            all_probs.extend(probs.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)

    auc_pr = average_precision_score(all_labels, all_probs)
    avg_loss = running_loss / len(val_loader)

    # # Binary predictions for F1
    # preds = (all_probs >= 0.5).astype(int)

    # # F1-score
    # f1 = f1_score(all_labels, preds)

    # ----- FIND BEST THRESHOLD FOR F1 -----
    thresholds = np.linspace(0.0, 1.0, 200)
    f1_scores = [
        f1_score(all_labels, (all_probs >= t).astype(int)) 
        for t in thresholds
    ]
    best_idx = int(np.argmax(f1_scores))
    best_threshold = float(thresholds[best_idx])
    best_f1 = float(f1_scores[best_idx])

    return avg_loss, auc_pr, best_f1, best_threshold

# %%
import os
import numpy as np

bad_files = []
good = 0

for f in os.listdir(extract_path):
    if not f.lower().endswith(".npy"):
        continue

    full = os.path.join(extract_path, f)

    try:
        arr = np.load(full)
        _ = arr.shape  # force read
        good += 1
    except Exception as e:
        print("❌ Bad file:", full)
        print("   Error:", repr(e))
        bad_files.append(full)

print("\n✅ Good files:", good)
print("❌ Bad files:", len(bad_files))
# Out:
# ✅ Good files: 1380
# ❌ Bad files: 0

# %%
print(device)
# Out:
# cuda

# %%
num_epochs = 200
patience = 30
min_delta = 1e-3

best_val_aucpr = 0.0
epochs_no_improve = 0
best_model_state = None

# %%
print(imported_model)
# Out:
# ResNet(
#   (conv1): Conv2d(6, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Dropout(p=0.25, inplace=False)
#     (7): Linear(in_features=128, out_features=2, bias=True)
#   )
# )

# %%
def apply_freezing(model, layer_groups: list[str], layers_to_modify: list[str], freeze_flag: bool):
    """
    freeze_flag: True → freeze layers, False → unfreeze layers
    layers_to_modify: list of keys from layer_groups,
    """

    target_substrings = []
    for key in layers_to_modify:
        target_substrings += layer_groups[key]

    for name, module in model.named_modules():
        if any(substr in name for substr in target_substrings):
            for param in module.parameters():
                param.requires_grad = (not freeze_flag)  # True→freeze means requires_grad=False

def build_optimizer(model, lr: float, wd: float):
    trainable_params = [p for p in model.parameters() if p.requires_grad]

    return torch.optim.AdamW(
        trainable_params,
        lr=lr,
        weight_decay=wd
    )

# optimizer = torch.optim.AdamW(imported_model.parameters(), lr=learning_rate, weight_decay=5e-5)

# %%
# Hyperparameters
learning_rate = 1e-4
weight_decay = 1e-4

freeze_schedule = [
    # Phase 1: no freezing at all (warmup)
    (5,  False, [], 1e-4),

    # Phase 2: freeze only layer1 briefly to stabilize early edges
    (10, True,  ["layer1"], 5e-5),

    # Phase 3: full fine-tuning
    (200, False, ["layer1"], 1e-5),
]

# Tracking lists
train_losses = []
val_losses = []
train_aucprs = []
val_aucprs = []
train_f1s = []
val_f1s = []

# Early stopping parameters
best_val_aucpr = 0.0
best_epoch = 0
epochs_no_improve = 0
current_epoch = 0

for block_epochs, freeze_flag, layers_to_modify, lr in freeze_schedule:

    print(f"\n=== New Training Block: {block_epochs} epochs | freeze={freeze_flag} | layers={layers_to_modify} ===")

    # Freeze/unfreeze layers
    apply_freezing(imported_model, layer_groups, layers_to_modify, freeze_flag)

    # Rebuild optimizer to include only unfrozen parameters
    optimizer = build_optimizer(imported_model, lr, weight_decay)

    # Rebuild scheduler
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    # Train inside this block
    for _ in range(block_epochs):

        # Safety break if total num_epochs is reached
        if current_epoch >= num_epochs: break

        # ---- Training ----
        train_loss, train_aucpr, train_f1 = Train(imported_model, train_loader, optimizer)
        val_loss, val_aucpr, val_f1, val_best_th = Validate(imported_model, val_loader)

        # Log metrics
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_aucprs.append(train_aucpr)
        val_aucprs.append(val_aucpr)
        train_f1s.append(train_f1)
        val_f1s.append(val_f1)

        print(
            f"Epoch [{current_epoch+1}/{num_epochs}] "
            f"| Freeze={freeze_flag} | Layers={layers_to_modify} "
            f"| Train Loss={train_loss:.4f} Train AUC={train_aucpr:.4f} "
            f"| Val Loss={val_loss:.4f} Val AUC={val_aucpr:.4f}"
        )

        # ---- EARLY STOPPING ----
        if val_aucpr > best_val_aucpr + min_delta:
            best_val_aucpr = val_aucpr
            best_epoch = current_epoch + 1
            epochs_no_improve = 0
            best_model_state = imported_model.state_dict()
            best_threshold = val_best_th
        else:
            epochs_no_improve += 1
            print(f"  EarlyStopping counter: {epochs_no_improve}/{patience}")

        if epochs_no_improve >= patience:
            print("\nEarly stopping triggered!\n")
            break

        # Step scheduler
        scheduler.step()
        current_epoch += 1

    if epochs_no_improve >= patience:
        break

# Restore best weights
imported_model.load_state_dict(best_model_state)
print(f"\nBest model restored (Epoch {best_epoch} | AUC-PR={best_val_aucpr:.4f})")
# Out:
# === New Training Block: 5 epochs | freeze=False | layers=[] ===
# Epoch [1/200] | Freeze=False | Layers=[] | Train Loss=0.1095 Train AUC=0.3954 | Val Loss=0.0914 Val AUC=0.4252
# Epoch [2/200] | Freeze=False | Layers=[] | Train Loss=0.0944 Train AUC=0.4415 | Val Loss=0.0805 Val AUC=0.5557
# Epoch [3/200] | Freeze=False | Layers=[] | Train Loss=0.0933 Train AUC=0.4161 | Val Loss=0.0748 Val AUC=0.5897
# Epoch [4/200] | Freeze=False | Layers=[] | Train Loss=0.0911 Train AUC=0.4320 | Val Loss=0.0767 Val AUC=0.5886
#   EarlyStopping counter: 1/30
# Epoch [5/200] | Freeze=False | Layers=[] | Train Loss=0.0857 Train AUC=0.5181 | Val Loss=0.0700 Val AUC=0.6941
#
# === New Training Block: 10 epochs | freeze=True | layers=['layer1'] ===
# Epoch [6/200] | Freeze=True | Layers=['layer1'] | Train Loss=0.0862 Train AUC=0.5421 | Val Loss=0.0753 Val AUC=0.6016
#   EarlyStopping counter: 1/30
# Epoch [7/200] | Freeze=True | Layers=['layer1'] | Train Loss=0.0786 Train AUC=0.6026 | Val Loss=0.0703 Val AUC=0.6507
#   EarlyStopping counter: 2/30
# Epoch [8/200] | Freeze=True | Layers=['layer1'] | Train Loss=0.0786 Train AUC=0.5755 | Val Loss=0.0683 Val AUC=0.7359
# Epoch [9/200] | Freeze=True | Layers=['layer1'] | Train Loss=0.0762 Train AUC=0.6445 | Val Loss=0.0674 Val AUC=0.7146
#   EarlyStopping counter: 1/30
# Epoch [10/200] | Freeze=True | Layers=['layer1'] | Train Loss=0.0785 Train AUC=0.6118 | Val Loss=0.0673 Val AUC=0.6982
#   EarlyStopping counter: 2/30
# Epoch [11/200] | Freeze=True | Layers=['layer1'] | Train Loss=0.0742 Train AUC=0.6606 | Val Loss=0.0627 Val AUC=0.7808
# Epoch [12/200] | Freeze=True | Layers=['layer1'] | Train Loss=0.0718 Train AUC=0.6685 | Val Loss=0.0646 Val AUC=0.7395
#   EarlyStopping counter: 1/30
# Epoch [13/200] | Freeze=True | Layers=['layer1'] | Train Loss=0.0699 Train AUC=0.7115 | Val Loss=0.0636 Val AUC=0.7633
#   EarlyStopping counter: 2/30
# Epoch [14/200] | Freeze=True | Layers=['layer1'] | Train Loss=0.0704 Train AUC=0.7010 | Val Loss=0.0626 Val AUC=0.7712
#   EarlyStopping counter: 3/30
# Epoch [15/200] | Freeze=True | Layers=['layer1'] | Train Loss=0.0714 Train AUC=0.6813 | Val Loss=0.0576 Val AUC=0.8095
#
# === New Training Block: 200 epochs | freeze=False | layers=['layer1'] ===
# Epoch [16/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0636 Train AUC=0.7538 | Val Loss=0.0598 Val AUC=0.7972
#   EarlyStopping counter: 1/30
# Epoch [17/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0592 Train AUC=0.8046 | Val Loss=0.0566 Val AUC=0.8060
#   EarlyStopping counter: 2/30
# Epoch [18/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0616 Train AUC=0.7691 | Val Loss=0.0580 Val AUC=0.7905
#   EarlyStopping counter: 3/30
# Epoch [19/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0588 Train AUC=0.8038 | Val Loss=0.0588 Val AUC=0.7965
#   EarlyStopping counter: 4/30
# Epoch [20/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0577 Train AUC=0.8062 | Val Loss=0.0582 Val AUC=0.7829
#   EarlyStopping counter: 5/30
# Epoch [21/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0540 Train AUC=0.8340 | Val Loss=0.0598 Val AUC=0.7936
#   EarlyStopping counter: 6/30
# Epoch [22/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0552 Train AUC=0.8337 | Val Loss=0.0600 Val AUC=0.7780
#   EarlyStopping counter: 7/30
# Epoch [23/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0557 Train AUC=0.8049 | Val Loss=0.0572 Val AUC=0.8043
#   EarlyStopping counter: 8/30
# Epoch [24/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0525 Train AUC=0.8418 | Val Loss=0.0566 Val AUC=0.8090
#   EarlyStopping counter: 9/30
# Epoch [25/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0526 Train AUC=0.8440 | Val Loss=0.0562 Val AUC=0.8212
# Epoch [26/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0535 Train AUC=0.8480 | Val Loss=0.0551 Val AUC=0.8127
#   EarlyStopping counter: 1/30
# Epoch [27/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0511 Train AUC=0.8404 | Val Loss=0.0557 Val AUC=0.8191
#   EarlyStopping counter: 2/30
# Epoch [28/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0495 Train AUC=0.8695 | Val Loss=0.0578 Val AUC=0.8085
#   EarlyStopping counter: 3/30
# Epoch [29/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0464 Train AUC=0.8750 | Val Loss=0.0560 Val AUC=0.8141
#   EarlyStopping counter: 4/30
# Epoch [30/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0486 Train AUC=0.8618 | Val Loss=0.0582 Val AUC=0.8156
#   EarlyStopping counter: 5/30
# Epoch [31/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0459 Train AUC=0.8768 | Val Loss=0.0606 Val AUC=0.8251
# Epoch [32/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0437 Train AUC=0.8897 | Val Loss=0.0649 Val AUC=0.8063
#   EarlyStopping counter: 1/30
# Epoch [33/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0433 Train AUC=0.8972 | Val Loss=0.0571 Val AUC=0.8201
#   EarlyStopping counter: 2/30
# Epoch [34/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0424 Train AUC=0.9028 | Val Loss=0.0641 Val AUC=0.7887
#   EarlyStopping counter: 3/30
# Epoch [35/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0430 Train AUC=0.8916 | Val Loss=0.0624 Val AUC=0.8024
#   EarlyStopping counter: 4/30
# Epoch [36/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0358 Train AUC=0.9265 | Val Loss=0.0675 Val AUC=0.8014
#   EarlyStopping counter: 5/30
# Epoch [37/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0424 Train AUC=0.9011 | Val Loss=0.0675 Val AUC=0.8005
#   EarlyStopping counter: 6/30
# Epoch [38/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0399 Train AUC=0.9131 | Val Loss=0.0597 Val AUC=0.8206
#   EarlyStopping counter: 7/30
# Epoch [39/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0385 Train AUC=0.9094 | Val Loss=0.0604 Val AUC=0.8153
#   EarlyStopping counter: 8/30
# Epoch [40/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0371 Train AUC=0.9154 | Val Loss=0.0671 Val AUC=0.8262
# Epoch [41/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0386 Train AUC=0.9159 | Val Loss=0.0604 Val AUC=0.8191
#   EarlyStopping counter: 1/30
# Epoch [42/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0360 Train AUC=0.9316 | Val Loss=0.0655 Val AUC=0.7911
#   EarlyStopping counter: 2/30
# Epoch [43/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0342 Train AUC=0.9341 | Val Loss=0.0764 Val AUC=0.7982
#   EarlyStopping counter: 3/30
# Epoch [44/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0389 Train AUC=0.9028 | Val Loss=0.0690 Val AUC=0.7856
#   EarlyStopping counter: 4/30
# Epoch [45/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0340 Train AUC=0.9317 | Val Loss=0.0705 Val AUC=0.7928
#   EarlyStopping counter: 5/30
# Epoch [46/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0314 Train AUC=0.9449 | Val Loss=0.0667 Val AUC=0.8279
# Epoch [47/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0345 Train AUC=0.9334 | Val Loss=0.0640 Val AUC=0.8331
# Epoch [48/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0343 Train AUC=0.9273 | Val Loss=0.0782 Val AUC=0.8113
#   EarlyStopping counter: 1/30
# Epoch [49/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0286 Train AUC=0.9541 | Val Loss=0.0633 Val AUC=0.8213
#   EarlyStopping counter: 2/30
# Epoch [50/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0302 Train AUC=0.9508 | Val Loss=0.0618 Val AUC=0.8264
#   EarlyStopping counter: 3/30
# Epoch [51/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0343 Train AUC=0.9405 | Val Loss=0.0693 Val AUC=0.8039
#   EarlyStopping counter: 4/30
# Epoch [52/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0337 Train AUC=0.9375 | Val Loss=0.0637 Val AUC=0.8150
#   EarlyStopping counter: 5/30
# Epoch [53/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0323 Train AUC=0.9388 | Val Loss=0.0711 Val AUC=0.8096
#   EarlyStopping counter: 6/30
# Epoch [54/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0249 Train AUC=0.9670 | Val Loss=0.0690 Val AUC=0.7942
#   EarlyStopping counter: 7/30
# Epoch [55/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0322 Train AUC=0.9395 | Val Loss=0.0682 Val AUC=0.8005
#   EarlyStopping counter: 8/30
# Epoch [56/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0241 Train AUC=0.9700 | Val Loss=0.0703 Val AUC=0.7982
#   EarlyStopping counter: 9/30
# Epoch [57/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0276 Train AUC=0.9557 | Val Loss=0.0663 Val AUC=0.7909
#   EarlyStopping counter: 10/30
# Epoch [58/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0265 Train AUC=0.9606 | Val Loss=0.0724 Val AUC=0.8074
#   EarlyStopping counter: 11/30
# Epoch [59/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0226 Train AUC=0.9739 | Val Loss=0.0734 Val AUC=0.8096
#   EarlyStopping counter: 12/30
# Epoch [60/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0231 Train AUC=0.9709 | Val Loss=0.0738 Val AUC=0.8143
#   EarlyStopping counter: 13/30
# Epoch [61/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0257 Train AUC=0.9634 | Val Loss=0.0726 Val AUC=0.8089
#   EarlyStopping counter: 14/30
# Epoch [62/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0251 Train AUC=0.9634 | Val Loss=0.0848 Val AUC=0.7846
#   EarlyStopping counter: 15/30
# Epoch [63/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0227 Train AUC=0.9685 | Val Loss=0.0774 Val AUC=0.8145
#   EarlyStopping counter: 16/30
# Epoch [64/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0241 Train AUC=0.9652 | Val Loss=0.0964 Val AUC=0.8176
#   EarlyStopping counter: 17/30
# Epoch [65/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0269 Train AUC=0.9663 | Val Loss=0.0912 Val AUC=0.8132
#   EarlyStopping counter: 18/30
# Epoch [66/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0233 Train AUC=0.9702 | Val Loss=0.0873 Val AUC=0.7986
#   EarlyStopping counter: 19/30
# Epoch [67/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0202 Train AUC=0.9800 | Val Loss=0.0783 Val AUC=0.8179
#   EarlyStopping counter: 20/30
# Epoch [68/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0222 Train AUC=0.9735 | Val Loss=0.0841 Val AUC=0.8366
# Epoch [69/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0215 Train AUC=0.9729 | Val Loss=0.0696 Val AUC=0.8065
#   EarlyStopping counter: 1/30
# Epoch [70/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0234 Train AUC=0.9656 | Val Loss=0.0780 Val AUC=0.7913
#   EarlyStopping counter: 2/30
# Epoch [71/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0193 Train AUC=0.9763 | Val Loss=0.0760 Val AUC=0.8067
#   EarlyStopping counter: 3/30
# Epoch [72/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0266 Train AUC=0.9601 | Val Loss=0.0798 Val AUC=0.7845
#   EarlyStopping counter: 4/30
# Epoch [73/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0261 Train AUC=0.9637 | Val Loss=0.0728 Val AUC=0.8121
#   EarlyStopping counter: 5/30
# Epoch [74/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0225 Train AUC=0.9760 | Val Loss=0.0858 Val AUC=0.8002
#   EarlyStopping counter: 6/30
# Epoch [75/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0199 Train AUC=0.9840 | Val Loss=0.0820 Val AUC=0.8094
#   EarlyStopping counter: 7/30
# Epoch [76/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0149 Train AUC=0.9905 | Val Loss=0.0691 Val AUC=0.8178
#   EarlyStopping counter: 8/30
# Epoch [77/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0225 Train AUC=0.9736 | Val Loss=0.0855 Val AUC=0.7955
#   EarlyStopping counter: 9/30
# Epoch [78/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0156 Train AUC=0.9887 | Val Loss=0.0737 Val AUC=0.8022
#   EarlyStopping counter: 10/30
# Epoch [79/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0171 Train AUC=0.9859 | Val Loss=0.0935 Val AUC=0.7878
#   EarlyStopping counter: 11/30
# Epoch [80/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0189 Train AUC=0.9841 | Val Loss=0.0770 Val AUC=0.7972
#   EarlyStopping counter: 12/30
# Epoch [81/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0210 Train AUC=0.9760 | Val Loss=0.1046 Val AUC=0.7743
#   EarlyStopping counter: 13/30
# Epoch [82/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0191 Train AUC=0.9755 | Val Loss=0.0777 Val AUC=0.7835
#   EarlyStopping counter: 14/30
# Epoch [83/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0210 Train AUC=0.9790 | Val Loss=0.0898 Val AUC=0.7812
#   EarlyStopping counter: 15/30
# Epoch [84/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0187 Train AUC=0.9787 | Val Loss=0.0853 Val AUC=0.7880
#   EarlyStopping counter: 16/30
# Epoch [85/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0222 Train AUC=0.9640 | Val Loss=0.0727 Val AUC=0.8044
#   EarlyStopping counter: 17/30
# Epoch [86/200] | Freeze=False | Layers=['layer1'] | Train Loss=0.0160 Train AUC=0.9849 | Val Loss=0.0864 Val AUC=0.8043
#   EarlyStopping counter: 18/30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 50
#      47 if current_epoch >= num_epochs: break
#      49 # ---- Training ----
# ---> 50 train_loss, train_aucpr, train_f1 = Train(imported_model, train_loader, optimizer)
#      51 val_loss, val_aucpr, val_f1, val_best_th = Validate(imported_model, val_loader)
#      53 # Log metrics
#
# Cell In[28], line 43, in Train(model, train_loader, optimizer, alpha)
#      40 loss.backward()
#      41 optimizer.step()
# ---> 43 running_loss += loss.item()
#      45 # Convert logits → probability of positive class
#      46 probs = F.softmax(outputs, dim=1)[:, 1]
#
# KeyboardInterrupt:

# %%
epochs = list(range(1, len(train_losses) + 1))

# -------- LOSS PLOT --------
plt.figure()
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.axvline(
    best_epoch,
    linestyle='--',
    label=f'Best Model (Epoch {best_epoch})'
)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs Epoch (Early Stopping)')
plt.legend()
plt.grid(True)
plt.show()

# -------- AUC-PR PLOT --------
plt.figure()
plt.plot(epochs, train_aucprs, label='Train AVG PR')
plt.plot(epochs, val_aucprs, label='Validation AVG PR')
plt.axvline(
    best_epoch,
    linestyle='--',
    label=f'Best Model (Epoch {best_epoch}) | Val AUC-PR = {best_val_aucpr:.4f}'
)
plt.xlabel('Epoch')
plt.ylabel('AVG PR')
plt.title('AUC-PR vs Epoch (Early Stopping)')
plt.legend()
plt.grid(True)
plt.show()

# -------- F1 SCORE PLOT --------
plt.figure()
plt.plot(epochs, train_f1s, label="Train F1")
plt.plot(epochs, val_f1s, label="Val F1")
plt.axvline(
    best_epoch,
    linestyle='--',
    label=f'Best Model (Epoch {best_epoch}) | Val AUC-PR = {best_val_aucpr:.4f}'
)
plt.xlabel("Epoch")
plt.ylabel("F1-score")
plt.title("F1-score vs Epoch")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import average_precision_score, precision_recall_curve
import torch.nn.functional as F

imported_model.eval()
all_probs = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = imported_model(images)

        # Probabilidad de clase positiva (defecto = clase 1)
        probs = F.softmax(outputs, dim=1)[:, 1]

        all_probs.extend(probs.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

auc_pr = average_precision_score(all_labels, all_probs)
print(f"AUC-PR: {auc_pr:.4f}")

# Convert lists to numpy arrays
all_probs = np.array(all_probs)
all_labels = np.array(all_labels)

# Compute Precision-Recall curve
precision, recall, thresholds = precision_recall_curve(all_labels, all_probs)

# Compute AUC-PR
auc_pr = average_precision_score(all_labels, all_probs)

# Plot
plt.figure()
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision-Recall Curve (AUC = {auc_pr:.4f})")
plt.grid(True)
plt.show()

print("Labels distribution:", np.bincount(all_labels.astype(int)))
# Out:
# AUC-PR: 0.8418
# Labels distribution: [78 47]

# %%
from sklearn.metrics import precision_recall_curve, auc
import numpy as np

imported_model.eval()
all_probs = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        logits = imported_model(images)
        probs = torch.softmax(logits, dim=1)[:, 1]

        all_probs.append(probs.cpu())
        all_labels.append(labels.cpu())

y_scores = torch.cat(all_probs).numpy()
y_true = torch.cat(all_labels).numpy()

# ---- PR Curve ----
precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
auc_pr = auc(recall, precision)

plt.figure()
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision-Recall Curve (AUC = {auc_pr:.4f})")
plt.grid(True)
plt.show()

# ---- F1 vs Threshold ----
f1_scores = 2 * (precision * recall) / (precision + recall + 1e-8)

best_idx = np.argmax(f1_scores)
best_f1 = f1_scores[best_idx]
best_threshold = thresholds[best_idx] if best_idx < len(thresholds) else 0.5

plt.figure()
plt.plot(thresholds, f1_scores[:-1])
plt.xlabel("Threshold")
plt.ylabel("F1 Score")
plt.title("F1 Score vs Threshold")
plt.grid(True)
plt.show()

print(f"AUC-PR: {auc_pr:.4f}")
print(f"Best F1: {best_f1:.4f}")
print(f"Best Threshold: {best_threshold:.4f}")
# Out:
# AUC-PR: 0.8403
# Best F1: 0.7865
# Best Threshold: 0.5871

# %% [markdown]
# ## Saving the model

# %%
# !pip install torch==2.2.0 torchvision==0.17.0 torchaudio==2.2.0 --index-url https://download.pytorch.org/whl/cu118
# !pip install onnx onnxruntime onnxscript

# %%
print(torch.__version__)
# Out:
# 2.10.0.dev20251210+cu128

# %%
import torch
import torch.onnx
import torchvision
dummy_input = torch.rand(1, 6, 310, 310).to(device)

import torch
print(torch.__version__)

imported_model.eval()
torch.onnx.export(
    imported_model,
    dummy_input,                     # still use (1,6,H,W)
    "model_test.onnx",
    opset_version=13,
    input_names=["x"],
    output_names=["linear"],
    dynamic_axes={
        "x": {0: "batch_size"},      # ✅ dynamic batch
        "linear": {0: "batch_size"}  # ✅ dynamic output batch
    },
    export_params=True,
    do_constant_folding=True,
    external_data=False   # export the parameters inside the same file
)

# torch.onnx.export(imported_model, dummy_input, 'model_v2.onnx', opset_version=11)
# Out:
# 2.10.0.dev20251210+cu128
# W1214 00:18:46.893000 32620 Lib\site-packages\torch\onnx\_internal\exporter\_compat.py:125] Setting ONNX exporter to use operator set version 18 because the requested opset_version 13 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# [torch.onnx] Obtain model graph for `ResNet([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `ResNet([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 13).
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# Failed to convert the model to the target version 13 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\onnxscript\version_converter\__init__.py", line 127, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\onnxscript\version_converter\_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\onnxscript\version_converter\__init__.py", line 122, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\onnx\version_converter.py", line 39, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: D:\a\onnx\onnx\onnx/version_converter/adapters/axes_input_to_attribute.h:65: adapt: Assertion `node->hasAttribute(kaxes)` failed: No initializer or constant input to node found
# Applied 75 of general pattern rewrite rules.
# ONNXProgram(
#     model=
#         <
#             ir_version=10,
#             opset_imports={'': 18},
#             producer_name='pytorch',
#             producer_version='2.10.0.dev20251210+cu128',
#             domain=None,
#             model_version=None,
#         >
#         graph(
#             name=main_graph,
#             inputs=(
#                 %"x"<FLOAT,[batch_size,6,310,310]>
#             ),
#             outputs=(
#                 %"linear"<FLOAT,[batch_size,2]>
#             ),
#             initializers=(
#                 %"fc.0.bias"<FLOAT,[256]>{Tensor(...)},
#                 %"fc.3.bias"<FLOAT,[128]>{Tensor(...)},
#                 %"fc.7.weight"<FLOAT,[2,128]>{TorchTensor(...)},
#                 %"fc.7.bias"<FLOAT,[2]>{TorchTensor<FLOAT,[2]>(Parameter containing: tensor([ 0.0380, -0.0292], device='cuda:0', requires_grad=True), name='fc.7.bias')},
#                 %"conv1.weight"<FLOAT,[64,6,7,7]>{Tensor(...)},
#                 %"layer1.0.conv1.weight"<FLOAT,[64,64,3,3]>{Tensor(...)},
#                 %"layer1.0.conv2.weight"<FLOAT,[64,64,3,3]>{Tensor(...)},
#                 %"layer1.1.conv1.weight"<FLOAT,[64,64,3,3]>{Tensor(...)},
#                 %"layer1.1.conv2.weight"<FLOAT,[64,64,3,3]>{Tensor(...)},
#                 %"layer1.2.conv1.weight"<FLOAT,[64,64,3,3]>{Tensor(...)},
#                 %"layer1.2.conv2.weight"<FLOAT,[64,64,3,3]>{Tensor(...)},
#                 %"layer2.0.conv1.weight"<FLOAT,[128,64,3,3]>{Tensor(...)},
#                 %"layer2.0.conv2.weight"<FLOAT,[128,128,3,3]>{Tensor(...)},
#                 %"layer2.0.downsample.0.weight"<FLOAT,[128,64,1,1]>{Tensor(...)},
#                 %"layer2.1.conv1.weight"<FLOAT,[128,128,3,3]>{Tensor(...)},
#                 %"layer2.1.conv2.weight"<FLOAT,[128,128,3,3]>{Tensor(...)},
#                 %"layer2.2.conv1.weight"<FLOAT,[128,128,3,3]>{Tensor(...)},
#                 %"layer2.2.conv2.weight"<FLOAT,[128,128,3,3]>{Tensor(...)},
#                 %"layer2.3.conv1.weight"<FLOAT,[128,128,3,3]>{Tensor(...)},
#                 %"layer2.3.conv2.weight"<FLOAT,[128,128,3,3]>{Tensor(...)},
#                 %"layer3.0.conv1.weight"<FLOAT,[256,128,3,3]>{Tensor(...)},
#                 %"layer3.0.conv2.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer3.0.downsample.0.weight"<FLOAT,[256,128,1,1]>{Tensor(...)},
#                 %"layer3.1.conv1.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer3.1.conv2.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer3.2.conv1.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer3.2.conv2.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer3.3.conv1.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer3.3.conv2.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer3.4.conv1.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer3.4.conv2.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer3.5.conv1.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer3.5.conv2.weight"<FLOAT,[256,256,3,3]>{Tensor(...)},
#                 %"layer4.0.conv1.weight"<FLOAT,[512,256,3,3]>{Tensor(...)},
#                 %"layer4.0.conv2.weight"<FLOAT,[512,512,3,3]>{Tensor(...)},
#                 %"layer4.0.downsample.0.weight"<FLOAT,[512,256,1,1]>{Tensor(...)},
#                 %"layer4.1.conv1.weight"<FLOAT,[512,512,3,3]>{Tensor(...)},
#                 %"layer4.1.conv2.weight"<FLOAT,[512,512,3,3]>{Tensor(...)},
#                 %"layer4.2.conv1.weight"<FLOAT,[512,512,3,3]>{Tensor(...)},
#                 %"layer4.2.conv2.weight"<FLOAT,[512,512,3,3]>{Tensor(...)},
#                 %"fc.0.weight"<FLOAT,[256,512]>{Tensor(...)},
#                 %"fc.3.weight"<FLOAT,[128,256]>{Tensor(...)},
#                 %"val_337"<INT64,[2]>{Tensor<INT64,[2]>(array([-1, -2]), name='val_337')},
#                 %"x_bias"<FLOAT,[64]>{Tensor(...)},
#                 %"max_pool2d_bias"<FLOAT,[64]>{Tensor(...)},
#                 %"relu_1_bias"<FLOAT,[64]>{Tensor(...)},
#                 %"relu_2_bias"<FLOAT,[64]>{Tensor(...)},
#                 %"relu_3_bias"<FLOAT,[64]>{Tensor(...)},
#                 %"relu_4_bias"<FLOAT,[64]>{Tensor(...)},
#                 %"relu_5_bias"<FLOAT,[64]>{Tensor(...)},
#                 %"relu_6_bias"<FLOAT,[128]>{Tensor(...)},
#                 %"relu_7_bias"<FLOAT,[128]>{Tensor(...)},
#                 %"relu_8_bias"<FLOAT,[128]>{Tensor(...)},
#                 %"relu_9_bias"<FLOAT,[128]>{Tensor(...)},
#                 %"relu_10_bias"<FLOAT,[128]>{Tensor(...)},
#                 %"relu_11_bias"<FLOAT,[128]>{Tensor(...)},
#                 %"relu_12_bias"<FLOAT,[128]>{Tensor(...)},
#                 %"relu_13_bias"<FLOAT,[128]>{Tensor(...)},
#                 %"relu_14_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_15_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_16_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_17_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_18_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_19_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_20_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_21_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_22_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_23_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_24_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_25_bias"<FLOAT,[256]>{Tensor(...)},
#                 %"relu_26_bias"<FLOAT,[512]>{Tensor(...)},
#                 %"relu_27_bias"<FLOAT,[512]>{Tensor(...)},
#                 %"relu_28_bias"<FLOAT,[512]>{Tensor(...)},
#                 %"relu_29_bias"<FLOAT,[512]>{Tensor(...)},
#                 %"relu_30_bias"<FLOAT,[512]>{Tensor(...)},
#                 %"relu_31_bias"<FLOAT,[512]>{Tensor(...)},
#                 %"val_340"<INT64,[1]>{Tensor<INT64,[1]>(array([512]), name='val_340')}
#             ),
#         ) {
#              0 |  # node_Shape_0
#                   %"val_0"<INT64,[1]> ⬅️ ::Shape(%"x") {start=0, end=1}
#              1 |  # node_Conv_458
#                   %"getitem"<FLOAT,[batch_size,64,155,155]> ⬅️ ::Conv(%"x", %"conv1.weight"{...}, %"x_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(3, 3, 3, 3)}
#              2 |  # node_relu
#                   %"relu"<FLOAT,[batch_size,64,155,155]> ⬅️ ::Relu(%"getitem")
#              3 |  # node_max_pool2d
#                   %"max_pool2d"<FLOAT,[batch_size,64,78,78]>, %""<?,?> ⬅️ ::MaxPool(%"relu") {kernel_shape=(3, 3), strides=(2, 2), dilations=(1, 1), auto_pad='NOTSET', pads=(1, 1, 1, 1), ceil_mode=0, storage_order=0}
#              4 |  # node_Conv_460
#                   %"getitem_3"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Conv(%"max_pool2d", %"layer1.0.conv1.weight"{...}, %"max_pool2d_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#              5 |  # node_relu_1
#                   %"relu_1"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Relu(%"getitem_3")
#              6 |  # node_Conv_462
#                   %"getitem_6"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Conv(%"relu_1", %"layer1.0.conv2.weight"{...}, %"relu_1_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#              7 |  # node_add_65
#                   %"add_65"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Add(%"getitem_6", %"max_pool2d")
#              8 |  # node_relu_2
#                   %"relu_2"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Relu(%"add_65")
#              9 |  # node_Conv_464
#                   %"getitem_9"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Conv(%"relu_2", %"layer1.1.conv1.weight"{...}, %"relu_2_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             10 |  # node_relu_3
#                   %"relu_3"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Relu(%"getitem_9")
#             11 |  # node_Conv_466
#                   %"getitem_12"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Conv(%"relu_3", %"layer1.1.conv2.weight"{...}, %"relu_3_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             12 |  # node_add_121
#                   %"add_121"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Add(%"getitem_12", %"relu_2")
#             13 |  # node_relu_4
#                   %"relu_4"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Relu(%"add_121")
#             14 |  # node_Conv_468
#                   %"getitem_15"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Conv(%"relu_4", %"layer1.2.conv1.weight"{...}, %"relu_4_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             15 |  # node_relu_5
#                   %"relu_5"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Relu(%"getitem_15")
#             16 |  # node_Conv_470
#                   %"getitem_18"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Conv(%"relu_5", %"layer1.2.conv2.weight"{...}, %"relu_5_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             17 |  # node_add_177
#                   %"add_177"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Add(%"getitem_18", %"relu_4")
#             18 |  # node_relu_6
#                   %"relu_6"<FLOAT,[batch_size,64,78,78]> ⬅️ ::Relu(%"add_177")
#             19 |  # node_Conv_472
#                   %"getitem_21"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Conv(%"relu_6", %"layer2.0.conv1.weight"{...}, %"relu_6_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(1, 1, 1, 1)}
#             20 |  # node_relu_7
#                   %"relu_7"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Relu(%"getitem_21")
#             21 |  # node_Conv_474
#                   %"getitem_24"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Conv(%"relu_7", %"layer2.0.conv2.weight"{...}, %"relu_7_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             22 |  # node_Conv_476
#                   %"getitem_27"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Conv(%"relu_6", %"layer2.0.downsample.0.weight"{...}, %"relu_6_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(0, 0, 0, 0)}
#             23 |  # node_add_243
#                   %"add_243"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Add(%"getitem_24", %"getitem_27")
#             24 |  # node_relu_8
#                   %"relu_8"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Relu(%"add_243")
#             25 |  # node_Conv_478
#                   %"getitem_30"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Conv(%"relu_8", %"layer2.1.conv1.weight"{...}, %"relu_8_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             26 |  # node_relu_9
#                   %"relu_9"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Relu(%"getitem_30")
#             27 |  # node_Conv_480
#                   %"getitem_33"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Conv(%"relu_9", %"layer2.1.conv2.weight"{...}, %"relu_9_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             28 |  # node_add_299
#                   %"add_299"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Add(%"getitem_33", %"relu_8")
#             29 |  # node_relu_10
#                   %"relu_10"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Relu(%"add_299")
#             30 |  # node_Conv_482
#                   %"getitem_36"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Conv(%"relu_10", %"layer2.2.conv1.weight"{...}, %"relu_10_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             31 |  # node_relu_11
#                   %"relu_11"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Relu(%"getitem_36")
#             32 |  # node_Conv_484
#                   %"getitem_39"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Conv(%"relu_11", %"layer2.2.conv2.weight"{...}, %"relu_11_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             33 |  # node_add_355
#                   %"add_355"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Add(%"getitem_39", %"relu_10")
#             34 |  # node_relu_12
#                   %"relu_12"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Relu(%"add_355")
#             35 |  # node_Conv_486
#                   %"getitem_42"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Conv(%"relu_12", %"layer2.3.conv1.weight"{...}, %"relu_12_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             36 |  # node_relu_13
#                   %"relu_13"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Relu(%"getitem_42")
#             37 |  # node_Conv_488
#                   %"getitem_45"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Conv(%"relu_13", %"layer2.3.conv2.weight"{...}, %"relu_13_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             38 |  # node_add_411
#                   %"add_411"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Add(%"getitem_45", %"relu_12")
#             39 |  # node_relu_14
#                   %"relu_14"<FLOAT,[batch_size,128,39,39]> ⬅️ ::Relu(%"add_411")
#             40 |  # node_Conv_490
#                   %"getitem_48"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_14", %"layer3.0.conv1.weight"{...}, %"relu_14_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(1, 1, 1, 1)}
#             41 |  # node_relu_15
#                   %"relu_15"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"getitem_48")
#             42 |  # node_Conv_492
#                   %"getitem_51"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_15", %"layer3.0.conv2.weight"{...}, %"relu_15_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             43 |  # node_Conv_494
#                   %"getitem_54"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_14", %"layer3.0.downsample.0.weight"{...}, %"relu_14_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(0, 0, 0, 0)}
#             44 |  # node_add_477
#                   %"add_477"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Add(%"getitem_51", %"getitem_54")
#             45 |  # node_relu_16
#                   %"relu_16"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"add_477")
#             46 |  # node_Conv_496
#                   %"getitem_57"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_16", %"layer3.1.conv1.weight"{...}, %"relu_16_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             47 |  # node_relu_17
#                   %"relu_17"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"getitem_57")
#             48 |  # node_Conv_498
#                   %"getitem_60"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_17", %"layer3.1.conv2.weight"{...}, %"relu_17_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             49 |  # node_add_533
#                   %"add_533"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Add(%"getitem_60", %"relu_16")
#             50 |  # node_relu_18
#                   %"relu_18"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"add_533")
#             51 |  # node_Conv_500
#                   %"getitem_63"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_18", %"layer3.2.conv1.weight"{...}, %"relu_18_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             52 |  # node_relu_19
#                   %"relu_19"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"getitem_63")
#             53 |  # node_Conv_502
#                   %"getitem_66"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_19", %"layer3.2.conv2.weight"{...}, %"relu_19_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             54 |  # node_add_589
#                   %"add_589"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Add(%"getitem_66", %"relu_18")
#             55 |  # node_relu_20
#                   %"relu_20"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"add_589")
#             56 |  # node_Conv_504
#                   %"getitem_69"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_20", %"layer3.3.conv1.weight"{...}, %"relu_20_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             57 |  # node_relu_21
#                   %"relu_21"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"getitem_69")
#             58 |  # node_Conv_506
#                   %"getitem_72"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_21", %"layer3.3.conv2.weight"{...}, %"relu_21_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             59 |  # node_add_645
#                   %"add_645"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Add(%"getitem_72", %"relu_20")
#             60 |  # node_relu_22
#                   %"relu_22"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"add_645")
#             61 |  # node_Conv_508
#                   %"getitem_75"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_22", %"layer3.4.conv1.weight"{...}, %"relu_22_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             62 |  # node_relu_23
#                   %"relu_23"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"getitem_75")
#             63 |  # node_Conv_510
#                   %"getitem_78"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_23", %"layer3.4.conv2.weight"{...}, %"relu_23_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             64 |  # node_add_701
#                   %"add_701"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Add(%"getitem_78", %"relu_22")
#             65 |  # node_relu_24
#                   %"relu_24"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"add_701")
#             66 |  # node_Conv_512
#                   %"getitem_81"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_24", %"layer3.5.conv1.weight"{...}, %"relu_24_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             67 |  # node_relu_25
#                   %"relu_25"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"getitem_81")
#             68 |  # node_Conv_514
#                   %"getitem_84"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Conv(%"relu_25", %"layer3.5.conv2.weight"{...}, %"relu_25_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             69 |  # node_add_757
#                   %"add_757"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Add(%"getitem_84", %"relu_24")
#             70 |  # node_relu_26
#                   %"relu_26"<FLOAT,[batch_size,256,20,20]> ⬅️ ::Relu(%"add_757")
#             71 |  # node_Conv_516
#                   %"getitem_87"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Conv(%"relu_26", %"layer4.0.conv1.weight"{...}, %"relu_26_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(1, 1, 1, 1)}
#             72 |  # node_relu_27
#                   %"relu_27"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Relu(%"getitem_87")
#             73 |  # node_Conv_518
#                   %"getitem_90"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Conv(%"relu_27", %"layer4.0.conv2.weight"{...}, %"relu_27_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             74 |  # node_Conv_520
#                   %"getitem_93"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Conv(%"relu_26", %"layer4.0.downsample.0.weight"{...}, %"relu_26_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(0, 0, 0, 0)}
#             75 |  # node_add_823
#                   %"add_823"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Add(%"getitem_90", %"getitem_93")
#             76 |  # node_relu_28
#                   %"relu_28"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Relu(%"add_823")
#             77 |  # node_Conv_522
#                   %"getitem_96"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Conv(%"relu_28", %"layer4.1.conv1.weight"{...}, %"relu_28_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             78 |  # node_relu_29
#                   %"relu_29"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Relu(%"getitem_96")
#             79 |  # node_Conv_524
#                   %"getitem_99"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Conv(%"relu_29", %"layer4.1.conv2.weight"{...}, %"relu_29_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             80 |  # node_add_879
#                   %"add_879"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Add(%"getitem_99", %"relu_28")
#             81 |  # node_relu_30
#                   %"relu_30"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Relu(%"add_879")
#             82 |  # node_Conv_526
#                   %"getitem_102"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Conv(%"relu_30", %"layer4.2.conv1.weight"{...}, %"relu_30_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             83 |  # node_relu_31
#                   %"relu_31"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Relu(%"getitem_102")
#             84 |  # node_Conv_528
#                   %"getitem_105"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Conv(%"relu_31", %"layer4.2.conv2.weight"{...}, %"relu_31_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             85 |  # node_add_935
#                   %"add_935"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Add(%"getitem_105", %"relu_30")
#             86 |  # node_relu_32
#                   %"relu_32"<FLOAT,[batch_size,512,10,10]> ⬅️ ::Relu(%"add_935")
#             87 |  # node_mean
#                   %"mean"<FLOAT,[batch_size,512,1,1]> ⬅️ ::ReduceMean(%"relu_32", %"val_337"{[-1, -2]}) {keepdims=1, noop_with_empty_axes=0}
#             88 |  # node_Concat_340
#                   %"val_341"<INT64,[2]> ⬅️ ::Concat(%"val_0", %"val_340"{[512]}) {axis=0}
#             89 |  # node_view
#                   %"view"<FLOAT,[batch_size,512]> ⬅️ ::Reshape(%"mean", %"val_341") {allowzero=1}
#             90 |  # node_Gemm_530
#                   %"getitem_108"<FLOAT,[batch_size,256]> ⬅️ ::Gemm(%"view", %"fc.0.weight"{...}, %"fc.0.bias"{...}) {transA=0, transB=1, alpha=1.0, beta=1.0}
#             91 |  # node_leaky_relu
#                   %"leaky_relu"<FLOAT,[batch_size,256]> ⬅️ ::LeakyRelu(%"getitem_108") {alpha=0.01}
#             92 |  # node_Gemm_531
#                   %"getitem_111"<FLOAT,[batch_size,128]> ⬅️ ::Gemm(%"leaky_relu", %"fc.3.weight"{...}, %"fc.3.bias"{...}) {transA=0, transB=1, alpha=1.0, beta=1.0}
#             93 |  # node_leaky_relu_1
#                   %"leaky_relu_1"<FLOAT,[batch_size,128]> ⬅️ ::LeakyRelu(%"getitem_111") {alpha=0.01}
#             94 |  # node_linear_2
#                   %"linear"<FLOAT,[batch_size,2]> ⬅️ ::Gemm(%"leaky_relu_1", %"fc.7.weight"{...}, %"fc.7.bias"{[0.037952929735183716, -0.02917024865746498]}) {transA=0, transB=1, alpha=1.0, beta=1.0}
#             return %"linear"<FLOAT,[batch_size,2]>
#         }
#
#
#     ,
#     exported_program=
#         ExportedProgram:
#             class GraphModule(torch.nn.Module):
#                 def forward(self, p_conv1_weight: "f32[64, 6, 7, 7]", p_bn1_weight: "f32[64]", p_bn1_bias: "f32[64]", p_layer1_0_conv1_weight: "f32[64, 64, 3, 3]", p_layer1_0_bn1_weight: "f32[64]", p_layer1_0_bn1_bias: "f32[64]", p_layer1_0_conv2_weight: "f32[64, 64, 3, 3]", p_layer1_0_bn2_weight: "f32[64]", p_layer1_0_bn2_bias: "f32[64]", p_layer1_1_conv1_weight: "f32[64, 64, 3, 3]", p_layer1_1_bn1_weight: "f32[64]", p_layer1_1_bn1_bias: "f32[64]", p_layer1_1_conv2_weight: "f32[64, 64, 3, 3]", p_layer1_1_bn2_weight: "f32[64]", p_layer1_1_bn2_bias: "f32[64]", p_layer1_2_conv1_weight: "f32[64, 64, 3, 3]", p_layer1_2_bn1_weight: "f32[64]", p_layer1_2_bn1_bias: "f32[64]", p_layer1_2_conv2_weight: "f32[64, 64, 3, 3]", p_layer1_2_bn2_weight: "f32[64]", p_layer1_2_bn2_bias: "f32[64]", p_layer2_0_conv1_weight: "f32[128, 64, 3, 3]", p_layer2_0_bn1_weight: "f32[128]", p_layer2_0_bn1_bias: "f32[128]", p_layer2_0_conv2_weight: "f32[128, 128, 3, 3]", p_layer2_0_bn2_weight: "f32[128]", p_layer2_0_bn2_bias: "f32[128]", p_layer2_0_downsample_0_weight: "f32[128, 64, 1, 1]", p_layer2_0_downsample_1_weight: "f32[128]", p_layer2_0_downsample_1_bias: "f32[128]", p_layer2_1_conv1_weight: "f32[128, 128, 3, 3]", p_layer2_1_bn1_weight: "f32[128]", p_layer2_1_bn1_bias: "f32[128]", p_layer2_1_conv2_weight: "f32[128, 128, 3, 3]", p_layer2_1_bn2_weight: "f32[128]", p_layer2_1_bn2_bias: "f32[128]", p_layer2_2_conv1_weight: "f32[128, 128, 3, 3]", p_layer2_2_bn1_weight: "f32[128]", p_layer2_2_bn1_bias: "f32[128]", p_layer2_2_conv2_weight: "f32[128, 128, 3, 3]", p_layer2_2_bn2_weight: "f32[128]", p_layer2_2_bn2_bias: "f32[128]", p_layer2_3_conv1_weight: "f32[128, 128, 3, 3]", p_layer2_3_bn1_weight: "f32[128]", p_layer2_3_bn1_bias: "f32[128]", p_layer2_3_conv2_weight: "f32[128, 128, 3, 3]", p_layer2_3_bn2_weight: "f32[128]", p_layer2_3_bn2_bias: "f32[128]", p_layer3_0_conv1_weight: "f32[256, 128, 3, 3]", p_layer3_0_bn1_weight: "f32[256]", p_layer3_0_bn1_bias: "f32[256]", p_layer3_0_conv2_weight: "f32[256, 256, 3, 3]", p_layer3_0_bn2_weight: "f32[256]", p_layer3_0_bn2_bias: "f32[256]", p_layer3_0_downsample_0_weight: "f32[256, 128, 1, 1]", p_layer3_0_downsample_1_weight: "f32[256]", p_layer3_0_downsample_1_bias: "f32[256]", p_layer3_1_conv1_weight: "f32[256, 256, 3, 3]", p_layer3_1_bn1_weight: "f32[256]", p_layer3_1_bn1_bias: "f32[256]", p_layer3_1_conv2_weight: "f32[256, 256, 3, 3]", p_layer3_1_bn2_weight: "f32[256]", p_layer3_1_bn2_bias: "f32[256]", p_layer3_2_conv1_weight: "f32[256, 256, 3, 3]", p_layer3_2_bn1_weight: "f32[256]", p_layer3_2_bn1_bias: "f32[256]", p_layer3_2_conv2_weight: "f32[256, 256, 3, 3]", p_layer3_2_bn2_weight: "f32[256]", p_layer3_2_bn2_bias: "f32[256]", p_layer3_3_conv1_weight: "f32[256, 256, 3, 3]", p_layer3_3_bn1_weight: "f32[256]", p_layer3_3_bn1_bias: "f32[256]", p_layer3_3_conv2_weight: "f32[256, 256, 3, 3]", p_layer3_3_bn2_weight: "f32[256]", p_layer3_3_bn2_bias: "f32[256]", p_layer3_4_conv1_weight: "f32[256, 256, 3, 3]", p_layer3_4_bn1_weight: "f32[256]", p_layer3_4_bn1_bias: "f32[256]", p_layer3_4_conv2_weight: "f32[256, 256, 3, 3]", p_layer3_4_bn2_weight: "f32[256]", p_layer3_4_bn2_bias: "f32[256]", p_layer3_5_conv1_weight: "f32[256, 256, 3, 3]", p_layer3_5_bn1_weight: "f32[256]", p_layer3_5_bn1_bias: "f32[256]", p_layer3_5_conv2_weight: "f32[256, 256, 3, 3]", p_layer3_5_bn2_weight: "f32[256]", p_layer3_5_bn2_bias: "f32[256]", p_layer4_0_conv1_weight: "f32[512, 256, 3, 3]", p_layer4_0_bn1_weight: "f32[512]", p_layer4_0_bn1_bias: "f32[512]", p_layer4_0_conv2_weight: "f32[512, 512, 3, 3]", p_layer4_0_bn2_weight: "f32[512]", p_layer4_0_bn2_bias: "f32[512]", p_layer4_0_downsample_0_weight: "f32[512, 256, 1, 1]", p_layer4_0_downsample_1_weight: "f32[512]", p_layer4_0_downsample_1_bias: "f32[512]", p_layer4_1_conv1_weight: "f32[512, 512, 3, 3]", p_layer4_1_bn1_weight: "f32[512]", p_layer4_1_bn1_bias: "f32[512]", p_layer4_1_conv2_weight: "f32[512, 512, 3, 3]", p_layer4_1_bn2_weight: "f32[512]", p_layer4_1_bn2_bias: "f32[512]", p_lay ...
#                     # No stacktrace found for following nodes
#                     sym_size_int_1: "Sym(s77)" = torch.ops.aten.sym_size.int(x, 0)
#                     mul_584: "Sym(1537600*s77)" = 1537600 * sym_size_int_1
#                     lt_57: "Sym(1537600*s77 < 2147483647)" = mul_584 < 2147483647;  mul_584 = lt_57 = None
#                     mul_585: "Sym(389376*s77)" = 389376 * sym_size_int_1
#                     lt_58: "Sym(389376*s77 < 2147483647)" = mul_585 < 2147483647;  mul_585 = lt_58 = None
#                     mul_586: "Sym(194688*s77)" = 194688 * sym_size_int_1
#                     lt_59: "Sym(194688*s77 < 2147483647)" = mul_586 < 2147483647;  mul_586 = lt_59 = None
#                     mul_587: "Sym(102400*s77)" = 102400 * sym_size_int_1
#                     lt_60: "Sym(102400*s77 < 2147483647)" = mul_587 < 2147483647;  mul_587 = lt_60 = None
#                     mul_588: "Sym(51200*s77)" = 51200 * sym_size_int_1
#                     lt_61: "Sym(51200*s77 < 2147483647)" = mul_588 < 2147483647;  mul_588 = lt_61 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d: "f32[s77, 64, 155, 155]" = torch.ops.aten.conv2d.default(x, p_conv1_weight, None, [2, 2], [3, 3]);  x = p_conv1_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d, p_bn1_weight, p_bn1_bias, b_bn1_running_mean, b_bn1_running_var, 0.1, 1e-05);  conv2d = p_bn1_weight = p_bn1_bias = b_bn1_running_mean = b_bn1_running_var = None
#                     getitem: "f32[s77, 64, 155, 155]" = _native_batch_norm_legit_no_training[0];  _native_batch_norm_legit_no_training = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu: "f32[s77, 64, 155, 155]" = torch.ops.aten.relu.default(getitem);  getitem = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d: "f32[s77, 64, 78, 78]" = torch.ops.aten.max_pool2d.default(relu, [3, 3], [2, 2], [1, 1]);  relu = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_1: "f32[s77, 64, 78, 78]" = torch.ops.aten.conv2d.default(max_pool2d, p_layer1_0_conv1_weight, None, [1, 1], [1, 1]);  p_layer1_0_conv1_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_1 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_1, p_layer1_0_bn1_weight, p_layer1_0_bn1_bias, b_layer1_0_bn1_running_mean, b_layer1_0_bn1_running_var, 0.1, 1e-05);  conv2d_1 = p_layer1_0_bn1_weight = p_layer1_0_bn1_bias = b_layer1_0_bn1_running_mean = b_layer1_0_bn1_running_var = None
#                     getitem_3: "f32[s77, 64, 78, 78]" = _native_batch_norm_legit_no_training_1[0];  _native_batch_norm_legit_no_training_1 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_1: "f32[s77, 64, 78, 78]" = torch.ops.aten.relu.default(getitem_3);  getitem_3 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_2: "f32[s77, 64, 78, 78]" = torch.ops.aten.conv2d.default(relu_1, p_layer1_0_conv2_weight, None, [1, 1], [1, 1]);  relu_1 = p_layer1_0_conv2_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_2 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_2, p_layer1_0_bn2_weight, p_layer1_0_bn2_bias, b_layer1_0_bn2_running_mean, b_layer1_0_bn2_running_var, 0.1, 1e-05);  conv2d_2 = p_layer1_0_bn2_weight = p_layer1_0_bn2_bias = b_layer1_0_bn2_running_mean = b_layer1_0_bn2_running_var = None
#                     getitem_6: "f32[s77, 64, 78, 78]" = _native_batch_norm_legit_no_training_2[0];  _native_batch_norm_legit_no_training_2 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torchvision\models\resnet.py:102 in forward, code: out += identity
#                     add_65: "f32[s77, 64, 78, 78]" = torch.ops.aten.add.Tensor(getitem_6, max_pool2d);  getitem_6 = max_pool2d = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_2: "f32[s77, 64, 78, 78]" = torch.ops.aten.relu.default(add_65);  add_65 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_3: "f32[s77, 64, 78, 78]" = torch.ops.aten.conv2d.default(relu_2, p_layer1_1_conv1_weight, None, [1, 1], [1, 1]);  p_layer1_1_conv1_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_3 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_3, p_layer1_1_bn1_weight, p_layer1_1_bn1_bias, b_layer1_1_bn1_running_mean, b_layer1_1_bn1_running_var, 0.1, 1e-05);  conv2d_3 = p_layer1_1_bn1_weight = p_layer1_1_bn1_bias = b_layer1_1_bn1_running_mean = b_layer1_1_bn1_running_var = None
#                     getitem_9: "f32[s77, 64, 78, 78]" = _native_batch_norm_legit_no_training_3[0];  _native_batch_norm_legit_no_training_3 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_3: "f32[s77, 64, 78, 78]" = torch.ops.aten.relu.default(getitem_9);  getitem_9 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_4: "f32[s77, 64, 78, 78]" = torch.ops.aten.conv2d.default(relu_3, p_layer1_1_conv2_weight, None, [1, 1], [1, 1]);  relu_3 = p_layer1_1_conv2_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_4 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_4, p_layer1_1_bn2_weight, p_layer1_1_bn2_bias, b_layer1_1_bn2_running_mean, b_layer1_1_bn2_running_var, 0.1, 1e-05);  conv2d_4 = p_layer1_1_bn2_weight = p_layer1_1_bn2_bias = b_layer1_1_bn2_running_mean = b_layer1_1_bn2_running_var = None
#                     getitem_12: "f32[s77, 64, 78, 78]" = _native_batch_norm_legit_no_training_4[0];  _native_batch_norm_legit_no_training_4 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torchvision\models\resnet.py:102 in forward, code: out += identity
#                     add_121: "f32[s77, 64, 78, 78]" = torch.ops.aten.add.Tensor(getitem_12, relu_2);  getitem_12 = relu_2 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_4: "f32[s77, 64, 78, 78]" = torch.ops.aten.relu.default(add_121);  add_121 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_5: "f32[s77, 64, 78, 78]" = torch.ops.aten.conv2d.default(relu_4, p_layer1_2_conv1_weight, None, [1, 1], [1, 1]);  p_layer1_2_conv1_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_5 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_5, p_layer1_2_bn1_weight, p_layer1_2_bn1_bias, b_layer1_2_bn1_running_mean, b_layer1_2_bn1_running_var, 0.1, 1e-05);  conv2d_5 = p_layer1_2_bn1_weight = p_layer1_2_bn1_bias = b_layer1_2_bn1_running_mean = b_layer1_2_bn1_running_var = None
#                     getitem_15: "f32[s77, 64, 78, 78]" = _native_batch_norm_legit_no_training_5[0];  _native_batch_norm_legit_no_training_5 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_5: "f32[s77, 64, 78, 78]" = torch.ops.aten.relu.default(getitem_15);  getitem_15 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_6: "f32[s77, 64, 78, 78]" = torch.ops.aten.conv2d.default(relu_5, p_layer1_2_conv2_weight, None, [1, 1], [1, 1]);  relu_5 = p_layer1_2_conv2_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_6 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_6, p_layer1_2_bn2_weight, p_layer1_2_bn2_bias, b_layer1_2_bn2_running_mean, b_layer1_2_bn2_running_var, 0.1, 1e-05);  conv2d_6 = p_layer1_2_bn2_weight = p_layer1_2_bn2_bias = b_layer1_2_bn2_running_mean = b_layer1_2_bn2_running_var = None
#                     getitem_18: "f32[s77, 64, 78, 78]" = _native_batch_norm_legit_no_training_6[0];  _native_batch_norm_legit_no_training_6 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torchvision\models\resnet.py:102 in forward, code: out += identity
#                     add_177: "f32[s77, 64, 78, 78]" = torch.ops.aten.add.Tensor(getitem_18, relu_4);  getitem_18 = relu_4 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_6: "f32[s77, 64, 78, 78]" = torch.ops.aten.relu.default(add_177);  add_177 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_7: "f32[s77, 128, 39, 39]" = torch.ops.aten.conv2d.default(relu_6, p_layer2_0_conv1_weight, None, [2, 2], [1, 1]);  p_layer2_0_conv1_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_7 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_7, p_layer2_0_bn1_weight, p_layer2_0_bn1_bias, b_layer2_0_bn1_running_mean, b_layer2_0_bn1_running_var, 0.1, 1e-05);  conv2d_7 = p_layer2_0_bn1_weight = p_layer2_0_bn1_bias = b_layer2_0_bn1_running_mean = b_layer2_0_bn1_running_var = None
#                     getitem_21: "f32[s77, 128, 39, 39]" = _native_batch_norm_legit_no_training_7[0];  _native_batch_norm_legit_no_training_7 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_7: "f32[s77, 128, 39, 39]" = torch.ops.aten.relu.default(getitem_21);  getitem_21 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_8: "f32[s77, 128, 39, 39]" = torch.ops.aten.conv2d.default(relu_7, p_layer2_0_conv2_weight, None, [1, 1], [1, 1]);  relu_7 = p_layer2_0_conv2_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_8 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_8, p_layer2_0_bn2_weight, p_layer2_0_bn2_bias, b_layer2_0_bn2_running_mean, b_layer2_0_bn2_running_var, 0.1, 1e-05);  conv2d_8 = p_layer2_0_bn2_weight = p_layer2_0_bn2_bias = b_layer2_0_bn2_running_mean = b_layer2_0_bn2_running_var = None
#                     getitem_24: "f32[s77, 128, 39, 39]" = _native_batch_norm_legit_no_training_8[0];  _native_batch_norm_legit_no_training_8 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_9: "f32[s77, 128, 39, 39]" = torch.ops.aten.conv2d.default(relu_6, p_layer2_0_downsample_0_weight, None, [2, 2]);  relu_6 = p_layer2_0_downsample_0_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_9 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_9, p_layer2_0_downsample_1_weight, p_layer2_0_downsample_1_bias, b_layer2_0_downsample_1_running_mean, b_layer2_0_downsample_1_running_var, 0.1, 1e-05);  conv2d_9 = p_layer2_0_downsample_1_weight = p_layer2_0_downsample_1_bias = b_layer2_0_downsample_1_running_mean = b_layer2_0_downsample_1_running_var = None
#                     getitem_27: "f32[s77, 128, 39, 39]" = _native_batch_norm_legit_no_training_9[0];  _native_batch_norm_legit_no_training_9 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torchvision\models\resnet.py:102 in forward, code: out += identity
#                     add_243: "f32[s77, 128, 39, 39]" = torch.ops.aten.add.Tensor(getitem_24, getitem_27);  getitem_24 = getitem_27 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_8: "f32[s77, 128, 39, 39]" = torch.ops.aten.relu.default(add_243);  add_243 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_10: "f32[s77, 128, 39, 39]" = torch.ops.aten.conv2d.default(relu_8, p_layer2_1_conv1_weight, None, [1, 1], [1, 1]);  p_layer2_1_conv1_weight = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\batchnorm.py:194 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_10 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_10, p_layer2_1_bn1_weight, p_layer2_1_bn1_bias, b_layer2_1_bn1_running_mean, b_layer2_1_bn1_running_var, 0.1, 1e-05);  conv2d_10 = p_layer2_1_bn1_weight = p_layer2_1_bn1_bias = b_layer2_1_bn1_running_mean = b_layer2_1_bn1_running_var = None
#                     getitem_30: "f32[s77, 128, 39, 39]" = _native_batch_norm_legit_no_training_10[0];  _native_batch_norm_legit_no_training_10 = None
#
#                     # File: c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\torch\nn\modules\activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_9: "f32[s77, 128, 39, 39]" = torch.ops.aten.relu.default(getitem_30);  getitem_30 = None
#
# ...
#             p_layer3_1_bn2_weight: PARAMETER target='layer3.1.bn2.weight'
#             p_layer3_1_bn2_bias: PARAMETER target='layer3.1.bn2.bias'
#             p_layer3_2_conv1_weight: PARAMETER target='layer3.2.conv1.weight'
#             p_layer3_2_bn1_weight: PARAMETER target='layer3.2.bn1.weight'
#             p_layer3_2_bn1_bias: PARAMETER target='layer3.2.bn1.bias'
#             p_layer3_2_conv2_weight: PARAMETER target='layer3.2.conv2.weight'
#             p_layer3_2_bn2_weight: PARAMETER target='layer3.2.bn2.weight'
#             p_layer3_2_bn2_bias: PARAMETER target='layer3.2.bn2.bias'
#             p_layer3_3_conv1_weight: PARAMETER target='layer3.3.conv1.weight'
#             p_layer3_3_bn1_weight: PARAMETER target='layer3.3.bn1.weight'
#             p_layer3_3_bn1_bias: PARAMETER target='layer3.3.bn1.bias'
#             p_layer3_3_conv2_weight: PARAMETER target='layer3.3.conv2.weight'
#             p_layer3_3_bn2_weight: PARAMETER target='layer3.3.bn2.weight'
#             p_layer3_3_bn2_bias: PARAMETER target='layer3.3.bn2.bias'
#             p_layer3_4_conv1_weight: PARAMETER target='layer3.4.conv1.weight'
#             p_layer3_4_bn1_weight: PARAMETER target='layer3.4.bn1.weight'
#             p_layer3_4_bn1_bias: PARAMETER target='layer3.4.bn1.bias'
#             p_layer3_4_conv2_weight: PARAMETER target='layer3.4.conv2.weight'
#             p_layer3_4_bn2_weight: PARAMETER target='layer3.4.bn2.weight'
#             p_layer3_4_bn2_bias: PARAMETER target='layer3.4.bn2.bias'
#             p_layer3_5_conv1_weight: PARAMETER target='layer3.5.conv1.weight'
#             p_layer3_5_bn1_weight: PARAMETER target='layer3.5.bn1.weight'
#             p_layer3_5_bn1_bias: PARAMETER target='layer3.5.bn1.bias'
#             p_layer3_5_conv2_weight: PARAMETER target='layer3.5.conv2.weight'
#             p_layer3_5_bn2_weight: PARAMETER target='layer3.5.bn2.weight'
#             p_layer3_5_bn2_bias: PARAMETER target='layer3.5.bn2.bias'
#             p_layer4_0_conv1_weight: PARAMETER target='layer4.0.conv1.weight'
#             p_layer4_0_bn1_weight: PARAMETER target='layer4.0.bn1.weight'
#             p_layer4_0_bn1_bias: PARAMETER target='layer4.0.bn1.bias'
#             p_layer4_0_conv2_weight: PARAMETER target='layer4.0.conv2.weight'
#             p_layer4_0_bn2_weight: PARAMETER target='layer4.0.bn2.weight'
#             p_layer4_0_bn2_bias: PARAMETER target='layer4.0.bn2.bias'
#             p_layer4_0_downsample_0_weight: PARAMETER target='layer4.0.downsample.0.weight'
#             p_layer4_0_downsample_1_weight: PARAMETER target='layer4.0.downsample.1.weight'
#             p_layer4_0_downsample_1_bias: PARAMETER target='layer4.0.downsample.1.bias'
#             p_layer4_1_conv1_weight: PARAMETER target='layer4.1.conv1.weight'
#             p_layer4_1_bn1_weight: PARAMETER target='layer4.1.bn1.weight'
#             p_layer4_1_bn1_bias: PARAMETER target='layer4.1.bn1.bias'
#             p_layer4_1_conv2_weight: PARAMETER target='layer4.1.conv2.weight'
#             p_layer4_1_bn2_weight: PARAMETER target='layer4.1.bn2.weight'
#             p_layer4_1_bn2_bias: PARAMETER target='layer4.1.bn2.bias'
#             p_layer4_2_conv1_weight: PARAMETER target='layer4.2.conv1.weight'
#             p_layer4_2_bn1_weight: PARAMETER target='layer4.2.bn1.weight'
#             p_layer4_2_bn1_bias: PARAMETER target='layer4.2.bn1.bias'
#             p_layer4_2_conv2_weight: PARAMETER target='layer4.2.conv2.weight'
#             p_layer4_2_bn2_weight: PARAMETER target='layer4.2.bn2.weight'
#             p_layer4_2_bn2_bias: PARAMETER target='layer4.2.bn2.bias'
#             p_fc_0_weight: PARAMETER target='fc.0.weight'
#             p_fc_0_bias: PARAMETER target='fc.0.bias'
#             p_fc_1_weight: PARAMETER target='fc.1.weight'
#             p_fc_1_bias: PARAMETER target='fc.1.bias'
#             p_fc_3_weight: PARAMETER target='fc.3.weight'
#             p_fc_3_bias: PARAMETER target='fc.3.bias'
#             p_fc_4_weight: PARAMETER target='fc.4.weight'
#             p_fc_4_bias: PARAMETER target='fc.4.bias'
#             p_fc_7_weight: PARAMETER target='fc.7.weight'
#             p_fc_7_bias: PARAMETER target='fc.7.bias'
#             b_bn1_running_mean: BUFFER target='bn1.running_mean' persistent=True
#             b_bn1_running_var: BUFFER target='bn1.running_var' persistent=True
#             b_bn1_num_batches_tracked: BUFFER target='bn1.num_batches_tracked' persistent=True
#             b_layer1_0_bn1_running_mean: BUFFER target='layer1.0.bn1.running_mean' persistent=True
#             b_layer1_0_bn1_running_var: BUFFER target='layer1.0.bn1.running_var' persistent=True
#             b_layer1_0_bn1_num_batches_tracked: BUFFER target='layer1.0.bn1.num_batches_tracked' persistent=True
#             b_layer1_0_bn2_running_mean: BUFFER target='layer1.0.bn2.running_mean' persistent=True
#             b_layer1_0_bn2_running_var: BUFFER target='layer1.0.bn2.running_var' persistent=True
#             b_layer1_0_bn2_num_batches_tracked: BUFFER target='layer1.0.bn2.num_batches_tracked' persistent=True
#             b_layer1_1_bn1_running_mean: BUFFER target='layer1.1.bn1.running_mean' persistent=True
#             b_layer1_1_bn1_running_var: BUFFER target='layer1.1.bn1.running_var' persistent=True
#             b_layer1_1_bn1_num_batches_tracked: BUFFER target='layer1.1.bn1.num_batches_tracked' persistent=True
#             b_layer1_1_bn2_running_mean: BUFFER target='layer1.1.bn2.running_mean' persistent=True
#             b_layer1_1_bn2_running_var: BUFFER target='layer1.1.bn2.running_var' persistent=True
#             b_layer1_1_bn2_num_batches_tracked: BUFFER target='layer1.1.bn2.num_batches_tracked' persistent=True
#             b_layer1_2_bn1_running_mean: BUFFER target='layer1.2.bn1.running_mean' persistent=True
#             b_layer1_2_bn1_running_var: BUFFER target='layer1.2.bn1.running_var' persistent=True
#             b_layer1_2_bn1_num_batches_tracked: BUFFER target='layer1.2.bn1.num_batches_tracked' persistent=True
#             b_layer1_2_bn2_running_mean: BUFFER target='layer1.2.bn2.running_mean' persistent=True
#             b_layer1_2_bn2_running_var: BUFFER target='layer1.2.bn2.running_var' persistent=True
#             b_layer1_2_bn2_num_batches_tracked: BUFFER target='layer1.2.bn2.num_batches_tracked' persistent=True
#             b_layer2_0_bn1_running_mean: BUFFER target='layer2.0.bn1.running_mean' persistent=True
#             b_layer2_0_bn1_running_var: BUFFER target='layer2.0.bn1.running_var' persistent=True
#             b_layer2_0_bn1_num_batches_tracked: BUFFER target='layer2.0.bn1.num_batches_tracked' persistent=True
#             b_layer2_0_bn2_running_mean: BUFFER target='layer2.0.bn2.running_mean' persistent=True
#             b_layer2_0_bn2_running_var: BUFFER target='layer2.0.bn2.running_var' persistent=True
#             b_layer2_0_bn2_num_batches_tracked: BUFFER target='layer2.0.bn2.num_batches_tracked' persistent=True
#             b_layer2_0_downsample_1_running_mean: BUFFER target='layer2.0.downsample.1.running_mean' persistent=True
#             b_layer2_0_downsample_1_running_var: BUFFER target='layer2.0.downsample.1.running_var' persistent=True
#             b_layer2_0_downsample_1_num_batches_tracked: BUFFER target='layer2.0.downsample.1.num_batches_tracked' persistent=True
#             b_layer2_1_bn1_running_mean: BUFFER target='layer2.1.bn1.running_mean' persistent=True
#             b_layer2_1_bn1_running_var: BUFFER target='layer2.1.bn1.running_var' persistent=True
#             b_layer2_1_bn1_num_batches_tracked: BUFFER target='layer2.1.bn1.num_batches_tracked' persistent=True
#             b_layer2_1_bn2_running_mean: BUFFER target='layer2.1.bn2.running_mean' persistent=True
#             b_layer2_1_bn2_running_var: BUFFER target='layer2.1.bn2.running_var' persistent=True
#             b_layer2_1_bn2_num_batches_tracked: BUFFER target='layer2.1.bn2.num_batches_tracked' persistent=True
#             b_layer2_2_bn1_running_mean: BUFFER target='layer2.2.bn1.running_mean' persistent=True
#             b_layer2_2_bn1_running_var: BUFFER target='layer2.2.bn1.running_var' persistent=True
#             b_layer2_2_bn1_num_batches_tracked: BUFFER target='layer2.2.bn1.num_batches_tracked' persistent=True
#             b_layer2_2_bn2_running_mean: BUFFER target='layer2.2.bn2.running_mean' persistent=True
#             b_layer2_2_bn2_running_var: BUFFER target='layer2.2.bn2.running_var' persistent=True
#             b_layer2_2_bn2_num_batches_tracked: BUFFER target='layer2.2.bn2.num_batches_tracked' persistent=True
#             b_layer2_3_bn1_running_mean: BUFFER target='layer2.3.bn1.running_mean' persistent=True
#             b_layer2_3_bn1_running_var: BUFFER target='layer2.3.bn1.running_var' persistent=True
#             b_layer2_3_bn1_num_batches_tracked: BUFFER target='layer2.3.bn1.num_batches_tracked' persistent=True
#             b_layer2_3_bn2_running_mean: BUFFER target='layer2.3.bn2.running_mean' persistent=True
#             b_layer2_3_bn2_running_var: BUFFER target='layer2.3.bn2.running_var' persistent=True
#             b_layer2_3_bn2_num_batches_tracked: BUFFER target='layer2.3.bn2.num_batches_tracked' persistent=True
#             b_layer3_0_bn1_running_mean: BUFFER target='layer3.0.bn1.running_mean' persistent=True
#             b_layer3_0_bn1_running_var: BUFFER target='layer3.0.bn1.running_var' persistent=True
#             b_layer3_0_bn1_num_batches_tracked: BUFFER target='layer3.0.bn1.num_batches_tracked' persistent=True
#             b_layer3_0_bn2_running_mean: BUFFER target='layer3.0.bn2.running_mean' persistent=True
#             b_layer3_0_bn2_running_var: BUFFER target='layer3.0.bn2.running_var' persistent=True
#             b_layer3_0_bn2_num_batches_tracked: BUFFER target='layer3.0.bn2.num_batches_tracked' persistent=True
#             b_layer3_0_downsample_1_running_mean: BUFFER target='layer3.0.downsample.1.running_mean' persistent=True
#             b_layer3_0_downsample_1_running_var: BUFFER target='layer3.0.downsample.1.running_var' persistent=True
#             b_layer3_0_downsample_1_num_batches_tracked: BUFFER target='layer3.0.downsample.1.num_batches_tracked' persistent=True
#             b_layer3_1_bn1_running_mean: BUFFER target='layer3.1.bn1.running_mean' persistent=True
#             b_layer3_1_bn1_running_var: BUFFER target='layer3.1.bn1.running_var' persistent=True
#             b_layer3_1_bn1_num_batches_tracked: BUFFER target='layer3.1.bn1.num_batches_tracked' persistent=True
#             b_layer3_1_bn2_running_mean: BUFFER target='layer3.1.bn2.running_mean' persistent=True
#             b_layer3_1_bn2_running_var: BUFFER target='layer3.1.bn2.running_var' persistent=True
#             b_layer3_1_bn2_num_batches_tracked: BUFFER target='layer3.1.bn2.num_batches_tracked' persistent=True
#             b_layer3_2_bn1_running_mean: BUFFER target='layer3.2.bn1.running_mean' persistent=True
#             b_layer3_2_bn1_running_var: BUFFER target='layer3.2.bn1.running_var' persistent=True
#             b_layer3_2_bn1_num_batches_tracked: BUFFER target='layer3.2.bn1.num_batches_tracked' persistent=True
#             b_layer3_2_bn2_running_mean: BUFFER target='layer3.2.bn2.running_mean' persistent=True
#             b_layer3_2_bn2_running_var: BUFFER target='layer3.2.bn2.running_var' persistent=True
#             b_layer3_2_bn2_num_batches_tracked: BUFFER target='layer3.2.bn2.num_batches_tracked' persistent=True
#             b_layer3_3_bn1_running_mean: BUFFER target='layer3.3.bn1.running_mean' persistent=True
#             b_layer3_3_bn1_running_var: BUFFER target='layer3.3.bn1.running_var' persistent=True
#             b_layer3_3_bn1_num_batches_tracked: BUFFER target='layer3.3.bn1.num_batches_tracked' persistent=True
#             b_layer3_3_bn2_running_mean: BUFFER target='layer3.3.bn2.running_mean' persistent=True
#             b_layer3_3_bn2_running_var: BUFFER target='layer3.3.bn2.running_var' persistent=True
#             b_layer3_3_bn2_num_batches_tracked: BUFFER target='layer3.3.bn2.num_batches_tracked' persistent=True
#             b_layer3_4_bn1_running_mean: BUFFER target='layer3.4.bn1.running_mean' persistent=True
#             b_layer3_4_bn1_running_var: BUFFER target='layer3.4.bn1.running_var' persistent=True
#             b_layer3_4_bn1_num_batches_tracked: BUFFER target='layer3.4.bn1.num_batches_tracked' persistent=True
#             b_layer3_4_bn2_running_mean: BUFFER target='layer3.4.bn2.running_mean' persistent=True
#             b_layer3_4_bn2_running_var: BUFFER target='layer3.4.bn2.running_var' persistent=True
#             b_layer3_4_bn2_num_batches_tracked: BUFFER target='layer3.4.bn2.num_batches_tracked' persistent=True
#             b_layer3_5_bn1_running_mean: BUFFER target='layer3.5.bn1.running_mean' persistent=True
#             b_layer3_5_bn1_running_var: BUFFER target='layer3.5.bn1.running_var' persistent=True
#             b_layer3_5_bn1_num_batches_tracked: BUFFER target='layer3.5.bn1.num_batches_tracked' persistent=True
#             b_layer3_5_bn2_running_mean: BUFFER target='layer3.5.bn2.running_mean' persistent=True
#             b_layer3_5_bn2_running_var: BUFFER target='layer3.5.bn2.running_var' persistent=True
#             b_layer3_5_bn2_num_batches_tracked: BUFFER target='layer3.5.bn2.num_batches_tracked' persistent=True
#             b_layer4_0_bn1_running_mean: BUFFER target='layer4.0.bn1.running_mean' persistent=True
#             b_layer4_0_bn1_running_var: BUFFER target='layer4.0.bn1.running_var' persistent=True
#             b_layer4_0_bn1_num_batches_tracked: BUFFER target='layer4.0.bn1.num_batches_tracked' persistent=True
#             b_layer4_0_bn2_running_mean: BUFFER target='layer4.0.bn2.running_mean' persistent=True
#             b_layer4_0_bn2_running_var: BUFFER target='layer4.0.bn2.running_var' persistent=True
#             b_layer4_0_bn2_num_batches_tracked: BUFFER target='layer4.0.bn2.num_batches_tracked' persistent=True
#             b_layer4_0_downsample_1_running_mean: BUFFER target='layer4.0.downsample.1.running_mean' persistent=True
#             b_layer4_0_downsample_1_running_var: BUFFER target='layer4.0.downsample.1.running_var' persistent=True
#             b_layer4_0_downsample_1_num_batches_tracked: BUFFER target='layer4.0.downsample.1.num_batches_tracked' persistent=True
#             b_layer4_1_bn1_running_mean: BUFFER target='layer4.1.bn1.running_mean' persistent=True
#             b_layer4_1_bn1_running_var: BUFFER target='layer4.1.bn1.running_var' persistent=True
#             b_layer4_1_bn1_num_batches_tracked: BUFFER target='layer4.1.bn1.num_batches_tracked' persistent=True
#             b_layer4_1_bn2_running_mean: BUFFER target='layer4.1.bn2.running_mean' persistent=True
#             b_layer4_1_bn2_running_var: BUFFER target='layer4.1.bn2.running_var' persistent=True
#             b_layer4_1_bn2_num_batches_tracked: BUFFER target='layer4.1.bn2.num_batches_tracked' persistent=True
#             b_layer4_2_bn1_running_mean: BUFFER target='layer4.2.bn1.running_mean' persistent=True
#             b_layer4_2_bn1_running_var: BUFFER target='layer4.2.bn1.running_var' persistent=True
#             b_layer4_2_bn1_num_batches_tracked: BUFFER target='layer4.2.bn1.num_batches_tracked' persistent=True
#             b_layer4_2_bn2_running_mean: BUFFER target='layer4.2.bn2.running_mean' persistent=True
#             b_layer4_2_bn2_running_var: BUFFER target='layer4.2.bn2.running_var' persistent=True
#             b_layer4_2_bn2_num_batches_tracked: BUFFER target='layer4.2.bn2.num_batches_tracked' persistent=True
#             b_fc_1_running_mean: BUFFER target='fc.1.running_mean' persistent=True
#             b_fc_1_running_var: BUFFER target='fc.1.running_var' persistent=True
#             b_fc_1_num_batches_tracked: BUFFER target='fc.1.num_batches_tracked' persistent=True
#             b_fc_4_running_mean: BUFFER target='fc.4.running_mean' persistent=True
#             b_fc_4_running_var: BUFFER target='fc.4.running_var' persistent=True
#             b_fc_4_num_batches_tracked: BUFFER target='fc.4.num_batches_tracked' persistent=True
#             x: USER_INPUT
#
#             # outputs
#             linear_2: USER_OUTPUT
#
#         Range constraints: {s77: VR[0, 65535]}
#
# )

# %% [markdown]
# ## Testing the model

# %%
import onnx

# Load the ONNX model
loaded_model = onnx.load("model_test.onnx")

# Check that the IR is well formed
onnx.checker.check_model(loaded_model)

# Print a human readable representation of the graph
print(onnx.helper.printable_graph(loaded_model.graph))

print(loaded_model.graph.input[0].type.tensor_type.shape)
# Out:
# graph main_graph (
#   %x[FLOAT, batch_sizex6x310x310]
# ) initializers (
#   %fc.0.bias[FLOAT, 256]
#   %fc.3.bias[FLOAT, 128]
#   %fc.7.weight[FLOAT, 2x128]
#   %fc.7.bias[FLOAT, 2]
#   %conv1.weight[FLOAT, 64x6x7x7]
#   %layer1.0.conv1.weight[FLOAT, 64x64x3x3]
#   %layer1.0.conv2.weight[FLOAT, 64x64x3x3]
#   %layer1.1.conv1.weight[FLOAT, 64x64x3x3]
#   %layer1.1.conv2.weight[FLOAT, 64x64x3x3]
#   %layer1.2.conv1.weight[FLOAT, 64x64x3x3]
#   %layer1.2.conv2.weight[FLOAT, 64x64x3x3]
#   %layer2.0.conv1.weight[FLOAT, 128x64x3x3]
#   %layer2.0.conv2.weight[FLOAT, 128x128x3x3]
#   %layer2.0.downsample.0.weight[FLOAT, 128x64x1x1]
#   %layer2.1.conv1.weight[FLOAT, 128x128x3x3]
#   %layer2.1.conv2.weight[FLOAT, 128x128x3x3]
#   %layer2.2.conv1.weight[FLOAT, 128x128x3x3]
#   %layer2.2.conv2.weight[FLOAT, 128x128x3x3]
#   %layer2.3.conv1.weight[FLOAT, 128x128x3x3]
#   %layer2.3.conv2.weight[FLOAT, 128x128x3x3]
#   %layer3.0.conv1.weight[FLOAT, 256x128x3x3]
#   %layer3.0.conv2.weight[FLOAT, 256x256x3x3]
#   %layer3.0.downsample.0.weight[FLOAT, 256x128x1x1]
#   %layer3.1.conv1.weight[FLOAT, 256x256x3x3]
#   %layer3.1.conv2.weight[FLOAT, 256x256x3x3]
#   %layer3.2.conv1.weight[FLOAT, 256x256x3x3]
#   %layer3.2.conv2.weight[FLOAT, 256x256x3x3]
#   %layer3.3.conv1.weight[FLOAT, 256x256x3x3]
#   %layer3.3.conv2.weight[FLOAT, 256x256x3x3]
#   %layer3.4.conv1.weight[FLOAT, 256x256x3x3]
#   %layer3.4.conv2.weight[FLOAT, 256x256x3x3]
#   %layer3.5.conv1.weight[FLOAT, 256x256x3x3]
#   %layer3.5.conv2.weight[FLOAT, 256x256x3x3]
#   %layer4.0.conv1.weight[FLOAT, 512x256x3x3]
#   %layer4.0.conv2.weight[FLOAT, 512x512x3x3]
#   %layer4.0.downsample.0.weight[FLOAT, 512x256x1x1]
#   %layer4.1.conv1.weight[FLOAT, 512x512x3x3]
#   %layer4.1.conv2.weight[FLOAT, 512x512x3x3]
#   %layer4.2.conv1.weight[FLOAT, 512x512x3x3]
#   %layer4.2.conv2.weight[FLOAT, 512x512x3x3]
#   %fc.0.weight[FLOAT, 256x512]
#   %fc.3.weight[FLOAT, 128x256]
#   %val_337[INT64, 2]
#   %x_bias[FLOAT, 64]
#   %max_pool2d_bias[FLOAT, 64]
#   %relu_1_bias[FLOAT, 64]
#   %relu_2_bias[FLOAT, 64]
#   %relu_3_bias[FLOAT, 64]
#   %relu_4_bias[FLOAT, 64]
#   %relu_5_bias[FLOAT, 64]
#   %relu_6_bias[FLOAT, 128]
#   %relu_7_bias[FLOAT, 128]
#   %relu_8_bias[FLOAT, 128]
#   %relu_9_bias[FLOAT, 128]
#   %relu_10_bias[FLOAT, 128]
#   %relu_11_bias[FLOAT, 128]
#   %relu_12_bias[FLOAT, 128]
#   %relu_13_bias[FLOAT, 128]
#   %relu_14_bias[FLOAT, 256]
#   %relu_15_bias[FLOAT, 256]
#   %relu_16_bias[FLOAT, 256]
#   %relu_17_bias[FLOAT, 256]
#   %relu_18_bias[FLOAT, 256]
#   %relu_19_bias[FLOAT, 256]
#   %relu_20_bias[FLOAT, 256]
#   %relu_21_bias[FLOAT, 256]
#   %relu_22_bias[FLOAT, 256]
#   %relu_23_bias[FLOAT, 256]
#   %relu_24_bias[FLOAT, 256]
#   %relu_25_bias[FLOAT, 256]
#   %relu_26_bias[FLOAT, 512]
#   %relu_27_bias[FLOAT, 512]
#   %relu_28_bias[FLOAT, 512]
#   %relu_29_bias[FLOAT, 512]
#   %relu_30_bias[FLOAT, 512]
#   %relu_31_bias[FLOAT, 512]
#   %val_340[INT64, 1]
# ) {
#   %val_0 = Shape[end = 1, start = 0](%x)
#   %getitem = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [3, 3, 3, 3], strides = [2, 2]](%x, %conv1.weight, %x_bias)
#   %relu = Relu(%getitem)
#   %max_pool2d = MaxPool[auto_pad = 'NOTSET', ceil_mode = 0, dilations = [1, 1], kernel_shape = [3, 3], pads = [1, 1, 1, 1], storage_order = 0, strides = [2, 2]](%relu)
#   %getitem_3 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%max_pool2d, %layer1.0.conv1.weight, %max_pool2d_bias)
#   %relu_1 = Relu(%getitem_3)
#   %getitem_6 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_1, %layer1.0.conv2.weight, %relu_1_bias)
#   %add_65 = Add(%getitem_6, %max_pool2d)
#   %relu_2 = Relu(%add_65)
#   %getitem_9 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_2, %layer1.1.conv1.weight, %relu_2_bias)
#   %relu_3 = Relu(%getitem_9)
#   %getitem_12 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_3, %layer1.1.conv2.weight, %relu_3_bias)
#   %add_121 = Add(%getitem_12, %relu_2)
#   %relu_4 = Relu(%add_121)
#   %getitem_15 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_4, %layer1.2.conv1.weight, %relu_4_bias)
#   %relu_5 = Relu(%getitem_15)
#   %getitem_18 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_5, %layer1.2.conv2.weight, %relu_5_bias)
#   %add_177 = Add(%getitem_18, %relu_4)
#   %relu_6 = Relu(%add_177)
#   %getitem_21 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [2, 2]](%relu_6, %layer2.0.conv1.weight, %relu_6_bias)
#   %relu_7 = Relu(%getitem_21)
#   %getitem_24 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_7, %layer2.0.conv2.weight, %relu_7_bias)
#   %getitem_27 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [2, 2]](%relu_6, %layer2.0.downsample.0.weight, %relu_6_bias)
#   %add_243 = Add(%getitem_24, %getitem_27)
#   %relu_8 = Relu(%add_243)
#   %getitem_30 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_8, %layer2.1.conv1.weight, %relu_8_bias)
#   %relu_9 = Relu(%getitem_30)
#   %getitem_33 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_9, %layer2.1.conv2.weight, %relu_9_bias)
#   %add_299 = Add(%getitem_33, %relu_8)
#   %relu_10 = Relu(%add_299)
#   %getitem_36 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_10, %layer2.2.conv1.weight, %relu_10_bias)
#   %relu_11 = Relu(%getitem_36)
#   %getitem_39 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_11, %layer2.2.conv2.weight, %relu_11_bias)
#   %add_355 = Add(%getitem_39, %relu_10)
#   %relu_12 = Relu(%add_355)
#   %getitem_42 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_12, %layer2.3.conv1.weight, %relu_12_bias)
#   %relu_13 = Relu(%getitem_42)
#   %getitem_45 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_13, %layer2.3.conv2.weight, %relu_13_bias)
#   %add_411 = Add(%getitem_45, %relu_12)
#   %relu_14 = Relu(%add_411)
#   %getitem_48 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [2, 2]](%relu_14, %layer3.0.conv1.weight, %relu_14_bias)
#   %relu_15 = Relu(%getitem_48)
#   %getitem_51 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_15, %layer3.0.conv2.weight, %relu_15_bias)
#   %getitem_54 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [2, 2]](%relu_14, %layer3.0.downsample.0.weight, %relu_14_bias)
#   %add_477 = Add(%getitem_51, %getitem_54)
#   %relu_16 = Relu(%add_477)
#   %getitem_57 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_16, %layer3.1.conv1.weight, %relu_16_bias)
#   %relu_17 = Relu(%getitem_57)
#   %getitem_60 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_17, %layer3.1.conv2.weight, %relu_17_bias)
#   %add_533 = Add(%getitem_60, %relu_16)
#   %relu_18 = Relu(%add_533)
#   %getitem_63 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_18, %layer3.2.conv1.weight, %relu_18_bias)
#   %relu_19 = Relu(%getitem_63)
#   %getitem_66 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_19, %layer3.2.conv2.weight, %relu_19_bias)
#   %add_589 = Add(%getitem_66, %relu_18)
#   %relu_20 = Relu(%add_589)
#   %getitem_69 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_20, %layer3.3.conv1.weight, %relu_20_bias)
#   %relu_21 = Relu(%getitem_69)
#   %getitem_72 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_21, %layer3.3.conv2.weight, %relu_21_bias)
#   %add_645 = Add(%getitem_72, %relu_20)
#   %relu_22 = Relu(%add_645)
#   %getitem_75 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_22, %layer3.4.conv1.weight, %relu_22_bias)
#   %relu_23 = Relu(%getitem_75)
#   %getitem_78 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_23, %layer3.4.conv2.weight, %relu_23_bias)
#   %add_701 = Add(%getitem_78, %relu_22)
#   %relu_24 = Relu(%add_701)
#   %getitem_81 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_24, %layer3.5.conv1.weight, %relu_24_bias)
#   %relu_25 = Relu(%getitem_81)
#   %getitem_84 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_25, %layer3.5.conv2.weight, %relu_25_bias)
#   %add_757 = Add(%getitem_84, %relu_24)
#   %relu_26 = Relu(%add_757)
#   %getitem_87 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [2, 2]](%relu_26, %layer4.0.conv1.weight, %relu_26_bias)
#   %relu_27 = Relu(%getitem_87)
#   %getitem_90 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_27, %layer4.0.conv2.weight, %relu_27_bias)
#   %getitem_93 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [2, 2]](%relu_26, %layer4.0.downsample.0.weight, %relu_26_bias)
#   %add_823 = Add(%getitem_90, %getitem_93)
#   %relu_28 = Relu(%add_823)
#   %getitem_96 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_28, %layer4.1.conv1.weight, %relu_28_bias)
#   %relu_29 = Relu(%getitem_96)
#   %getitem_99 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_29, %layer4.1.conv2.weight, %relu_29_bias)
#   %add_879 = Add(%getitem_99, %relu_28)
#   %relu_30 = Relu(%add_879)
#   %getitem_102 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_30, %layer4.2.conv1.weight, %relu_30_bias)
#   %relu_31 = Relu(%getitem_102)
#   %getitem_105 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [1, 1]](%relu_31, %layer4.2.conv2.weight, %relu_31_bias)
#   %add_935 = Add(%getitem_105, %relu_30)
#   %relu_32 = Relu(%add_935)
#   %mean = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%relu_32, %val_337)
#   %val_341 = Concat[axis = 0](%val_0, %val_340)
#   %view = Reshape[allowzero = 1](%mean, %val_341)
#   %getitem_108 = Gemm[alpha = 1, beta = 1, transA = 0, transB = 1](%view, %fc.0.weight, %fc.0.bias)
#   %leaky_relu = LeakyRelu[alpha = 0.00999999977648258](%getitem_108)
#   %getitem_111 = Gemm[alpha = 1, beta = 1, transA = 0, transB = 1](%leaky_relu, %fc.3.weight, %fc.3.bias)
#   %leaky_relu_1 = LeakyRelu[alpha = 0.00999999977648258](%getitem_111)
#   %linear = Gemm[alpha = 1, beta = 1, transA = 0, transB = 1](%leaky_relu_1, %fc.7.weight, %fc.7.bias)
#   return %linear
# }
# dim {
#   dim_param: "batch_size"
# }
# dim {
#   dim_value: 6
# }
# dim {
#   dim_value: 310
# }
# dim {
#   dim_value: 310
# }

# %%
import onnx
from onnx import numpy_helper
import onnxruntime as ort
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import average_precision_score, precision_recall_curve

onnx_path_in = "model_test.onnx"
onnx_path_out = "model_v5_patched.onnx"

model = onnx.load(onnx_path_in)

# patched = False

# for node in model.graph.node:
#     if node.op_type == "Reshape":
#         shape_name = node.input[1]   # second input is the shape tensor

#         for i, init in enumerate(model.graph.initializer):
#             if init.name == shape_name:
#                 arr = numpy_helper.to_array(init)

#                 print(f"Found Reshape shape initializer: {shape_name}")
#                 print("Original shape:", arr)

#                 if len(arr) == 2 and arr[0] == 1:
#                     arr[0] = -1   # ✅ make batch dimension dynamic
#                     new_init = numpy_helper.from_array(arr.astype(np.int64), name=shape_name)
#                     model.graph.initializer[i].CopyFrom(new_init)

#                     print("✅ Patched shape to:", arr)
#                     patched = True
#                 break

# if not patched:
#     print("⚠️ No static [1, N] reshape found. Model may already be dynamic.")

# onnx.save(model, onnx_path_out)
# print(f"\n✅ Saved patched ONNX model as: {onnx_path_out}")


# ---------- 2) CREATE ONNX RUNTIME SESSION ----------
ort_session = ort.InferenceSession(
    onnx_path_in,
    providers=["CUDAExecutionProvider", "CPUExecutionProvider"]
)

input_name = ort_session.get_inputs()[0].name
output_name = ort_session.get_outputs()[0].name

print("ONNX Input Name :", input_name)
print("ONNX Output Name:", output_name)

# ---------- 3) RUN INFERENCE ON TEST LOADER (BATCHED, e.g. batch_size=10) ----------
all_probs = []
all_labels = []

for images, labels in test_loader:
    images_np = images.cpu().numpy()   # (B, 6, 310, 310)
    labels_np = labels.cpu().numpy()

    outputs = ort_session.run(
        [output_name],
        {input_name: images_np}
    )[0]  # (B, 2)

    # Softmax 
    exp_logits = np.exp(outputs)
    probs = exp_logits / exp_logits.sum(axis=1, keepdims=True)
    probs_pos = probs[:, 1]  # positive class

    all_probs.extend(probs_pos)
    all_labels.extend(labels_np)

all_probs = np.array(all_probs)
all_labels = np.array(all_labels)

# ---------- 4) METRICS & PLOT ----------
auc_pr = average_precision_score(all_labels, all_probs)
print(f"\n✅ AUC-PR (ONNX, batched): {auc_pr:.4f}")

precision, recall, thresholds = precision_recall_curve(all_labels, all_probs)

plt.figure()
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision-Recall Curve (AUC = {auc_pr:.4f})")
plt.grid(True)
plt.show()

print("\nLabels distribution:", np.bincount(all_labels.astype(int)))
print("Probabilities min/max:", all_probs.min(), all_probs.max())
print("Total samples:", len(all_probs))
# Out:
# ONNX Input Name : x
# ONNX Output Name: linear
#
# ✅ AUC-PR (ONNX, batched): 0.5622
# Labels distribution: [78 47]
# Probabilities min/max: 0.06443181 0.13431087
# Total samples: 125
