# %% [markdown]
# # Machine Learning Final Proyect - Nopales
# ### David Villanueva Guzmán - U6110618
# ### Alvaro Cámara Guerra - U6110583

# %% [markdown]
# ### Import Required Libraries

# %%
import sys
print(sys.executable)
import torch
print(torch.__version__)
print(torch.cuda.is_available())

# import torch.multiprocessing as mp
# mp.set_start_method("spawn", force=True)
# Out:
# c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Scripts\python.exe
# 2.10.0.dev20251210+cu128
# True

# %%
import torch, kornia, platform

print("Torch:", torch.__version__)
print("CUDA version in torch:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")
print("Kornia:", kornia.__version__)
print("Python:", platform.python_version())
# Out:
# Torch: 2.10.0.dev20251210+cu128
# CUDA version in torch: 12.8
# CUDA available: True
# Device: NVIDIA GeForce RTX 5060 Laptop GPU
# Kornia: 0.8.2
# Python: 3.11.9

# %%
# !nvidia-smi
# Out:
# Thu Dec 11 19:46:25 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 573.24                 Driver Version: 573.24         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   70C    P2             47W /   85W |    6054MiB /   8151MiB |     52%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            3164    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A            9860      C   ...in\versions\3.11.9\python.exe      N/A      |
# |    0   N/A  N/A           29024      C   ...in\versions\3.11.9\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install "numpy<2.0" --force-reinstall
# !pip install kornia
import warnings
warnings.filterwarnings("ignore")

# %%
# For data processing
# !pip install pandas
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Integrate google drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ### Load the Dataset
# Milan Dataset --

# %%
# Import Multiclass and Binary annotations
file_path_MC = r"C:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\Labs\FP\annotations_multiclass.csv"
file_path_BIN = r"C:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\Labs\FP\annotations_binary.csv"
# file_path_MC = '/content/drive/MyDrive/IFRoS/ML Labs/MILAN-dataset/annotations_multiclass.csv'
# file_path_BIN = '/content/drive/MyDrive/IFRoS/ML Labs/MILAN-dataset/annotations_binary.csv'

# Get dataframes of annotations
df_MC = pd.read_csv(file_path_MC)
df_MC.drop(columns=["Unnamed: 2", "Unnamed: 3"], inplace=True)

print(df_MC.head(10))
# Out:
#   file_prefix printError_physicalDefect
# 0  001_516_01                       0_0
# 1  001_516_02                       0_1
# 2  001_516_03                       0_0
# 3  001_516_04                       0_0
# 4  001_516_05                       0_0
# 5  001_516_06                       0_0
# 6  001_516_07                       0_0
# 7  001_516_08                       0_0
# 8  001_516_09                       0_0
# 9  001_516_10                       1_0

# %% [markdown]
# #### Data Preprocessing

# %%
mapping = {
    "0_0": 0,
    "0_1": 1,
    "1_0": 2,
    "1_1": 3
}

df_MC["printError_physicalDefect_int"] = df_MC["printError_physicalDefect"].map(mapping)

# Count occurrences of each class
print_counts = df_MC["printError_physicalDefect_int"].value_counts().sort_index()

# Create the figure
fig, ax = plt.subplots(figsize=(7, 5))

# Define x positions for side-by-side bars
x = range(len(print_counts))  # same class positions (e.g. 0 and 1)
width = 0.5  # bar width

# Plot bars
bars1 = ax.bar([i - width/2 for i in x], print_counts, width, color='#1f77b4', alpha=0.8)

# Add text labels on top of bars
for bar in bars1:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, height + 10, f'{int(height)}',
            ha='center', va='bottom', fontsize=9, fontweight='bold')

# Customize axes
ax.set_xlabel("Class")
ax.set_ylabel("Counts")
ax.set_title("Distribution of Print and Physical Errors")
ax.set_xticks(x)
ax.set_xticklabels(print_counts.index)  # e.g. 0 and 1 only
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

print(df_MC)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#      file_prefix printError_physicalDefect  printError_physicalDefect_int
# 0     001_516_01                       0_0                              0
# 1     001_516_02                       0_1                              1
# 2     001_516_03                       0_0                              0
# 3     001_516_04                       0_0                              0
# 4     001_516_05                       0_0                              0
# ...          ...                       ...                            ...
# 1375  002_100_11                       0_1                              1
# 1376  002_100_12                       0_0                              0
# 1377  002_100_13                       0_0                              0
# 1378  002_100_14                       0_0                              0
# 1379  002_100_15                       1_0                              2
#
# [1380 rows x 3 columns]

# %% [markdown]
# ### Binary annotations

# %%
# Lista de strings a buscar en el nombre de la imagen

# Filtrar solo filas donde la segunda columna sea exactamente '0_0'
df_MC["binary"] = (df_MC["printError_physicalDefect_int"] != 0).astype(int)

# Count occurrences of each class
print_counts = df_MC["binary"].value_counts().sort_index()

# Create the figure
fig, ax = plt.subplots(figsize=(7, 5))

# Define x positions for side-by-side bars
x = range(len(print_counts))  # same class positions (e.g. 0 and 1)
width = 0.5  # bar width

# Plot bars
bars1 = ax.bar([i - width/2 for i in x], print_counts, width, label='Print Error', color='#1f77b4', alpha=0.8)

# Add text labels on top of bars
for bar in bars1:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, height + 10, f'{int(height)}',
            ha='center', va='bottom', fontsize=9, fontweight='bold')

# Customize axes
ax.set_xlabel("Class")
ax.set_ylabel("Counts")
ax.set_title("Distribution of Print and Physical Errors")
ax.set_xticks(x)
ax.set_xticklabels(print_counts.index)  # e.g. 0 and 1 only
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data reduction

# %% [markdown]
# #### Unzip images inside google drive

# %%
extract_path = r"C:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\Labs\FP\drive-download-20251113T114126Z-1-001\arrays"
# extract_path = '/content/drive/MyDrive/IFRoS/ML Labs/MILAN-dataset/arrays'

# %% [markdown]
# #### Define NPYImageDataset class to load the images

# %%
# import os
# from torch.utils.data import Dataset
# import numpy as np

# class NPYImageDataset(Dataset):
#     def __init__(self, root_dir, names: list[str], transform=None):
#         self.root_dir = root_dir
#         self.files = [f for f in os.listdir(root_dir) if f in names]
#         self.transform = transform

#     def __len__(self):
#         return len(self.files)

#     def __getitem__(self, idx):
#         path = os.path.join(self.root_dir, self.files[idx])
#         img = np.load(path)  # shape (H, W, C)
#         img = torch.from_numpy(img).permute(2, 0, 1).float()  # (C, H, W)
#         if self.transform:
#           img = self.transform(img)
#         return img

# %%
import os
import torch
from torch.utils.data import Dataset
import numpy as np

class NPYImageDataset(Dataset):
    def __init__(self, root_dir, names, labels, transform=None):
        """
        root_dir : Folder with .npy files
        names    : List like ['003_045_012', '002_047_12', ...]
        labels   : Array-like with class labels aligned with 'names'
        transform: torchvision transform
        """
        self.root_dir = root_dir
        self.names = names
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.names)

    def __getitem__(self, idx):
        name = self.names[idx]
        filename = f"{name}.npy"
        path = os.path.join(self.root_dir, filename)

        # Debugging: Print the path and check if it exists and is a file
        # print(f"Attempting to load: {path}")
        # if not os.path.exists(path):
        #     raise FileNotFoundError(f"File not found: {path}")
        # if not os.path.isfile(path):
        #     raise IOError(f"Path is not a file: {path}")
        ###

        if not os.path.exists(path):
            raise FileNotFoundError(f"File not found: {path}")

        img = np.load(path)                          # (H, W, C)
        img = torch.from_numpy(img).permute(2, 0, 1).float()  # (C, H, W)

        if self.transform:
            img = self.transform(img)

        label = torch.tensor(self.labels[idx]).long()

        return img, label

# %%
all_names = df_MC["file_prefix"].values      # list of .npy filenames
all_labels = df_MC["binary"].values       # 0 / 1 labels

# %%
from sklearn.model_selection import train_test_split

# All indices as ints
indices = np.arange(len(all_names))

# Train set
train_idx, temp_idx = train_test_split(
    indices,
    test_size=0.30,
    stratify=all_labels,
    random_state=42
)

# Validation and test set
temp_labels = all_labels[temp_idx]
val_idx, test_idx = train_test_split(
    temp_idx,
    test_size=0.30,
    stratify=temp_labels,
    random_state=42
)

# %%
# Apply split to names and labels
train_names = all_names[train_idx]
val_names   = all_names[val_idx]
test_names  = all_names[test_idx]

train_labels = all_labels[train_idx]
val_labels   = all_labels[val_idx]
test_labels  = all_labels[test_idx]

# %% [markdown]
# #### Data transforming

# %%
# For Data Transformation
import torchvision.transforms.v2 as transforms

transform = transforms.Compose([
    # To tensor
    transforms.ToImage(),

    # Scale the images
    transforms.Lambda(lambda x: x / 255.0),  # manually scale to [0,1]
    transforms.ToDtype(torch.float32),        # ensure float32 type

    # Normalize each channel
    transforms.Normalize(mean=[0.5]*6, std=[0.5]*6)
 ])

# %%
import torchvision.transforms.v2 as transforms
import torch
import kornia.augmentation as K
import kornia

def scale_image(x):
    return x / 255.0

train_transform = transforms.Compose([
    # Input comes as (C,H,W) torch tensor from NPY
    # Scale to [0,1]
    transforms.Lambda(scale_image),
    transforms.ToDtype(torch.float32),

    # Normalize all 6 channels
    transforms.Normalize(
        mean=[0.5]*6,
        std=[0.5]*6
    )
])

val_transform = transforms.Compose([
    transforms.Lambda(scale_image),
    transforms.ToDtype(torch.float32),

    transforms.Normalize(
        mean=[0.5]*6,
        std=[0.5]*6
    )
])

test_transform = transforms.Compose([
    transforms.Lambda(scale_image),
    transforms.ToDtype(torch.float32),

    transforms.Normalize(
        mean=[0.5]*6,
        std=[0.5]*6
    )
])


kornia_augment = torch.nn.Sequential(
    # --- Moderate geometric jitter ---
    K.RandomHorizontalFlip(p=0.4),
    K.RandomRotation(degrees=3.0, p=0.3),
    K.RandomAffine(
        degrees=0,
        translate=(0.04, 0.04),
        scale=(0.96, 1.04),
        p=0.35
    ),

    # --- Stronger photometric jitter ---
    K.RandomBrightness(brightness=(0.90, 1.10), p=0.4),
    K.RandomContrast(contrast=(0.85, 1.15), p=0.4),
    # K.RandomGamma(gamma=(0.8, 1.3), p=0.3),

    # --- Light noise and blur ---
    K.RandomGaussianNoise(mean=0, std=0.01, p=0.3),
    K.RandomGaussianBlur(kernel_size=(3,3), sigma=(0.05, 0.25), p=0.2),

    # --- KEY regularizer: Random erasing ---
    K.RandomErasing(scale=(0.005, 0.05), ratio=(0.3, 3.3), p=0.35),
)

# %%
train_dataset = NPYImageDataset(
    root_dir=extract_path,
    names=train_names,
    labels=train_labels,
    transform=train_transform
)

val_dataset = NPYImageDataset(
    root_dir=extract_path,
    names=val_names,
    labels=val_labels,
    transform=val_transform
)

test_dataset = NPYImageDataset(
    root_dir=extract_path,
    names=test_names,
    labels=test_labels,
    transform=val_transform
)

# %%
batch_size = 8

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0, # Changed from 4 to 0 for debugging
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0, # Changed from 4 to 0 for debugging
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0, # Changed from commented out to 0 for debugging
    pin_memory=True
)

# %% [markdown]
# #### Visuazlie a sample

# %%
# Visualize ONE sample directly from the DATASET (no batching issues)

import matplotlib.pyplot as plt

# Get one raw sample from the dataset
img, label = train_dataset[0]
print("label = ",label)
img = kornia_augment(img)

print("Type:", type(img))
print("Shape:", img.shape)      # Expected: (1, 6, H, W)
print("Label:", label)

# Undo normalization for visualization
# Since you used: Normalize(mean=[0.5]*6, std=[0.5]*6)
img_vis = img[0, :3] * 0.5 + 0.5   # Take first 3 channels from the first image in batch as pseudo-RGB
img_vis = img_vis.clamp(0, 1)  # Safety clamp

# Show image
plt.imshow(img_vis.permute(1, 2, 0))
plt.title("Train Sample (Pseudo-RGB)")
plt.axis("off")
plt.show()
# Out:
# label =  tensor(1)
# Type: <class 'torch.Tensor'>
# Shape: torch.Size([1, 6, 310, 310])
# Label: tensor(1)

# %% [markdown]
# ### Data splitting using multiclass

# %%
# def count_labels(loader):
#     count_0 = 0
#     count_1 = 0

#     for _, labels in loader:
#         labels = labels.cpu().numpy()
#         count_0 += (labels == 0).sum()
#         count_1 += (labels == 1).sum()

#     total = count_0 + count_1
#     perc_0 = 100 * count_0 / total
#     perc_1 = 100 * count_1 / total

#     return count_0, count_1, perc_0, perc_1


# # Train
# c0, c1, p0, p1 = count_labels(train_loader)
# print(f"\nTrain -> Class 0: {c0} ({p0:.2f}%) | Class 1: {c1} ({p1:.2f}%)")

# # Validation
# c0, c1, p0, p1 = count_labels(val_loader)
# print(f"Val   -> Class 0: {c0} ({p0:.2f}%) | Class 1: {c1} ({p1:.2f}%)")

# # Test
# c0, c1, p0, p1 = count_labels(test_loader)
# print(f"Test  -> Class 0: {c0} ({p0:.2f}%) | Class 1: {c1} ({p1:.2f}%)")

# %% [markdown]
# ### Setting the Device

# %% [markdown]
# ### Define structure

# %%
import torch
import torch.nn as nn
import timm

def make_efficientnet_b2_6ch(dropout_rate=0.3, num_classes=2, pretrained=True):
    """
    EfficientNet-B2 modified for:
    - 6-channel input
    - custom dropout classifier head
    - binary classification
    """

    # Load pretrained model from timm
    model = timm.create_model("efficientnet_b2", pretrained=pretrained)

    # -------------------------
    # 1) Modify first conv to accept 6 channels
    # -------------------------
    old_conv = model.conv_stem  # original conv
    old_w = old_conv.weight     # shape [32, 3, 3, 3]

    new_conv = nn.Conv2d(
        in_channels=6,
        out_channels=old_conv.out_channels,
        kernel_size=old_conv.kernel_size,
        stride=old_conv.stride,
        padding=old_conv.padding,
        bias=False,
    )

    # Repeat pretrained weights to initialize the new 6-channel conv
    with torch.no_grad():
        new_conv.weight[:, :3] = old_w
        new_conv.weight[:, 3:] = old_w.clone()

    model.conv_stem = new_conv

    # -------------------------
    # 2) Replace classifier head
    # EfficientNet-B2 default head is:
    # classifier = Linear(1408, 1000)
    # -------------------------
    in_features = model.classifier.in_features

    model.classifier = nn.Sequential(
        nn.Linear(in_features, 512),
        nn.BatchNorm1d(512),
        nn.Mish(),
        nn.Dropout(dropout_rate),

        nn.Linear(512, 256),
        nn.BatchNorm1d(256),
        nn.Mish(),
        nn.Dropout(dropout_rate + 0.1),

        nn.Linear(256, num_classes)
    )

    return model

dropout_rate = 0.3
num_classes = 2

imported_model = make_efficientnet_b2_6ch(
    dropout_rate=dropout_rate,
    num_classes=num_classes,
    pretrained=True
)

layer_groups = {
    "stem":   ["conv_stem", "bn1"],
    "block1": ["blocks.0"],
    "block2": ["blocks.1"],
    "block3": ["blocks.2"],
    "block4": ["blocks.3"],
    "block5": ["blocks.4"],
    "block6": ["blocks.5"],
    "block7": ["blocks.6"],
    "head":   ["classifier"],
}

# %% [markdown]
# ### Train the model

# %% [markdown]
# ### Train and Validation Fucntions

# %%
import torch, kornia, platform
# Define device foor runtime
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("Torch:", torch.__version__)
print("CUDA version in torch:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")
print("Kornia:", kornia.__version__)
print("Python:", platform.python_version())
print(device)
# Out:
# Torch: 2.10.0.dev20251210+cu128
# CUDA version in torch: 12.8
# CUDA available: True
# Device: NVIDIA GeForce RTX 5060 Laptop GPU
# Kornia: 0.8.2
# Python: 3.11.9
# cuda

# %%
#train function
from sklearn.metrics import average_precision_score, f1_score
import torch.nn.functional as F
import numpy as np

def Train(model, train_loader, optimizer):
    model.train()

    running_loss = 0.0
    all_probs = []
    all_labels = []

    for i, (images, labels) in enumerate(train_loader):


        # Move augmented batch to GPU for training
        images = images.to(device)
        labels = labels.to(device)

        # Data augmentation with kornia in the GPU 
        images = kornia_augment(images)

        # Initialize backpropagation and optimization
        optimizer.zero_grad()

        # Forward pass
        outputs = model(images)

        # Backpropagation
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Convert logits → probability of positive class
        probs = F.softmax(outputs, dim=1)[:, 1]

        all_probs.extend(probs.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

    # Compute AUC-PR for the full epoch
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)

    # AUC-PR
    if len(np.unique(all_labels)) > 1:
        auc_pr = average_precision_score(all_labels, all_probs)
    else:
        auc_pr = 0.0

    # Average loss
    avg_loss = running_loss / len(train_loader)

    # Binary predictions for F1
    preds = (all_probs >= 0.5).astype(int)

    # F1-score
    f1 = f1_score(all_labels, preds)

    return avg_loss, auc_pr, f1

#validation function
def Validate(model, val_loader):
    model.eval()

    running_loss = 0.0
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            running_loss += loss.item()

            # Convert logits → probability of positive class
            probs = F.softmax(outputs, dim=1)[:, 1]

            all_probs.extend(probs.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)

    auc_pr = average_precision_score(all_labels, all_probs)
    avg_loss = running_loss / len(val_loader)

    # # Binary predictions for F1
    # preds = (all_probs >= 0.5).astype(int)

    # # F1-score
    # f1 = f1_score(all_labels, preds)

    # ----- FIND BEST THRESHOLD FOR F1 -----
    thresholds = np.linspace(0.0, 1.0, 200)
    f1_scores = [
        f1_score(all_labels, (all_probs >= t).astype(int)) 
        for t in thresholds
    ]
    best_idx = int(np.argmax(f1_scores))
    best_threshold = float(thresholds[best_idx])
    best_f1 = float(f1_scores[best_idx])

    return avg_loss, auc_pr, best_f1, best_threshold

# %%
import os
import numpy as np

bad_files = []
good = 0

for f in os.listdir(extract_path):
    if not f.lower().endswith(".npy"):
        continue

    full = os.path.join(extract_path, f)

    try:
        arr = np.load(full)
        _ = arr.shape  # force read
        good += 1
    except Exception as e:
        print("❌ Bad file:", full)
        print("   Error:", repr(e))
        bad_files.append(full)

print("\n✅ Good files:", good)
print("❌ Bad files:", len(bad_files))
# Out:
# ✅ Good files: 1380
# ❌ Bad files: 0

# %%
# ============================================
# FOCAL LOSS - Para datasets desbalanceados
# ============================================
import torch
import torch.nn as nn
import torch.nn.functional as F

class FocalLoss(nn.Module):
    """
    Focal Loss para clasificación binaria/multiclase con desbalance.

    Parámetros:
    -----------
    alpha : tensor o None
        Peso para cada clase. Ej: [0.3, 0.7] da más peso a clase 1
    gamma : float
        Factor de enfoque. Típicamente 2.0
        - gamma=0 equivale a CrossEntropyLoss
        - gamma>0 reduce la pérdida para ejemplos bien clasificados
    label_smoothing : float
        Suavizado de etiquetas (0.0 a 0.2 típicamente)
    """
    def __init__(self, alpha=None, gamma=2.0, label_smoothing=0.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha  # será un tensor en GPU
        self.gamma = gamma
        self.label_smoothing = label_smoothing
        self.reduction = reduction

    def forward(self, inputs, targets):
        """
        inputs: logits del modelo, shape (N, C) donde C=num_classes
        targets: etiquetas, shape (N,) con valores 0 o 1
        """
        # Calcular log-softmax para estabilidad numérica
        log_probs = F.log_softmax(inputs, dim=1)

        # Obtener log_prob de la clase correcta para cada muestra
        # targets.unsqueeze(1) -> (N, 1)
        # gather selecciona el log_prob correspondiente a la clase correcta
        ce_loss = F.nll_loss(log_probs, targets, reduction='none')

        # Probabilidad de la clase correcta
        probs = torch.exp(log_probs)
        pt = probs.gather(1, targets.unsqueeze(1)).squeeze(1)

        # Focal weight: (1 - pt)^gamma
        focal_weight = (1 - pt) ** self.gamma

        # Aplicar focal weight
        focal_loss = focal_weight * ce_loss

        # Aplicar alpha (peso por clase) si está definido
        if self.alpha is not None:
            alpha_t = self.alpha.gather(0, targets)
            focal_loss = alpha_t * focal_loss

        # Reducción
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
# Optimizer and Criterion
def compute_class_stats_from_loader(loader):
    total_per_class = torch.zeros(2)

    for _, labels in loader:
        for c in [0, 1]:
            total_per_class[c] += (labels == c).sum()

    N0 = int(total_per_class[0].item())  # non-defective
    N1 = int(total_per_class[1].item())  # defective

    return N0, N1


# Class distribution
N0, N1 = compute_class_stats_from_loader(train_loader)
print("Non-defective:", N0)
print("Defective:", N1)

# Calculate the weights
beta = 0.999
w0 = (1 - beta) / (1 - beta**N0)
w1 = (1 - beta) / (1 - beta**N1)

weights = torch.tensor([w0, w1]).to(device)
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.035)

alpha = torch.tensor([0.35, 0.65]).to(device)  # suma = 1.0

# gamma controla cuánto enfocarse en ejemplos difíciles
# gamma=2.0 es el valor típico del paper original
# criterion = FocalLoss(
#     alpha=alpha,
#     gamma=2.0,
#     label_smoothing=0.05  
# )

# Define optimizer
optimizer = torch.optim.AdamW(imported_model.parameters(), lr=1e-4, weight_decay=5e-5)

# Parse model to the GPU
imported_model = imported_model.to(device)
# Out:
# Non-defective: 603
# Defective: 363

# %%
print(device)
# Out:
# cuda

# %%
num_epochs = 200
patience = 30
min_delta = 1e-2

best_val_aucpr = 0.0
epochs_no_improve = 0
best_model_state = None

# %%
print(imported_model)
# Out:
# EfficientNet(
#   (conv_stem): Conv2d(6, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNormAct2d(
#     32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn1): BatchNormAct2d(
#           32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pw): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn1): BatchNormAct2d(
#           16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(4, 16, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pw): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): BatchNormAct2d(
#           96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#         (bn2): BatchNormAct2d(
#           288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#         (bn2): BatchNormAct2d(
#           288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#         (bn2): BatchNormAct2d(
#           288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(288, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNormAct2d(
#           528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNormAct2d(
#           528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNormAct2d(
#           528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(528, 528, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=528, bias=False)
#         (bn2): BatchNormAct2d(
#           528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNormAct2d(
#           720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNormAct2d(
#           720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNormAct2d(
#           720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNormAct2d(
#           720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNormAct2d(
#           1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNormAct2d(
#           1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNormAct2d(
#           1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNormAct2d(
#           1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (6): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1248, bias=False)
#         (bn2): BatchNormAct2d(
#           1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(352, 2112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(2112, 2112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2112, bias=False)
#         (bn2): BatchNormAct2d(
#           2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(2112, 88, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(88, 2112, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(2112, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#   )
#   (conv_head): Conv2d(352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNormAct2d(
#     1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (classifier): Sequential(
#     (0): Linear(in_features=1408, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Mish()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Mish()
#     (7): Dropout(p=0.4, inplace=False)
#     (8): Linear(in_features=256, out_features=2, bias=True)
#   )
# )

# %%
def apply_freezing(model, layer_groups: list[str], layers_to_modify: list[str], freeze_flag: bool):
    """
    freeze_flag: True → freeze layers, False → unfreeze layers
    layers_to_modify: list of keys from layer_groups,
    """

    target_substrings = []
    for key in layers_to_modify:
        target_substrings += layer_groups[key]

    for name, module in model.named_modules():
        if any(substr in name for substr in target_substrings):
            for param in module.parameters():
                param.requires_grad = (not freeze_flag)  # True→freeze means requires_grad=False

def build_optimizer(model, lr: float, wd: float):
    trainable_params = [p for p in model.parameters() if p.requires_grad]

    return torch.optim.AdamW(
        trainable_params,
        lr=lr,
        weight_decay=wd
    )

# optimizer = torch.optim.AdamW(imported_model.parameters(), lr=learning_rate, weight_decay=5e-5)

# %%
# Hyperparameters
learning_rate = 1e-4
weight_decay = 3e-4

freeze_schedule = [

    # Safety reset: unfreeze everything
    (1, False, ["stem","block1","block2","block3","block4","block5","block6","block7","head"], 1e-4),

    # Phase 1 — Warmup: train only top blocks
    (5, True, ["stem", "block1", "block2", "block3", "block4"], 3e-4),

    # Phase 2 — Unfreeze block4
    (5, False, ["block4"], 1e-4),

    # Phase 3 — Unfreeze block3
    (5, False, ["block3"], 7e-5),

    # Phase 4 — Explicit full unfreeze
    (1, False, ["stem","block1","block2","block3","block4","block5","block6","block7","head"], 5e-5),

    # Phase 5 — Full fine-tuning
    (60, False, [], 3e-5),

    # Phase 6 — Final refinement
    (40, False, [], 1e-5),
]

# Tracking lists
train_losses = []
val_losses = []
train_aucprs = []
val_aucprs = []
train_f1s = []
val_f1s = []

# Early stopping parameters
best_val_aucpr = 0.0
best_epoch = 0
epochs_no_improve = 0
current_epoch = 0

for block_epochs, freeze_flag, layers_to_modify, lr in freeze_schedule:

    print(f"\n=== New Training Block: {block_epochs} epochs | freeze={freeze_flag} | layers={layers_to_modify} ===")

    # Freeze/unfreeze layers
    apply_freezing(imported_model, layer_groups, layers_to_modify, freeze_flag)

    # Rebuild optimizer to include only unfrozen parameters
    optimizer = build_optimizer(imported_model, lr, weight_decay)

    # Rebuild scheduler (optional but recommended)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=lr,                      # the block's lr
        epochs=block_epochs,
        steps_per_epoch=len(train_loader),
        pct_start=0.1
    )

    # Train inside this block
    for _ in range(block_epochs):

        # Safety break if total num_epochs is reached
        if current_epoch >= num_epochs: break

        # ---- Training ----
        train_loss, train_aucpr, train_f1 = Train(imported_model, train_loader, optimizer)
        val_loss, val_aucpr, val_f1, val_best_th = Validate(imported_model, val_loader)

        # Log metrics
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_aucprs.append(train_aucpr)
        val_aucprs.append(val_aucpr)
        train_f1s.append(train_f1)
        val_f1s.append(val_f1)

        print(
            f"Epoch [{current_epoch+1}/{num_epochs}] "
            f"| Freeze={freeze_flag} | Layers={layers_to_modify} "
            f"| Train Loss={train_loss:.4f} Train AUC={train_aucpr:.4f} "
            f"| Val Loss={val_loss:.4f} Val AUC={val_aucpr:.4f}"
        )

        # ---- EARLY STOPPING ----
        if val_aucpr > best_val_aucpr + min_delta:
            best_val_aucpr = val_aucpr
            best_epoch = current_epoch + 1
            epochs_no_improve = 0
            best_model_state = imported_model.state_dict()
            best_threshold = val_best_th
        else:
            epochs_no_improve += 1
            print(f"  EarlyStopping counter: {epochs_no_improve}/{patience}")

        if epochs_no_improve >= patience:
            print("\nEarly stopping triggered!\n")
            break

        # Step scheduler
        scheduler.step()
        current_epoch += 1

    if epochs_no_improve >= patience:
        break

# Restore best weights
imported_model.load_state_dict(best_model_state)
print(f"\nBest model restored (Epoch {best_epoch} | AUC-PR={best_val_aucpr:.4f})")
# Out:
# === New Training Block: 1 epochs | freeze=False | layers=['stem', 'block1', 'block2', 'block3', 'block4', 'block5', 'block6', 'block7', 'head'] ===
# Epoch [1/200] | Freeze=False | Layers=['stem', 'block1', 'block2', 'block3', 'block4', 'block5', 'block6', 'block7', 'head'] | Train Loss=0.7148 Train AUC=0.4332 | Val Loss=0.6724 Val AUC=0.4725
#
# === New Training Block: 5 epochs | freeze=True | layers=['stem', 'block1', 'block2', 'block3', 'block4'] ===
# Epoch [2/200] | Freeze=True | Layers=['stem', 'block1', 'block2', 'block3', 'block4'] | Train Loss=0.7210 Train AUC=0.3947 | Val Loss=0.6503 Val AUC=0.5535
# Epoch [3/200] | Freeze=True | Layers=['stem', 'block1', 'block2', 'block3', 'block4'] | Train Loss=0.7437 Train AUC=0.3794 | Val Loss=0.6590 Val AUC=0.5295
#   EarlyStopping counter: 1/30
# Epoch [4/200] | Freeze=True | Layers=['stem', 'block1', 'block2', 'block3', 'block4'] | Train Loss=0.7211 Train AUC=0.4022 | Val Loss=0.6503 Val AUC=0.5767
# Epoch [5/200] | Freeze=True | Layers=['stem', 'block1', 'block2', 'block3', 'block4'] | Train Loss=0.6928 Train AUC=0.4665 | Val Loss=0.6420 Val AUC=0.5805
#   EarlyStopping counter: 1/30
# Epoch [6/200] | Freeze=True | Layers=['stem', 'block1', 'block2', 'block3', 'block4'] | Train Loss=0.6987 Train AUC=0.4658 | Val Loss=0.6366 Val AUC=0.5825
#   EarlyStopping counter: 2/30
#
# === New Training Block: 5 epochs | freeze=False | layers=['block4'] ===
# Epoch [7/200] | Freeze=False | Layers=['block4'] | Train Loss=0.6986 Train AUC=0.4737 | Val Loss=0.6265 Val AUC=0.6158
# Epoch [8/200] | Freeze=False | Layers=['block4'] | Train Loss=0.6749 Train AUC=0.5057 | Val Loss=0.6325 Val AUC=0.6183
#   EarlyStopping counter: 1/30
# Epoch [9/200] | Freeze=False | Layers=['block4'] | Train Loss=0.7046 Train AUC=0.4555 | Val Loss=0.6331 Val AUC=0.5871
#   EarlyStopping counter: 2/30
# Epoch [10/200] | Freeze=False | Layers=['block4'] | Train Loss=0.6873 Train AUC=0.4849 | Val Loss=0.6297 Val AUC=0.6051
#   EarlyStopping counter: 3/30
# Epoch [11/200] | Freeze=False | Layers=['block4'] | Train Loss=0.6964 Train AUC=0.4837 | Val Loss=0.6273 Val AUC=0.6168
#   EarlyStopping counter: 4/30
#
# === New Training Block: 5 epochs | freeze=False | layers=['block3'] ===
# Epoch [12/200] | Freeze=False | Layers=['block3'] | Train Loss=0.6871 Train AUC=0.4694 | Val Loss=0.6247 Val AUC=0.6153
#   EarlyStopping counter: 5/30
# Epoch [13/200] | Freeze=False | Layers=['block3'] | Train Loss=0.6771 Train AUC=0.5072 | Val Loss=0.6192 Val AUC=0.6470
# Epoch [14/200] | Freeze=False | Layers=['block3'] | Train Loss=0.6916 Train AUC=0.4647 | Val Loss=0.6187 Val AUC=0.6373
#   EarlyStopping counter: 1/30
# Epoch [15/200] | Freeze=False | Layers=['block3'] | Train Loss=0.6863 Train AUC=0.4951 | Val Loss=0.6218 Val AUC=0.6268
#   EarlyStopping counter: 2/30
# Epoch [16/200] | Freeze=False | Layers=['block3'] | Train Loss=0.6610 Train AUC=0.5321 | Val Loss=0.6228 Val AUC=0.6208
#   EarlyStopping counter: 3/30
#
# === New Training Block: 1 epochs | freeze=False | layers=['stem', 'block1', 'block2', 'block3', 'block4', 'block5', 'block6', 'block7', 'head'] ===
# Epoch [17/200] | Freeze=False | Layers=['stem', 'block1', 'block2', 'block3', 'block4', 'block5', 'block6', 'block7', 'head'] | Train Loss=0.6585 Train AUC=0.5491 | Val Loss=0.6235 Val AUC=0.6258
#   EarlyStopping counter: 4/30
#
# === New Training Block: 60 epochs | freeze=False | layers=[] ===
# Epoch [18/200] | Freeze=False | Layers=[] | Train Loss=0.6600 Train AUC=0.5426 | Val Loss=0.6276 Val AUC=0.6163
#   EarlyStopping counter: 5/30
# Epoch [19/200] | Freeze=False | Layers=[] | Train Loss=0.6787 Train AUC=0.5115 | Val Loss=0.6223 Val AUC=0.6207
#   EarlyStopping counter: 6/30
# Epoch [20/200] | Freeze=False | Layers=[] | Train Loss=0.6666 Train AUC=0.5404 | Val Loss=0.6213 Val AUC=0.6207
#   EarlyStopping counter: 7/30
# Epoch [21/200] | Freeze=False | Layers=[] | Train Loss=0.6666 Train AUC=0.5296 | Val Loss=0.6206 Val AUC=0.6227
#   EarlyStopping counter: 8/30
# Epoch [22/200] | Freeze=False | Layers=[] | Train Loss=0.6577 Train AUC=0.5674 | Val Loss=0.6230 Val AUC=0.6305
#   EarlyStopping counter: 9/30
# Epoch [23/200] | Freeze=False | Layers=[] | Train Loss=0.6706 Train AUC=0.5397 | Val Loss=0.6209 Val AUC=0.6337
#   EarlyStopping counter: 10/30
# Epoch [24/200] | Freeze=False | Layers=[] | Train Loss=0.6654 Train AUC=0.5470 | Val Loss=0.6179 Val AUC=0.6333
#   EarlyStopping counter: 11/30
# Epoch [25/200] | Freeze=False | Layers=[] | Train Loss=0.6665 Train AUC=0.5348 | Val Loss=0.6215 Val AUC=0.6200
#   EarlyStopping counter: 12/30
# Epoch [26/200] | Freeze=False | Layers=[] | Train Loss=0.6639 Train AUC=0.5258 | Val Loss=0.6253 Val AUC=0.6088
#   EarlyStopping counter: 13/30
# Epoch [27/200] | Freeze=False | Layers=[] | Train Loss=0.6564 Train AUC=0.5363 | Val Loss=0.6202 Val AUC=0.6327
#   EarlyStopping counter: 14/30
# Epoch [28/200] | Freeze=False | Layers=[] | Train Loss=0.6545 Train AUC=0.5736 | Val Loss=0.6200 Val AUC=0.6207
#   EarlyStopping counter: 15/30
# Epoch [29/200] | Freeze=False | Layers=[] | Train Loss=0.6625 Train AUC=0.5492 | Val Loss=0.6171 Val AUC=0.6361
#   EarlyStopping counter: 16/30
# Epoch [30/200] | Freeze=False | Layers=[] | Train Loss=0.6497 Train AUC=0.5652 | Val Loss=0.6291 Val AUC=0.6213
#   EarlyStopping counter: 17/30
# Epoch [31/200] | Freeze=False | Layers=[] | Train Loss=0.6615 Train AUC=0.5523 | Val Loss=0.6144 Val AUC=0.6428
#   EarlyStopping counter: 18/30
# Epoch [32/200] | Freeze=False | Layers=[] | Train Loss=0.6586 Train AUC=0.5552 | Val Loss=0.6165 Val AUC=0.6325
#   EarlyStopping counter: 19/30
# Epoch [33/200] | Freeze=False | Layers=[] | Train Loss=0.6540 Train AUC=0.5569 | Val Loss=0.6148 Val AUC=0.6342
#   EarlyStopping counter: 20/30
# Epoch [34/200] | Freeze=False | Layers=[] | Train Loss=0.6690 Train AUC=0.5538 | Val Loss=0.6170 Val AUC=0.6324
#   EarlyStopping counter: 21/30
# Epoch [35/200] | Freeze=False | Layers=[] | Train Loss=0.6441 Train AUC=0.5700 | Val Loss=0.6181 Val AUC=0.6281
#   EarlyStopping counter: 22/30
# Epoch [36/200] | Freeze=False | Layers=[] | Train Loss=0.6759 Train AUC=0.5306 | Val Loss=0.6194 Val AUC=0.6269
#   EarlyStopping counter: 23/30
# Epoch [37/200] | Freeze=False | Layers=[] | Train Loss=0.6532 Train AUC=0.5516 | Val Loss=0.6182 Val AUC=0.6473
#   EarlyStopping counter: 24/30
# Epoch [38/200] | Freeze=False | Layers=[] | Train Loss=0.6377 Train AUC=0.5943 | Val Loss=0.6274 Val AUC=0.6262
#   EarlyStopping counter: 25/30
# Epoch [39/200] | Freeze=False | Layers=[] | Train Loss=0.6489 Train AUC=0.5743 | Val Loss=0.6162 Val AUC=0.6331
#   EarlyStopping counter: 26/30
# Epoch [40/200] | Freeze=False | Layers=[] | Train Loss=0.6331 Train AUC=0.6008 | Val Loss=0.6221 Val AUC=0.6293
#   EarlyStopping counter: 27/30
# Epoch [41/200] | Freeze=False | Layers=[] | Train Loss=0.6718 Train AUC=0.5363 | Val Loss=0.6171 Val AUC=0.6276
#   EarlyStopping counter: 28/30
# Epoch [42/200] | Freeze=False | Layers=[] | Train Loss=0.6516 Train AUC=0.5668 | Val Loss=0.6204 Val AUC=0.6302
#   EarlyStopping counter: 29/30
# Epoch [43/200] | Freeze=False | Layers=[] | Train Loss=0.6473 Train AUC=0.5839 | Val Loss=0.6175 Val AUC=0.6270
#   EarlyStopping counter: 30/30
#
# Early stopping triggered!
#
#
# Best model restored (Epoch 13 | AUC-PR=0.6470)

# %%
# # History containers
# train_losses = []
# val_losses = []
# train_aucprs = []
# val_aucprs = []
# train_f1s = []
# val_f1s = []

# # Early stopping parameters
# best_val_aucpr = 0.0
# best_epoch = 0
# epochs_no_improve = 0

# # Scheduler for early stopping
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
#     optimizer,
#     T_max=num_epochs
# )

# for epoch in range(num_epochs):
#     train_loss, train_aucpr, train_f1 = Train(imported_model, train_loader, optimizer)
#     # val_loss, val_aucpr, val_f1 = Validate(imported_model, val_loader)
#     val_loss, val_aucpr, val_f1, val_best_th = Validate(imported_model, val_loader) # Store the best threshold for f1 score

#     # Store values
#     train_losses.append(train_loss)
#     val_losses.append(val_loss)
#     train_aucprs.append(train_aucpr)
#     val_aucprs.append(val_aucpr)
#     train_f1s.append(train_f1)
#     val_f1s.append(val_f1)

#     print(
#         f"Epoch [{epoch+1}/{num_epochs}] | "
#         f"Train Loss: {train_loss:.4f} | Train AUC-PR: {train_aucpr:.4f} | Train F1: {train_f1:.4f} || "
#         f"Val Loss: {val_loss:.4f} | Val AUC-PR: {val_aucpr:.4f} | Val F1: {val_f1:.4f}"
#     )

#     # CORRECT early stopping + TRUE best model tracking
#     if val_aucpr > best_val_aucpr + min_delta:
#         best_val_aucpr = val_aucpr
#         best_epoch = epoch + 1
#         epochs_no_improve = 0
#         best_model_state = imported_model.state_dict()
#         best_threshold = val_best_th
#     else:
#         epochs_no_improve += 1
#         print(f" EarlyStopping counter: {epochs_no_improve}/{patience}")

#     if epochs_no_improve >= patience:
#         print("Early stopping triggered.")
#         break

#     scheduler.step()

# # Restore true best model
# imported_model.load_state_dict(best_model_state)
# print(
#     f"Best model restored (Epoch = {best_epoch} | Val AUC-PR = {best_val_aucpr:.4f})"
# )

# %%
epochs = list(range(1, len(train_losses) + 1))

# -------- LOSS PLOT --------
plt.figure()
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.axvline(
    best_epoch,
    linestyle='--',
    label=f'Best Model (Epoch {best_epoch})'
)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs Epoch (Early Stopping)')
plt.legend()
plt.grid(True)
plt.show()

# -------- AUC-PR PLOT --------
plt.figure()
plt.plot(epochs, train_aucprs, label='Train AVG PR')
plt.plot(epochs, val_aucprs, label='Validation AVG PR')
plt.axvline(
    best_epoch,
    linestyle='--',
    label=f'Best Model (Epoch {best_epoch}) | Val AUC-PR = {best_val_aucpr:.4f}'
)
plt.xlabel('Epoch')
plt.ylabel('AVG PR')
plt.title('AUC-PR vs Epoch (Early Stopping)')
plt.legend()
plt.grid(True)
plt.show()

# -------- F1 SCORE PLOT --------
plt.figure()
plt.plot(epochs, train_f1s, label="Train F1")
plt.plot(epochs, val_f1s, label="Val F1")
plt.axvline(
    best_epoch,
    linestyle='--',
    label=f'Best Model (Epoch {best_epoch}) | Val AUC-PR = {best_val_aucpr:.4f}'
)
plt.xlabel("Epoch")
plt.ylabel("F1-score")
plt.title("F1-score vs Epoch")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import average_precision_score, precision_recall_curve
import torch.nn.functional as F

imported_model.eval()
all_probs = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = imported_model(images)

        # Probabilidad de clase positiva (defecto = clase 1)
        probs = F.softmax(outputs, dim=1)[:, 1]

        all_probs.extend(probs.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

auc_pr = average_precision_score(all_labels, all_probs)
print(f"AUC-PR: {auc_pr:.4f}")

# Convert lists to numpy arrays
all_probs = np.array(all_probs)
all_labels = np.array(all_labels)

# Compute Precision-Recall curve
precision, recall, thresholds = precision_recall_curve(all_labels, all_probs)

# Compute AUC-PR
auc_pr = average_precision_score(all_labels, all_probs)

# Plot
plt.figure()
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision-Recall Curve (AUC = {auc_pr:.4f})")
plt.grid(True)
plt.show()

print("Labels distribution:", np.bincount(all_labels.astype(int)))
# Out:
# AUC-PR: 0.6569
# Labels distribution: [78 47]

# %%
from sklearn.metrics import precision_recall_curve, auc
import numpy as np

imported_model.eval()
all_probs = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        logits = imported_model(images)
        probs = torch.softmax(logits, dim=1)[:, 1]

        all_probs.append(probs.cpu())
        all_labels.append(labels.cpu())

y_scores = torch.cat(all_probs).numpy()
y_true = torch.cat(all_labels).numpy()

# ---- PR Curve ----
precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
auc_pr = auc(recall, precision)

plt.figure()
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision-Recall Curve (AUC = {auc_pr:.4f})")
plt.grid(True)
plt.show()

# ---- F1 vs Threshold ----
f1_scores = 2 * (precision * recall) / (precision + recall + 1e-8)

best_idx = np.argmax(f1_scores)
best_f1 = f1_scores[best_idx]
best_threshold = thresholds[best_idx] if best_idx < len(thresholds) else 0.5

plt.figure()
plt.plot(thresholds, f1_scores[:-1])
plt.xlabel("Threshold")
plt.ylabel("F1 Score")
plt.title("F1 Score vs Threshold")
plt.grid(True)
plt.show()

print(f"AUC-PR: {auc_pr:.4f}")
print(f"Best F1: {best_f1:.4f}")
print(f"Best Threshold: {best_threshold:.4f}")
# Out:
# AUC-PR: 0.6536
# Best F1: 0.5890
# Best Threshold: 0.2897

# %% [markdown]
# ## Saving the model

# %%
# !pip install torch==2.2.0 torchvision==0.17.0 torchaudio==2.2.0 --index-url https://download.pytorch.org/whl/cu118
# !pip install onnx onnxruntime onnxscript

# %%
print(torch.__version__)
# Out:
# 2.10.0.dev20251210+cu128

# %%
import torch
import torch.onnx
import torchvision
dummy_input = torch.rand(1, 6, 310, 310).to(device)

import torch
print(torch.__version__)

imported_model.eval()
torch.onnx.export(
    imported_model,
    dummy_input,                     # still use (1,6,H,W)
    "model_v5.onnx",
    opset_version=13,
    input_names=["x"],
    output_names=["linear"],
    dynamic_axes={
        "x": {0: "batch_size"},      # ✅ dynamic batch
        "linear": {0: "batch_size"}  # ✅ dynamic output batch
    }
)

# torch.onnx.export(imported_model, dummy_input, 'model_v2.onnx', opset_version=11)
# Out:
# W1211 20:01:23.059000 29024 Lib\site-packages\torch\onnx\_internal\exporter\_compat.py:125] Setting ONNX exporter to use operator set version 18 because the requested opset_version 13 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# 2.10.0.dev20251210+cu128
# [torch.onnx] Obtain model graph for `EfficientNet([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `EfficientNet([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 13).
# Failed to convert the model to the target version 13 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\onnxscript\version_converter\__init__.py", line 127, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\onnxscript\version_converter\_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\onnxscript\version_converter\__init__.py", line 122, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\kartp\OneDrive\Documentos\IFRoS\1st semester\Machine Learning\.ML_venv\Lib\site-packages\onnx\version_converter.py", line 39, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: D:\a\onnx\onnx\onnx/version_converter/adapters/axes_input_to_attribute.h:65: adapt: Assertion `node->hasAttribute(kaxes)` failed: No initializer or constant input to node found
# Applied 141 of general pattern rewrite rules.
# ONNXProgram(
#     model=
#         <
#             ir_version=10,
#             opset_imports={'': 18},
#             producer_name='pytorch',
#             producer_version='2.10.0.dev20251210+cu128',
#             domain=None,
#             model_version=None,
#         >
#         graph(
#             name=main_graph,
#             inputs=(
#                 %"x"<FLOAT,[batch_size,6,310,310]>
#             ),
#             outputs=(
#                 %"linear"<FLOAT,[batch_size,2]>
#             ),
#             initializers=(
#                 %"blocks.0.0.conv_dw.weight"<FLOAT,[32,1,3,3]>{Tensor(...)},
#                 %"blocks.0.0.se.conv_reduce.weight"<FLOAT,[8,32,1,1]>{TorchTensor(...)},
#                 %"blocks.0.0.se.conv_reduce.bias"<FLOAT,[8]>{TorchTensor<FLOAT,[8]>(Parameter containing: tensor([ 0.2408, -1.7536, -2.0101, -2.2364, -0.2116, -1.3380, -0.5118, -1.2261], device='cuda:0', requires_grad=True), name='blocks.0.0.se.conv_reduce.bias')},
#                 %"blocks.0.0.se.conv_expand.weight"<FLOAT,[32,8,1,1]>{TorchTensor(...)},
#                 %"blocks.0.0.se.conv_expand.bias"<FLOAT,[32]>{TorchTensor(...)},
#                 %"blocks.0.0.conv_pw.weight"<FLOAT,[16,32,1,1]>{Tensor(...)},
#                 %"blocks.0.1.conv_dw.weight"<FLOAT,[16,1,3,3]>{Tensor(...)},
#                 %"blocks.0.1.se.conv_reduce.weight"<FLOAT,[4,16,1,1]>{TorchTensor(...)},
#                 %"blocks.0.1.se.conv_reduce.bias"<FLOAT,[4]>{TorchTensor<FLOAT,[4]>(Parameter containing: tensor([-1.2742,  5.3332,  1.5145,  3.4600], device='cuda:0', requires_grad=True), name='blocks.0.1.se.conv_reduce.bias')},
#                 %"blocks.0.1.se.conv_expand.weight"<FLOAT,[16,4,1,1]>{TorchTensor(...)},
#                 %"blocks.0.1.se.conv_expand.bias"<FLOAT,[16]>{TorchTensor(...)},
#                 %"blocks.0.1.conv_pw.weight"<FLOAT,[16,16,1,1]>{Tensor(...)},
#                 %"blocks.1.0.conv_dw.weight"<FLOAT,[96,1,3,3]>{Tensor(...)},
#                 %"blocks.1.0.se.conv_reduce.weight"<FLOAT,[4,96,1,1]>{TorchTensor(...)},
#                 %"blocks.1.0.se.conv_reduce.bias"<FLOAT,[4]>{TorchTensor<FLOAT,[4]>(Parameter containing: tensor([ 0.6906, -0.5265, -0.4240,  0.3661], device='cuda:0', requires_grad=True), name='blocks.1.0.se.conv_reduce.bias')},
#                 %"blocks.1.0.se.conv_expand.weight"<FLOAT,[96,4,1,1]>{TorchTensor(...)},
#                 %"blocks.1.0.se.conv_expand.bias"<FLOAT,[96]>{TorchTensor(...)},
#                 %"blocks.1.1.se.conv_reduce.weight"<FLOAT,[6,144,1,1]>{TorchTensor(...)},
#                 %"blocks.1.1.se.conv_reduce.bias"<FLOAT,[6]>{TorchTensor<FLOAT,[6]>(Parameter containing: tensor([2.3049, 0.8669, 2.1380, 1.4287, 2.0830, 0.6134], device='cuda:0', requires_grad=True), name='blocks.1.1.se.conv_reduce.bias')},
#                 %"blocks.1.1.se.conv_expand.weight"<FLOAT,[144,6,1,1]>{TorchTensor(...)},
#                 %"blocks.1.1.se.conv_expand.bias"<FLOAT,[144]>{TorchTensor(...)},
#                 %"blocks.1.2.se.conv_reduce.weight"<FLOAT,[6,144,1,1]>{TorchTensor(...)},
#                 %"blocks.1.2.se.conv_reduce.bias"<FLOAT,[6]>{TorchTensor<FLOAT,[6]>(Parameter containing: tensor([1.2230, 2.0036, 0.5707, 0.0763, 1.0952, 1.1301], device='cuda:0', requires_grad=True), name='blocks.1.2.se.conv_reduce.bias')},
#                 %"blocks.1.2.se.conv_expand.weight"<FLOAT,[144,6,1,1]>{TorchTensor(...)},
#                 %"blocks.1.2.se.conv_expand.bias"<FLOAT,[144]>{TorchTensor(...)},
#                 %"blocks.2.0.se.conv_reduce.weight"<FLOAT,[6,144,1,1]>{TorchTensor(...)},
#                 %"blocks.2.0.se.conv_reduce.bias"<FLOAT,[6]>{TorchTensor<FLOAT,[6]>(Parameter containing: tensor([-0.7789, -0.0974, -0.3555, -0.6869, -0.3724, -0.1110], device='cuda:0', requires_grad=True), name='blocks.2.0.se.conv_reduce.bias')},
#                 %"blocks.2.0.se.conv_expand.weight"<FLOAT,[144,6,1,1]>{TorchTensor(...)},
#                 %"blocks.2.0.se.conv_expand.bias"<FLOAT,[144]>{TorchTensor(...)},
#                 %"blocks.2.1.se.conv_reduce.bias"<FLOAT,[12]>{TorchTensor(...)},
#                 %"blocks.2.1.se.conv_expand.bias"<FLOAT,[288]>{TorchTensor(...)},
#                 %"blocks.2.2.se.conv_reduce.bias"<FLOAT,[12]>{TorchTensor(...)},
#                 %"blocks.2.2.se.conv_expand.bias"<FLOAT,[288]>{TorchTensor(...)},
#                 %"blocks.3.0.se.conv_reduce.bias"<FLOAT,[12]>{TorchTensor(...)},
#                 %"blocks.3.0.se.conv_expand.bias"<FLOAT,[288]>{TorchTensor(...)},
#                 %"blocks.3.1.se.conv_reduce.bias"<FLOAT,[22]>{TorchTensor(...)},
#                 %"blocks.3.1.se.conv_expand.bias"<FLOAT,[528]>{TorchTensor(...)},
#                 %"blocks.3.2.se.conv_reduce.bias"<FLOAT,[22]>{TorchTensor(...)},
#                 %"blocks.3.2.se.conv_expand.bias"<FLOAT,[528]>{TorchTensor(...)},
#                 %"blocks.3.3.se.conv_reduce.bias"<FLOAT,[22]>{TorchTensor(...)},
#                 %"blocks.3.3.se.conv_expand.bias"<FLOAT,[528]>{TorchTensor(...)},
#                 %"blocks.4.0.se.conv_reduce.bias"<FLOAT,[22]>{TorchTensor(...)},
#                 %"blocks.4.0.se.conv_expand.bias"<FLOAT,[528]>{TorchTensor(...)},
#                 %"blocks.4.1.se.conv_reduce.bias"<FLOAT,[30]>{TorchTensor(...)},
#                 %"blocks.4.1.se.conv_expand.bias"<FLOAT,[720]>{TorchTensor(...)},
#                 %"blocks.4.2.se.conv_reduce.bias"<FLOAT,[30]>{TorchTensor(...)},
#                 %"blocks.4.2.se.conv_expand.bias"<FLOAT,[720]>{TorchTensor(...)},
#                 %"blocks.4.3.se.conv_reduce.bias"<FLOAT,[30]>{TorchTensor(...)},
#                 %"blocks.4.3.se.conv_expand.bias"<FLOAT,[720]>{TorchTensor(...)},
#                 %"blocks.5.0.se.conv_reduce.bias"<FLOAT,[30]>{TorchTensor(...)},
#                 %"blocks.5.0.se.conv_expand.bias"<FLOAT,[720]>{TorchTensor(...)},
#                 %"blocks.5.1.se.conv_reduce.bias"<FLOAT,[52]>{TorchTensor(...)},
#                 %"blocks.5.2.se.conv_reduce.bias"<FLOAT,[52]>{TorchTensor(...)},
#                 %"blocks.5.3.se.conv_reduce.bias"<FLOAT,[52]>{TorchTensor(...)},
#                 %"blocks.5.4.se.conv_reduce.bias"<FLOAT,[52]>{TorchTensor(...)},
#                 %"blocks.6.0.se.conv_reduce.bias"<FLOAT,[52]>{TorchTensor(...)},
#                 %"blocks.6.1.se.conv_reduce.bias"<FLOAT,[88]>{TorchTensor(...)},
#                 %"classifier.0.bias"<FLOAT,[512]>{Tensor(...)},
#                 %"classifier.4.bias"<FLOAT,[256]>{Tensor(...)},
#                 %"classifier.8.weight"<FLOAT,[2,256]>{TorchTensor(...)},
#                 %"classifier.8.bias"<FLOAT,[2]>{TorchTensor<FLOAT,[2]>(Parameter containing: tensor([0.0296, 0.0292], device='cuda:0', requires_grad=True), name='classifier.8.bias')},
#                 %"conv_stem.weight"<FLOAT,[32,6,3,3]>{Tensor(...)},
#                 %"blocks.1.0.conv_pw.weight"<FLOAT,[96,16,1,1]>{Tensor(...)},
#                 %"blocks.1.0.conv_pwl.weight"<FLOAT,[24,96,1,1]>{Tensor(...)},
#                 %"blocks.1.1.conv_pw.weight"<FLOAT,[144,24,1,1]>{Tensor(...)},
#                 %"blocks.1.1.conv_dw.weight"<FLOAT,[144,1,3,3]>{Tensor(...)},
#                 %"blocks.1.1.conv_pwl.weight"<FLOAT,[24,144,1,1]>{Tensor(...)},
#                 %"blocks.1.2.conv_pw.weight"<FLOAT,[144,24,1,1]>{Tensor(...)},
#                 %"blocks.1.2.conv_dw.weight"<FLOAT,[144,1,3,3]>{Tensor(...)},
#                 %"blocks.1.2.conv_pwl.weight"<FLOAT,[24,144,1,1]>{Tensor(...)},
#                 %"blocks.2.0.conv_pw.weight"<FLOAT,[144,24,1,1]>{Tensor(...)},
#                 %"blocks.2.0.conv_dw.weight"<FLOAT,[144,1,5,5]>{Tensor(...)},
#                 %"blocks.2.0.conv_pwl.weight"<FLOAT,[48,144,1,1]>{Tensor(...)},
#                 %"blocks.2.1.conv_pw.weight"<FLOAT,[288,48,1,1]>{Tensor(...)},
#                 %"blocks.2.1.conv_dw.weight"<FLOAT,[288,1,5,5]>{Tensor(...)},
#                 %"blocks.2.1.se.conv_reduce.weight"<FLOAT,[12,288,1,1]>{TorchTensor(...)},
#                 %"blocks.2.1.se.conv_expand.weight"<FLOAT,[288,12,1,1]>{TorchTensor(...)},
#                 %"blocks.2.1.conv_pwl.weight"<FLOAT,[48,288,1,1]>{Tensor(...)},
#                 %"blocks.2.2.conv_pw.weight"<FLOAT,[288,48,1,1]>{Tensor(...)},
#                 %"blocks.2.2.conv_dw.weight"<FLOAT,[288,1,5,5]>{Tensor(...)},
#                 %"blocks.2.2.se.conv_reduce.weight"<FLOAT,[12,288,1,1]>{TorchTensor(...)},
#                 %"blocks.2.2.se.conv_expand.weight"<FLOAT,[288,12,1,1]>{TorchTensor(...)},
#                 %"blocks.2.2.conv_pwl.weight"<FLOAT,[48,288,1,1]>{Tensor(...)},
#                 %"blocks.3.0.conv_pw.weight"<FLOAT,[288,48,1,1]>{Tensor(...)},
#                 %"blocks.3.0.conv_dw.weight"<FLOAT,[288,1,3,3]>{Tensor(...)},
#                 %"blocks.3.0.se.conv_reduce.weight"<FLOAT,[12,288,1,1]>{TorchTensor(...)},
#                 %"blocks.3.0.se.conv_expand.weight"<FLOAT,[288,12,1,1]>{TorchTensor(...)},
#                 %"blocks.3.0.conv_pwl.weight"<FLOAT,[88,288,1,1]>{Tensor(...)},
#                 %"blocks.3.1.conv_pw.weight"<FLOAT,[528,88,1,1]>{Tensor(...)},
#                 %"blocks.3.1.conv_dw.weight"<FLOAT,[528,1,3,3]>{Tensor(...)},
#                 %"blocks.3.1.se.conv_reduce.weight"<FLOAT,[22,528,1,1]>{TorchTensor(...)},
#                 %"blocks.3.1.se.conv_expand.weight"<FLOAT,[528,22,1,1]>{TorchTensor(...)},
#                 %"blocks.3.1.conv_pwl.weight"<FLOAT,[88,528,1,1]>{Tensor(...)},
#                 %"blocks.3.2.conv_pw.weight"<FLOAT,[528,88,1,1]>{Tensor(...)},
#                 %"blocks.3.2.conv_dw.weight"<FLOAT,[528,1,3,3]>{Tensor(...)},
#                 %"blocks.3.2.se.conv_reduce.weight"<FLOAT,[22,528,1,1]>{TorchTensor(...)},
#                 %"blocks.3.2.se.conv_expand.weight"<FLOAT,[528,22,1,1]>{TorchTensor(...)},
#                 %"blocks.3.2.conv_pwl.weight"<FLOAT,[88,528,1,1]>{Tensor(...)},
#                 %"blocks.3.3.conv_pw.weight"<FLOAT,[528,88,1,1]>{Tensor(...)},
#                 %"blocks.3.3.conv_dw.weight"<FLOAT,[528,1,3,3]>{Tensor(...)},
#                 %"blocks.3.3.se.conv_reduce.weight"<FLOAT,[22,528,1,1]>{TorchTensor(...)},
#                 %"blocks.3.3.se.conv_expand.weight"<FLOAT,[528,22,1,1]>{TorchTensor(...)},
#                 %"blocks.3.3.conv_pwl.weight"<FLOAT,[88,528,1,1]>{Tensor(...)},
#                 %"blocks.4.0.conv_pw.weight"<FLOAT,[528,88,1,1]>{Tensor(...)},
#                 %"blocks.4.0.conv_dw.weight"<FLOAT,[528,1,5,5]>{Tensor(...)},
#                 %"blocks.4.0.se.conv_reduce.weight"<FLOAT,[22,528,1,1]>{TorchTensor(...)},
#                 %"blocks.4.0.se.conv_expand.weight"<FLOAT,[528,22,1,1]>{TorchTensor(...)},
#                 %"blocks.4.0.conv_pwl.weight"<FLOAT,[120,528,1,1]>{Tensor(...)},
#                 %"blocks.4.1.conv_pw.weight"<FLOAT,[720,120,1,1]>{Tensor(...)},
#                 %"blocks.4.1.conv_dw.weight"<FLOAT,[720,1,5,5]>{Tensor(...)},
#                 %"blocks.4.1.se.conv_reduce.weight"<FLOAT,[30,720,1,1]>{TorchTensor(...)},
#                 %"blocks.4.1.se.conv_expand.weight"<FLOAT,[720,30,1,1]>{TorchTensor(...)},
#                 %"blocks.4.1.conv_pwl.weight"<FLOAT,[120,720,1,1]>{Tensor(...)},
#                 %"blocks.4.2.conv_pw.weight"<FLOAT,[720,120,1,1]>{Tensor(...)},
#                 %"blocks.4.2.conv_dw.weight"<FLOAT,[720,1,5,5]>{Tensor(...)},
#                 %"blocks.4.2.se.conv_reduce.weight"<FLOAT,[30,720,1,1]>{TorchTensor(...)},
#                 %"blocks.4.2.se.conv_expand.weight"<FLOAT,[720,30,1,1]>{TorchTensor(...)},
#                 %"blocks.4.2.conv_pwl.weight"<FLOAT,[120,720,1,1]>{Tensor(...)},
#                 %"blocks.4.3.conv_pw.weight"<FLOAT,[720,120,1,1]>{Tensor(...)},
#                 %"blocks.4.3.conv_dw.weight"<FLOAT,[720,1,5,5]>{Tensor(...)},
#                 %"blocks.4.3.se.conv_reduce.weight"<FLOAT,[30,720,1,1]>{TorchTensor(...)},
#                 %"blocks.4.3.se.conv_expand.weight"<FLOAT,[720,30,1,1]>{TorchTensor(...)},
#                 %"blocks.4.3.conv_pwl.weight"<FLOAT,[120,720,1,1]>{Tensor(...)},
#                 %"blocks.5.0.conv_pw.weight"<FLOAT,[720,120,1,1]>{Tensor(...)},
#                 %"blocks.5.0.conv_dw.weight"<FLOAT,[720,1,5,5]>{Tensor(...)},
#                 %"blocks.5.0.se.conv_reduce.weight"<FLOAT,[30,720,1,1]>{TorchTensor(...)},
#                 %"blocks.5.0.se.conv_expand.weight"<FLOAT,[720,30,1,1]>{TorchTensor(...)},
#                 %"blocks.5.0.conv_pwl.weight"<FLOAT,[208,720,1,1]>{Tensor(...)},
#                 %"blocks.5.1.conv_pw.weight"<FLOAT,[1248,208,1,1]>{Tensor(...)},
#                 %"blocks.5.1.conv_dw.weight"<FLOAT,[1248,1,5,5]>{Tensor(...)},
#                 %"blocks.5.1.se.conv_reduce.weight"<FLOAT,[52,1248,1,1]>{TorchTensor(...)},
#                 %"blocks.5.1.se.conv_expand.weight"<FLOAT,[1248,52,1,1]>{TorchTensor(...)},
#                 %"blocks.5.1.se.conv_expand.bias"<FLOAT,[1248]>{TorchTensor(...)},
#                 %"blocks.5.1.conv_pwl.weight"<FLOAT,[208,1248,1,1]>{Tensor(...)},
#                 %"blocks.5.2.conv_pw.weight"<FLOAT,[1248,208,1,1]>{Tensor(...)},
#                 %"blocks.5.2.conv_dw.weight"<FLOAT,[1248,1,5,5]>{Tensor(...)},
#                 %"blocks.5.2.se.conv_reduce.weight"<FLOAT,[52,1248,1,1]>{TorchTensor(...)},
#                 %"blocks.5.2.se.conv_expand.weight"<FLOAT,[1248,52,1,1]>{TorchTensor(...)},
#                 %"blocks.5.2.se.conv_expand.bias"<FLOAT,[1248]>{TorchTensor(...)},
#                 %"blocks.5.2.conv_pwl.weight"<FLOAT,[208,1248,1,1]>{Tensor(...)},
#                 %"blocks.5.3.conv_pw.weight"<FLOAT,[1248,208,1,1]>{Tensor(...)},
#                 %"blocks.5.3.conv_dw.weight"<FLOAT,[1248,1,5,5]>{Tensor(...)},
#                 %"blocks.5.3.se.conv_reduce.weight"<FLOAT,[52,1248,1,1]>{TorchTensor(...)},
#                 %"blocks.5.3.se.conv_expand.weight"<FLOAT,[1248,52,1,1]>{TorchTensor(...)},
#                 %"blocks.5.3.se.conv_expand.bias"<FLOAT,[1248]>{TorchTensor(...)},
#                 %"blocks.5.3.conv_pwl.weight"<FLOAT,[208,1248,1,1]>{Tensor(...)},
#                 %"blocks.5.4.conv_pw.weight"<FLOAT,[1248,208,1,1]>{Tensor(...)},
#                 %"blocks.5.4.conv_dw.weight"<FLOAT,[1248,1,5,5]>{Tensor(...)},
#                 %"blocks.5.4.se.conv_reduce.weight"<FLOAT,[52,1248,1,1]>{TorchTensor(...)},
#                 %"blocks.5.4.se.conv_expand.weight"<FLOAT,[1248,52,1,1]>{TorchTensor(...)},
#                 %"blocks.5.4.se.conv_expand.bias"<FLOAT,[1248]>{TorchTensor(...)},
#                 %"blocks.5.4.conv_pwl.weight"<FLOAT,[208,1248,1,1]>{Tensor(...)},
#                 %"blocks.6.0.conv_pw.weight"<FLOAT,[1248,208,1,1]>{Tensor(...)},
#                 %"blocks.6.0.conv_dw.weight"<FLOAT,[1248,1,3,3]>{Tensor(...)},
#                 %"blocks.6.0.se.conv_reduce.weight"<FLOAT,[52,1248,1,1]>{TorchTensor(...)},
#                 %"blocks.6.0.se.conv_expand.weight"<FLOAT,[1248,52,1,1]>{TorchTensor(...)},
#                 %"blocks.6.0.se.conv_expand.bias"<FLOAT,[1248]>{TorchTensor(...)},
#                 %"blocks.6.0.conv_pwl.weight"<FLOAT,[352,1248,1,1]>{Tensor(...)},
#                 %"blocks.6.1.conv_pw.weight"<FLOAT,[2112,352,1,1]>{Tensor(...)},
#                 %"blocks.6.1.conv_dw.weight"<FLOAT,[2112,1,3,3]>{Tensor(...)},
#                 %"blocks.6.1.se.conv_reduce.weight"<FLOAT,[88,2112,1,1]>{TorchTensor(...)},
#                 %"blocks.6.1.se.conv_expand.weight"<FLOAT,[2112,88,1,1]>{TorchTensor(...)},
#                 %"blocks.6.1.se.conv_expand.bias"<FLOAT,[2112]>{TorchTensor(...)},
#                 %"blocks.6.1.conv_pwl.weight"<FLOAT,[352,2112,1,1]>{Tensor(...)},
#                 %"conv_head.weight"<FLOAT,[1408,352,1,1]>{Tensor(...)},
#                 %"classifier.0.weight"<FLOAT,[512,1408]>{Tensor(...)},
#                 %"classifier.4.weight"<FLOAT,[256,512]>{Tensor(...)},
#                 %"val_72"<INT64,[2]>{Tensor<INT64,[2]>(array([2, 3]), name='val_72')},
#                 %"val_789"<INT64,[2]>{Tensor<INT64,[2]>(array([-1, -2]), name='val_789')},
#                 %"x_bias"<FLOAT,[32]>{Tensor(...)},
#                 %"silu_bias"<FLOAT,[32]>{Tensor(...)},
#                 %"mul_128_bias"<FLOAT,[16]>{Tensor(...)},
#                 %"getitem_6_bias"<FLOAT,[16]>{Tensor(...)},
#                 %"mul_184_bias"<FLOAT,[16]>{Tensor(...)},
#                 %"add_208_bias"<FLOAT,[96]>{Tensor(...)},
#                 %"silu_5_bias"<FLOAT,[96]>{Tensor(...)},
#                 %"mul_266_bias"<FLOAT,[24]>{Tensor(...)},
#                 %"getitem_21_bias"<FLOAT,[144]>{Tensor(...)},
#                 %"silu_8_bias"<FLOAT,[144]>{Tensor(...)},
#                 %"mul_346_bias"<FLOAT,[24]>{Tensor(...)},
#                 %"add_390_bias"<FLOAT,[144]>{Tensor(...)},
#                 %"silu_11_bias"<FLOAT,[144]>{Tensor(...)},
#                 %"mul_428_bias"<FLOAT,[24]>{Tensor(...)},
#                 %"add_484_bias"<FLOAT,[144]>{Tensor(...)},
#                 %"silu_14_bias"<FLOAT,[144]>{Tensor(...)},
#                 %"mul_510_bias"<FLOAT,[48]>{Tensor(...)},
#                 %"getitem_48_bias"<FLOAT,[288]>{Tensor(...)},
#                 %"silu_17_bias"<FLOAT,[288]>{Tensor(...)},
#                 %"mul_590_bias"<FLOAT,[48]>{Tensor(...)},
#                 %"add_666_bias"<FLOAT,[288]>{Tensor(...)},
#                 %"silu_20_bias"<FLOAT,[288]>{Tensor(...)},
#                 %"mul_672_bias"<FLOAT,[48]>{Tensor(...)},
#                 %"add_760_bias"<FLOAT,[288]>{Tensor(...)},
#                 %"silu_23_bias"<FLOAT,[288]>{Tensor(...)},
#                 %"mul_754_bias"<FLOAT,[88]>{Tensor(...)},
#                 %"getitem_75_bias"<FLOAT,[528]>{Tensor(...)},
#                 %"silu_26_bias"<FLOAT,[528]>{Tensor(...)},
#                 %"mul_834_bias"<FLOAT,[88]>{Tensor(...)},
#                 %"add_942_bias"<FLOAT,[528]>{Tensor(...)},
#                 %"silu_29_bias"<FLOAT,[528]>{Tensor(...)},
#                 %"mul_916_bias"<FLOAT,[88]>{Tensor(...)},
#                 %"add_1036_bias"<FLOAT,[528]>{Tensor(...)},
#                 %"silu_32_bias"<FLOAT,[528]>{Tensor(...)},
#                 %"mul_998_bias"<FLOAT,[88]>{Tensor(...)},
#                 %"add_1130_bias"<FLOAT,[528]>{Tensor(...)},
#                 %"silu_35_bias"<FLOAT,[528]>{Tensor(...)},
#                 %"mul_1080_bias"<FLOAT,[120]>{Tensor(...)},
#                 %"getitem_111_bias"<FLOAT,[720]>{Tensor(...)},
#                 %"silu_38_bias"<FLOAT,[720]>{Tensor(...)},
#                 %"mul_1160_bias"<FLOAT,[120]>{Tensor(...)},
#                 %"add_1312_bias"<FLOAT,[720]>{Tensor(...)},
#                 %"silu_41_bias"<FLOAT,[720]>{Tensor(...)},
#                 %"mul_1242_bias"<FLOAT,[120]>{Tensor(...)},
#                 %"add_1406_bias"<FLOAT,[720]>{Tensor(...)},
#                 %"silu_44_bias"<FLOAT,[720]>{Tensor(...)},
#                 %"mul_1324_bias"<FLOAT,[120]>{Tensor(...)},
#                 %"add_1500_bias"<FLOAT,[720]>{Tensor(...)},
#                 %"silu_47_bias"<FLOAT,[720]>{Tensor(...)},
#                 %"mul_1406_bias"<FLOAT,[208]>{Tensor(...)},
#                 %"getitem_147_bias"<FLOAT,[1248]>{Tensor(...)},
#                 %"silu_50_bias"<FLOAT,[1248]>{Tensor(...)},
#                 %"mul_1486_bias"<FLOAT,[208]>{Tensor(...)},
#                 %"add_1682_bias"<FLOAT,[1248]>{Tensor(...)},
#                 %"silu_53_bias"<FLOAT,[1248]>{Tensor(...)},
#                 %"mul_1568_bias"<FLOAT,[208]>{Tensor(...)},
#                 %"add_1776_bias"<FLOAT,[1248]>{Tensor(...)},
#                 %"silu_56_bias"<FLOAT,[1248]>{Tensor(...)},
#                 %"mul_1650_bias"<FLOAT,[208]>{Tensor(...)},
#                 %"add_1870_bias"<FLOAT,[1248]>{Tensor(...)},
#                 %"silu_59_bias"<FLOAT,[1248]>{Tensor(...)},
#                 %"mul_1732_bias"<FLOAT,[208]>{Tensor(...)},
#                 %"add_1964_bias"<FLOAT,[1248]>{Tensor(...)},
#                 %"silu_62_bias"<FLOAT,[1248]>{Tensor(...)},
#                 %"mul_1814_bias"<FLOAT,[352]>{Tensor(...)},
#                 %"getitem_192_bias"<FLOAT,[2112]>{Tensor(...)},
#                 %"silu_65_bias"<FLOAT,[2112]>{Tensor(...)},
#                 %"mul_1894_bias"<FLOAT,[352]>{Tensor(...)},
#                 %"add_2146_bias"<FLOAT,[1408]>{Tensor(...)},
#                 %"val_792"<INT64,[1]>{Tensor<INT64,[1]>(array([1408]), name='val_792')}
#             ),
#         ) {
#               0 |  # node_Shape_0
#                    %"val_0"<INT64,[1]> ⬅️ ::Shape(%"x") {start=0, end=1}
#               1 |  # node_Conv_1010
#                    %"getitem"<FLOAT,[batch_size,32,155,155]> ⬅️ ::Conv(%"x", %"conv_stem.weight"{...}, %"x_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(1, 1, 1, 1)}
#               2 |  # node_Sigmoid_59
#                    %"val_59"<FLOAT,[batch_size,32,155,155]> ⬅️ ::Sigmoid(%"getitem")
#               3 |  # node_silu
#                    %"silu"<FLOAT,[batch_size,32,155,155]> ⬅️ ::Mul(%"getitem", %"val_59")
#               4 |  # node_Conv_1012
#                    %"getitem_3"<FLOAT,[batch_size,32,155,155]> ⬅️ ::Conv(%"silu", %"blocks.0.0.conv_dw.weight"{...}, %"silu_bias"{...}) {group=32, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#               5 |  # node_Sigmoid_69
#                    %"val_69"<FLOAT,[batch_size,32,155,155]> ⬅️ ::Sigmoid(%"getitem_3")
#               6 |  # node_silu_1
#                    %"silu_1"<FLOAT,[batch_size,32,155,155]> ⬅️ ::Mul(%"getitem_3", %"val_69")
#               7 |  # node_mean
#                    %"mean"<FLOAT,[batch_size,32,1,1]> ⬅️ ::ReduceMean(%"silu_1", %"val_72"{[2, 3]}) {keepdims=1, noop_with_empty_axes=0}
#               8 |  # node_conv2d_2
#                    %"conv2d_2"<FLOAT,[batch_size,8,1,1]> ⬅️ ::Conv(%"mean", %"blocks.0.0.se.conv_reduce.weight"{...}, %"blocks.0.0.se.conv_reduce.bias"{[0.24084654450416565, -1.7536197900772095, -2.010108709335327, -2.236360788345337, -0.2116107940673828, -1.337973952293396, -0.5117788314819336, -1.2261250019073486]}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#               9 |  # node_Sigmoid_73
#                    %"val_73"<FLOAT,[batch_size,8,1,1]> ⬅️ ::Sigmoid(%"conv2d_2")
#              10 |  # node_silu_2
#                    %"silu_2"<FLOAT,[batch_size,8,1,1]> ⬅️ ::Mul(%"conv2d_2", %"val_73")
#              11 |  # node_conv2d_3
#                    %"conv2d_3"<FLOAT,[batch_size,32,1,1]> ⬅️ ::Conv(%"silu_2", %"blocks.0.0.se.conv_expand.weight"{...}, %"blocks.0.0.se.conv_expand.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              12 |  # node_sigmoid
#                    %"sigmoid"<FLOAT,[batch_size,32,1,1]> ⬅️ ::Sigmoid(%"conv2d_3")
#              13 |  # node_mul_128
#                    %"mul_128"<FLOAT,[batch_size,32,155,155]> ⬅️ ::Mul(%"silu_1", %"sigmoid")
#              14 |  # node_Conv_1014
#                    %"getitem_6"<FLOAT,[batch_size,16,155,155]> ⬅️ ::Conv(%"mul_128", %"blocks.0.0.conv_pw.weight"{...}, %"mul_128_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              15 |  # node_Conv_1016
#                    %"getitem_9"<FLOAT,[batch_size,16,155,155]> ⬅️ ::Conv(%"getitem_6", %"blocks.0.1.conv_dw.weight"{...}, %"getitem_6_bias"{...}) {group=16, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#              16 |  # node_Sigmoid_92
#                    %"val_92"<FLOAT,[batch_size,16,155,155]> ⬅️ ::Sigmoid(%"getitem_9")
#              17 |  # node_silu_3
#                    %"silu_3"<FLOAT,[batch_size,16,155,155]> ⬅️ ::Mul(%"getitem_9", %"val_92")
#              18 |  # node_mean_1
#                    %"mean_1"<FLOAT,[batch_size,16,1,1]> ⬅️ ::ReduceMean(%"silu_3", %"val_72"{[2, 3]}) {keepdims=1, noop_with_empty_axes=0}
#              19 |  # node_conv2d_6
#                    %"conv2d_6"<FLOAT,[batch_size,4,1,1]> ⬅️ ::Conv(%"mean_1", %"blocks.0.1.se.conv_reduce.weight"{...}, %"blocks.0.1.se.conv_reduce.bias"{[-1.274183750152588, 5.33315372467041, 1.5145010948181152, 3.4599852561950684]}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              20 |  # node_Sigmoid_95
#                    %"val_95"<FLOAT,[batch_size,4,1,1]> ⬅️ ::Sigmoid(%"conv2d_6")
#              21 |  # node_silu_4
#                    %"silu_4"<FLOAT,[batch_size,4,1,1]> ⬅️ ::Mul(%"conv2d_6", %"val_95")
#              22 |  # node_conv2d_7
#                    %"conv2d_7"<FLOAT,[batch_size,16,1,1]> ⬅️ ::Conv(%"silu_4", %"blocks.0.1.se.conv_expand.weight"{...}, %"blocks.0.1.se.conv_expand.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              23 |  # node_sigmoid_1
#                    %"sigmoid_1"<FLOAT,[batch_size,16,1,1]> ⬅️ ::Sigmoid(%"conv2d_7")
#              24 |  # node_mul_184
#                    %"mul_184"<FLOAT,[batch_size,16,155,155]> ⬅️ ::Mul(%"silu_3", %"sigmoid_1")
#              25 |  # node_Conv_1018
#                    %"getitem_12"<FLOAT,[batch_size,16,155,155]> ⬅️ ::Conv(%"mul_184", %"blocks.0.1.conv_pw.weight"{...}, %"mul_184_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              26 |  # node_add_208
#                    %"add_208"<FLOAT,[batch_size,16,155,155]> ⬅️ ::Add(%"getitem_12", %"getitem_6")
#              27 |  # node_Conv_1020
#                    %"getitem_15"<FLOAT,[batch_size,96,155,155]> ⬅️ ::Conv(%"add_208", %"blocks.1.0.conv_pw.weight"{...}, %"add_208_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              28 |  # node_Sigmoid_114
#                    %"val_114"<FLOAT,[batch_size,96,155,155]> ⬅️ ::Sigmoid(%"getitem_15")
#              29 |  # node_silu_5
#                    %"silu_5"<FLOAT,[batch_size,96,155,155]> ⬅️ ::Mul(%"getitem_15", %"val_114")
#              30 |  # node_Conv_1022
#                    %"getitem_18"<FLOAT,[batch_size,96,78,78]> ⬅️ ::Conv(%"silu_5", %"blocks.1.0.conv_dw.weight"{...}, %"silu_5_bias"{...}) {group=96, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(1, 1, 1, 1)}
#              31 |  # node_Sigmoid_124
#                    %"val_124"<FLOAT,[batch_size,96,78,78]> ⬅️ ::Sigmoid(%"getitem_18")
#              32 |  # node_silu_6
#                    %"silu_6"<FLOAT,[batch_size,96,78,78]> ⬅️ ::Mul(%"getitem_18", %"val_124")
#              33 |  # node_mean_2
#                    %"mean_2"<FLOAT,[batch_size,96,1,1]> ⬅️ ::ReduceMean(%"silu_6", %"val_72"{[2, 3]}) {keepdims=1, noop_with_empty_axes=0}
#              34 |  # node_conv2d_11
#                    %"conv2d_11"<FLOAT,[batch_size,4,1,1]> ⬅️ ::Conv(%"mean_2", %"blocks.1.0.se.conv_reduce.weight"{...}, %"blocks.1.0.se.conv_reduce.bias"{[0.6906346082687378, -0.5264692902565002, -0.4240016043186188, 0.36608701944351196]}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              35 |  # node_Sigmoid_127
#                    %"val_127"<FLOAT,[batch_size,4,1,1]> ⬅️ ::Sigmoid(%"conv2d_11")
#              36 |  # node_silu_7
#                    %"silu_7"<FLOAT,[batch_size,4,1,1]> ⬅️ ::Mul(%"conv2d_11", %"val_127")
#              37 |  # node_conv2d_12
#                    %"conv2d_12"<FLOAT,[batch_size,96,1,1]> ⬅️ ::Conv(%"silu_7", %"blocks.1.0.se.conv_expand.weight"{...}, %"blocks.1.0.se.conv_expand.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              38 |  # node_sigmoid_2
#                    %"sigmoid_2"<FLOAT,[batch_size,96,1,1]> ⬅️ ::Sigmoid(%"conv2d_12")
#              39 |  # node_mul_266
#                    %"mul_266"<FLOAT,[batch_size,96,78,78]> ⬅️ ::Mul(%"silu_6", %"sigmoid_2")
#              40 |  # node_Conv_1024
#                    %"getitem_21"<FLOAT,[batch_size,24,78,78]> ⬅️ ::Conv(%"mul_266", %"blocks.1.0.conv_pwl.weight"{...}, %"mul_266_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              41 |  # node_Conv_1026
#                    %"getitem_24"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Conv(%"getitem_21", %"blocks.1.1.conv_pw.weight"{...}, %"getitem_21_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              42 |  # node_Sigmoid_146
#                    %"val_146"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Sigmoid(%"getitem_24")
#              43 |  # node_silu_8
#                    %"silu_8"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Mul(%"getitem_24", %"val_146")
#              44 |  # node_Conv_1028
#                    %"getitem_27"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Conv(%"silu_8", %"blocks.1.1.conv_dw.weight"{...}, %"silu_8_bias"{...}) {group=144, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#              45 |  # node_Sigmoid_156
#                    %"val_156"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Sigmoid(%"getitem_27")
#              46 |  # node_silu_9
#                    %"silu_9"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Mul(%"getitem_27", %"val_156")
#              47 |  # node_mean_3
#                    %"mean_3"<FLOAT,[batch_size,144,1,1]> ⬅️ ::ReduceMean(%"silu_9", %"val_72"{[2, 3]}) {keepdims=1, noop_with_empty_axes=0}
#              48 |  # node_conv2d_16
#                    %"conv2d_16"<FLOAT,[batch_size,6,1,1]> ⬅️ ::Conv(%"mean_3", %"blocks.1.1.se.conv_reduce.weight"{...}, %"blocks.1.1.se.conv_reduce.bias"{[2.3048722743988037, 0.8668678998947144, 2.13803768157959, 1.4287266731262207, 2.083022356033325, 0.6134131550788879]}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              49 |  # node_Sigmoid_159
#                    %"val_159"<FLOAT,[batch_size,6,1,1]> ⬅️ ::Sigmoid(%"conv2d_16")
#              50 |  # node_silu_10
#                    %"silu_10"<FLOAT,[batch_size,6,1,1]> ⬅️ ::Mul(%"conv2d_16", %"val_159")
#              51 |  # node_conv2d_17
#                    %"conv2d_17"<FLOAT,[batch_size,144,1,1]> ⬅️ ::Conv(%"silu_10", %"blocks.1.1.se.conv_expand.weight"{...}, %"blocks.1.1.se.conv_expand.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              52 |  # node_sigmoid_3
#                    %"sigmoid_3"<FLOAT,[batch_size,144,1,1]> ⬅️ ::Sigmoid(%"conv2d_17")
#              53 |  # node_mul_346
#                    %"mul_346"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Mul(%"silu_9", %"sigmoid_3")
#              54 |  # node_Conv_1030
#                    %"getitem_30"<FLOAT,[batch_size,24,78,78]> ⬅️ ::Conv(%"mul_346", %"blocks.1.1.conv_pwl.weight"{...}, %"mul_346_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              55 |  # node_add_390
#                    %"add_390"<FLOAT,[batch_size,24,78,78]> ⬅️ ::Add(%"getitem_30", %"getitem_21")
#              56 |  # node_Conv_1032
#                    %"getitem_33"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Conv(%"add_390", %"blocks.1.2.conv_pw.weight"{...}, %"add_390_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              57 |  # node_Sigmoid_178
#                    %"val_178"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Sigmoid(%"getitem_33")
#              58 |  # node_silu_11
#                    %"silu_11"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Mul(%"getitem_33", %"val_178")
#              59 |  # node_Conv_1034
#                    %"getitem_36"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Conv(%"silu_11", %"blocks.1.2.conv_dw.weight"{...}, %"silu_11_bias"{...}) {group=144, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#              60 |  # node_Sigmoid_188
#                    %"val_188"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Sigmoid(%"getitem_36")
#              61 |  # node_silu_12
#                    %"silu_12"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Mul(%"getitem_36", %"val_188")
#              62 |  # node_mean_4
#                    %"mean_4"<FLOAT,[batch_size,144,1,1]> ⬅️ ::ReduceMean(%"silu_12", %"val_72"{[2, 3]}) {keepdims=1, noop_with_empty_axes=0}
#              63 |  # node_conv2d_21
#                    %"conv2d_21"<FLOAT,[batch_size,6,1,1]> ⬅️ ::Conv(%"mean_4", %"blocks.1.2.se.conv_reduce.weight"{...}, %"blocks.1.2.se.conv_reduce.bias"{[1.2229682207107544, 2.0036425590515137, 0.5707300901412964, 0.07628879696130753, 1.0951786041259766, 1.1301254034042358]}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              64 |  # node_Sigmoid_191
#                    %"val_191"<FLOAT,[batch_size,6,1,1]> ⬅️ ::Sigmoid(%"conv2d_21")
#              65 |  # node_silu_13
#                    %"silu_13"<FLOAT,[batch_size,6,1,1]> ⬅️ ::Mul(%"conv2d_21", %"val_191")
#              66 |  # node_conv2d_22
#                    %"conv2d_22"<FLOAT,[batch_size,144,1,1]> ⬅️ ::Conv(%"silu_13", %"blocks.1.2.se.conv_expand.weight"{...}, %"blocks.1.2.se.conv_expand.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              67 |  # node_sigmoid_4
#                    %"sigmoid_4"<FLOAT,[batch_size,144,1,1]> ⬅️ ::Sigmoid(%"conv2d_22")
#              68 |  # node_mul_428
#                    %"mul_428"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Mul(%"silu_12", %"sigmoid_4")
#              69 |  # node_Conv_1036
#                    %"getitem_39"<FLOAT,[batch_size,24,78,78]> ⬅️ ::Conv(%"mul_428", %"blocks.1.2.conv_pwl.weight"{...}, %"mul_428_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              70 |  # node_add_484
#                    %"add_484"<FLOAT,[batch_size,24,78,78]> ⬅️ ::Add(%"getitem_39", %"add_390")
#              71 |  # node_Conv_1038
#                    %"getitem_42"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Conv(%"add_484", %"blocks.2.0.conv_pw.weight"{...}, %"add_484_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              72 |  # node_Sigmoid_210
#                    %"val_210"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Sigmoid(%"getitem_42")
#              73 |  # node_silu_14
#                    %"silu_14"<FLOAT,[batch_size,144,78,78]> ⬅️ ::Mul(%"getitem_42", %"val_210")
#              74 |  # node_Conv_1040
#                    %"getitem_45"<FLOAT,[batch_size,144,39,39]> ⬅️ ::Conv(%"silu_14", %"blocks.2.0.conv_dw.weight"{...}, %"silu_14_bias"{...}) {group=144, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(2, 2, 2, 2)}
#              75 |  # node_Sigmoid_220
#                    %"val_220"<FLOAT,[batch_size,144,39,39]> ⬅️ ::Sigmoid(%"getitem_45")
#              76 |  # node_silu_15
#                    %"silu_15"<FLOAT,[batch_size,144,39,39]> ⬅️ ::Mul(%"getitem_45", %"val_220")
#              77 |  # node_mean_5
#                    %"mean_5"<FLOAT,[batch_size,144,1,1]> ⬅️ ::ReduceMean(%"silu_15", %"val_72"{[2, 3]}) {keepdims=1, noop_with_empty_axes=0}
#              78 |  # node_conv2d_26
#                    %"conv2d_26"<FLOAT,[batch_size,6,1,1]> ⬅️ ::Conv(%"mean_5", %"blocks.2.0.se.conv_reduce.weight"{...}, %"blocks.2.0.se.conv_reduce.bias"{[-0.7788673639297485, -0.0974101796746254, -0.35546576976776123, -0.6868922114372253, -0.3724120259284973, -0.11101813614368439]}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              79 |  # node_Sigmoid_223
#                    %"val_223"<FLOAT,[batch_size,6,1,1]> ⬅️ ::Sigmoid(%"conv2d_26")
#              80 |  # node_silu_16
#                    %"silu_16"<FLOAT,[batch_size,6,1,1]> ⬅️ ::Mul(%"conv2d_26", %"val_223")
#              81 |  # node_conv2d_27
#                    %"conv2d_27"<FLOAT,[batch_size,144,1,1]> ⬅️ ::Conv(%"silu_16", %"blocks.2.0.se.conv_expand.weight"{...}, %"blocks.2.0.se.conv_expand.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              82 |  # node_sigmoid_5
#                    %"sigmoid_5"<FLOAT,[batch_size,144,1,1]> ⬅️ ::Sigmoid(%"conv2d_27")
#              83 |  # node_mul_510
#                    %"mul_510"<FLOAT,[batch_size,144,39,39]> ⬅️ ::Mul(%"silu_15", %"sigmoid_5")
#              84 |  # node_Conv_1042
#                    %"getitem_48"<FLOAT,[batch_size,48,39,39]> ⬅️ ::Conv(%"mul_510", %"blocks.2.0.conv_pwl.weight"{...}, %"mul_510_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              85 |  # node_Conv_1044
#                    %"getitem_51"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Conv(%"getitem_48", %"blocks.2.1.conv_pw.weight"{...}, %"getitem_48_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              86 |  # node_Sigmoid_242
#                    %"val_242"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Sigmoid(%"getitem_51")
#              87 |  # node_silu_17
#                    %"silu_17"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Mul(%"getitem_51", %"val_242")
#              88 |  # node_Conv_1046
#                    %"getitem_54"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Conv(%"silu_17", %"blocks.2.1.conv_dw.weight"{...}, %"silu_17_bias"{...}) {group=288, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(2, 2, 2, 2)}
#              89 |  # node_Sigmoid_252
#                    %"val_252"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Sigmoid(%"getitem_54")
#              90 |  # node_silu_18
#                    %"silu_18"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Mul(%"getitem_54", %"val_252")
#              91 |  # node_mean_6
#                    %"mean_6"<FLOAT,[batch_size,288,1,1]> ⬅️ ::ReduceMean(%"silu_18", %"val_72"{[2, 3]}) {keepdims=1, noop_with_empty_axes=0}
#              92 |  # node_conv2d_31
#                    %"conv2d_31"<FLOAT,[batch_size,12,1,1]> ⬅️ ::Conv(%"mean_6", %"blocks.2.1.se.conv_reduce.weight"{...}, %"blocks.2.1.se.conv_reduce.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              93 |  # node_Sigmoid_255
#                    %"val_255"<FLOAT,[batch_size,12,1,1]> ⬅️ ::Sigmoid(%"conv2d_31")
#              94 |  # node_silu_19
#                    %"silu_19"<FLOAT,[batch_size,12,1,1]> ⬅️ ::Mul(%"conv2d_31", %"val_255")
#              95 |  # node_conv2d_32
#                    %"conv2d_32"<FLOAT,[batch_size,288,1,1]> ⬅️ ::Conv(%"silu_19", %"blocks.2.1.se.conv_expand.weight"{...}, %"blocks.2.1.se.conv_expand.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              96 |  # node_sigmoid_6
#                    %"sigmoid_6"<FLOAT,[batch_size,288,1,1]> ⬅️ ::Sigmoid(%"conv2d_32")
#              97 |  # node_mul_590
#                    %"mul_590"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Mul(%"silu_18", %"sigmoid_6")
#              98 |  # node_Conv_1048
#                    %"getitem_57"<FLOAT,[batch_size,48,39,39]> ⬅️ ::Conv(%"mul_590", %"blocks.2.1.conv_pwl.weight"{...}, %"mul_590_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#              99 |  # node_add_666
#                    %"add_666"<FLOAT,[batch_size,48,39,39]> ⬅️ ::Add(%"getitem_57", %"getitem_48")
#             100 |  # node_Conv_1050
#                    %"getitem_60"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Conv(%"add_666", %"blocks.2.2.conv_pw.weight"{...}, %"add_666_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             101 |  # node_Sigmoid_274
#                    %"val_274"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Sigmoid(%"getitem_60")
#             102 |  # node_silu_20
#                    %"silu_20"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Mul(%"getitem_60", %"val_274")
#             103 |  # node_Conv_1052
#                    %"getitem_63"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Conv(%"silu_20", %"blocks.2.2.conv_dw.weight"{...}, %"silu_20_bias"{...}) {group=288, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(2, 2, 2, 2)}
#             104 |  # node_Sigmoid_284
#                    %"val_284"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Sigmoid(%"getitem_63")
#             105 |  # node_silu_21
#                    %"silu_21"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Mul(%"getitem_63", %"val_284")
#             106 |  # node_mean_7
#                    %"mean_7"<FLOAT,[batch_size,288,1,1]> ⬅️ ::ReduceMean(%"silu_21", %"val_72"{[2, 3]}) {keepdims=1, noop_with_empty_axes=0}
#             107 |  # node_conv2d_36
#                    %"conv2d_36"<FLOAT,[batch_size,12,1,1]> ⬅️ ::Conv(%"mean_7", %"blocks.2.2.se.conv_reduce.weight"{...}, %"blocks.2.2.se.conv_reduce.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             108 |  # node_Sigmoid_287
#                    %"val_287"<FLOAT,[batch_size,12,1,1]> ⬅️ ::Sigmoid(%"conv2d_36")
#             109 |  # node_silu_22
#                    %"silu_22"<FLOAT,[batch_size,12,1,1]> ⬅️ ::Mul(%"conv2d_36", %"val_287")
#             110 |  # node_conv2d_37
#                    %"conv2d_37"<FLOAT,[batch_size,288,1,1]> ⬅️ ::Conv(%"silu_22", %"blocks.2.2.se.conv_expand.weight"{...}, %"blocks.2.2.se.conv_expand.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             111 |  # node_sigmoid_7
#                    %"sigmoid_7"<FLOAT,[batch_size,288,1,1]> ⬅️ ::Sigmoid(%"conv2d_37")
#             112 |  # node_mul_672
#                    %"mul_672"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Mul(%"silu_21", %"sigmoid_7")
#             113 |  # node_Conv_1054
#                    %"getitem_66"<FLOAT,[batch_size,48,39,39]> ⬅️ ::Conv(%"mul_672", %"blocks.2.2.conv_pwl.weight"{...}, %"mul_672_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             114 |  # node_add_760
#                    %"add_760"<FLOAT,[batch_size,48,39,39]> ⬅️ ::Add(%"getitem_66", %"add_666")
#             115 |  # node_Conv_1056
#                    %"getitem_69"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Conv(%"add_760", %"blocks.3.0.conv_pw.weight"{...}, %"add_760_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             116 |  # node_Sigmoid_306
#                    %"val_306"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Sigmoid(%"getitem_69")
#             117 |  # node_silu_23
#                    %"silu_23"<FLOAT,[batch_size,288,39,39]> ⬅️ ::Mul(%"getitem_69", %"val_306")
#             118 |  # node_Conv_1058
#                    %"getitem_72"<FLOAT,[batch_size,288,20,20]> ⬅️ ::Conv(%"silu_23", %"blocks.3.0.conv_dw.weight"{...}, %"silu_23_bias"{...}) {group=288, auto_pad='NOTSET', dilations=(1, 1), strides=(2, 2), pads=(1, 1, 1, 1)}
#             119 |  # node_Sigmoid_316
#                    %"val_316"<FLOAT,[batch_size,288,20,20]> ⬅️ ::Sigmoid(%"getitem_72")
#             120 |  # node_silu_24
#                    %"silu_24"<FLOAT,[batch_size,288,20,20]> ⬅️ ::Mul(%"getitem_72", %"val_316")
#             121 |  # node_mean_8
#                    %"mean_8"<FLOAT,[batch_size,288,1,1]> ⬅️ ::ReduceMean(%"silu_24", %"val_72"{[2, 3]}) {keepdims=1, noop_with_empty_axes=0}
#             122 |  # node_conv2d_41
#                    %"conv2d_41"<FLOAT,[batch_size,12,1,1]> ⬅️ ::Conv(%"mean_8", %"blocks.3.0.se.conv_reduce.weight"{...}, %"blocks.3.0.se.conv_reduce.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             123 |  # node_Sigmoid_319
#                    %"val_319"<FLOAT,[batch_size,12,1,1]> ⬅️ ::Sigmoid(%"conv2d_41")
#             124 |  # node_silu_25
#                    %"silu_25"<FLOAT,[batch_size,12,1,1]> ⬅️ ::Mul(%"conv2d_41", %"val_319")
#             125 |  # node_conv2d_42
#                    %"conv2d_42"<FLOAT,[batch_size,288,1,1]> ⬅️ ::Conv(%"silu_25", %"blocks.3.0.se.conv_expand.weight"{...}, %"blocks.3.0.se.conv_expand.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             126 |  # node_sigmoid_8
#                    %"sigmoid_8"<FLOAT,[batch_size,288,1,1]> ⬅️ ::Sigmoid(%"conv2d_42")
#             127 |  # node_mul_754
#                    %"mul_754"<FLOAT,[batch_size,288,20,20]> ⬅️ ::Mul(%"silu_24", %"sigmoid_8")
#             128 |  # node_Conv_1060
#                    %"getitem_75"<FLOAT,[batch_size,88,20,20]> ⬅️ ::Conv(%"mul_754", %"blocks.3.0.conv_pwl.weight"{...}, %"mul_754_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             129 |  # node_Conv_1062
#                    %"getitem_78"<FLOAT,[batch_size,528,20,20]> ⬅️ ::Conv(%"getitem_75", %"blocks.3.1.conv_pw.weight"{...}, %"getitem_75_bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             130 |  # node_Sigmoid_338
#                    %"val_338"<FLOAT,[batch_size,528,20,20]> ⬅️ ::Sigmoid(%"getitem_78")
#             131 |  # node_silu_26
#                    %"silu_26"<FLOAT,[batch_size,528,20,20]> ⬅️ ::Mul(%"getitem_78", %"val_338")
#             132 |  # node_Conv_1064
#                    %"getitem_81"<FLOAT,[batch_size,528,20,20]> ⬅️ ::Conv(%"silu_26", %"blocks.3.1.conv_dw.weight"{...}, %"silu_26_bias"{...}) {group=528, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(1, 1, 1, 1)}
#             133 |  # node_Sigmoid_348
#                    %"val_348"<FLOAT,[batch_size,528,20,20]> ⬅️ ::Sigmoid(%"getitem_81")
#             134 |  # node_silu_27
#                    %"silu_27"<FLOAT,[batch_size,528,20,20]> ⬅️ ::Mul(%"getitem_81", %"val_348")
#             135 |  # node_mean_9
#                    %"mean_9"<FLOAT,[batch_size,528,1,1]> ⬅️ ::ReduceMean(%"silu_27", %"val_72"{[2, 3]}) {keepdims=1, noop_with_empty_axes=0}
#             136 |  # node_conv2d_46
#                    %"conv2d_46"<FLOAT,[batch_size,22,1,1]> ⬅️ ::Conv(%"mean_9", %"blocks.3.1.se.conv_reduce.weight"{...}, %"blocks.3.1.se.conv_reduce.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             137 |  # node_Sigmoid_351
#                    %"val_351"<FLOAT,[batch_size,22,1,1]> ⬅️ ::Sigmoid(%"conv2d_46")
#             138 |  # node_silu_28
#                    %"silu_28"<FLOAT,[batch_size,22,1,1]> ⬅️ ::Mul(%"conv2d_46", %"val_351")
#             139 |  # node_conv2d_47
#                    %"conv2d_47"<FLOAT,[batch_size,528,1,1]> ⬅️ ::Conv(%"silu_28", %"blocks.3.1.se.conv_expand.weight"{...}, %"blocks.3.1.se.conv_expand.bias"{...}) {group=1, auto_pad='NOTSET', dilations=(1, 1), strides=(1, 1), pads=(0, 0, 0, 0)}
#             140 |  # node_sigmoid_9
# ...
#             b_blocks_2_2_bn2_running_var: BUFFER target='blocks.2.2.bn2.running_var' persistent=True
#             b_blocks_2_2_bn2_num_batches_tracked: BUFFER target='blocks.2.2.bn2.num_batches_tracked' persistent=True
#             b_blocks_2_2_bn3_running_mean: BUFFER target='blocks.2.2.bn3.running_mean' persistent=True
#             b_blocks_2_2_bn3_running_var: BUFFER target='blocks.2.2.bn3.running_var' persistent=True
#             b_blocks_2_2_bn3_num_batches_tracked: BUFFER target='blocks.2.2.bn3.num_batches_tracked' persistent=True
#             b_blocks_3_0_bn1_running_mean: BUFFER target='blocks.3.0.bn1.running_mean' persistent=True
#             b_blocks_3_0_bn1_running_var: BUFFER target='blocks.3.0.bn1.running_var' persistent=True
#             b_blocks_3_0_bn1_num_batches_tracked: BUFFER target='blocks.3.0.bn1.num_batches_tracked' persistent=True
#             b_blocks_3_0_bn2_running_mean: BUFFER target='blocks.3.0.bn2.running_mean' persistent=True
#             b_blocks_3_0_bn2_running_var: BUFFER target='blocks.3.0.bn2.running_var' persistent=True
#             b_blocks_3_0_bn2_num_batches_tracked: BUFFER target='blocks.3.0.bn2.num_batches_tracked' persistent=True
#             b_blocks_3_0_bn3_running_mean: BUFFER target='blocks.3.0.bn3.running_mean' persistent=True
#             b_blocks_3_0_bn3_running_var: BUFFER target='blocks.3.0.bn3.running_var' persistent=True
#             b_blocks_3_0_bn3_num_batches_tracked: BUFFER target='blocks.3.0.bn3.num_batches_tracked' persistent=True
#             b_blocks_3_1_bn1_running_mean: BUFFER target='blocks.3.1.bn1.running_mean' persistent=True
#             b_blocks_3_1_bn1_running_var: BUFFER target='blocks.3.1.bn1.running_var' persistent=True
#             b_blocks_3_1_bn1_num_batches_tracked: BUFFER target='blocks.3.1.bn1.num_batches_tracked' persistent=True
#             b_blocks_3_1_bn2_running_mean: BUFFER target='blocks.3.1.bn2.running_mean' persistent=True
#             b_blocks_3_1_bn2_running_var: BUFFER target='blocks.3.1.bn2.running_var' persistent=True
#             b_blocks_3_1_bn2_num_batches_tracked: BUFFER target='blocks.3.1.bn2.num_batches_tracked' persistent=True
#             b_blocks_3_1_bn3_running_mean: BUFFER target='blocks.3.1.bn3.running_mean' persistent=True
#             b_blocks_3_1_bn3_running_var: BUFFER target='blocks.3.1.bn3.running_var' persistent=True
#             b_blocks_3_1_bn3_num_batches_tracked: BUFFER target='blocks.3.1.bn3.num_batches_tracked' persistent=True
#             b_blocks_3_2_bn1_running_mean: BUFFER target='blocks.3.2.bn1.running_mean' persistent=True
#             b_blocks_3_2_bn1_running_var: BUFFER target='blocks.3.2.bn1.running_var' persistent=True
#             b_blocks_3_2_bn1_num_batches_tracked: BUFFER target='blocks.3.2.bn1.num_batches_tracked' persistent=True
#             b_blocks_3_2_bn2_running_mean: BUFFER target='blocks.3.2.bn2.running_mean' persistent=True
#             b_blocks_3_2_bn2_running_var: BUFFER target='blocks.3.2.bn2.running_var' persistent=True
#             b_blocks_3_2_bn2_num_batches_tracked: BUFFER target='blocks.3.2.bn2.num_batches_tracked' persistent=True
#             b_blocks_3_2_bn3_running_mean: BUFFER target='blocks.3.2.bn3.running_mean' persistent=True
#             b_blocks_3_2_bn3_running_var: BUFFER target='blocks.3.2.bn3.running_var' persistent=True
#             b_blocks_3_2_bn3_num_batches_tracked: BUFFER target='blocks.3.2.bn3.num_batches_tracked' persistent=True
#             b_blocks_3_3_bn1_running_mean: BUFFER target='blocks.3.3.bn1.running_mean' persistent=True
#             b_blocks_3_3_bn1_running_var: BUFFER target='blocks.3.3.bn1.running_var' persistent=True
#             b_blocks_3_3_bn1_num_batches_tracked: BUFFER target='blocks.3.3.bn1.num_batches_tracked' persistent=True
#             b_blocks_3_3_bn2_running_mean: BUFFER target='blocks.3.3.bn2.running_mean' persistent=True
#             b_blocks_3_3_bn2_running_var: BUFFER target='blocks.3.3.bn2.running_var' persistent=True
#             b_blocks_3_3_bn2_num_batches_tracked: BUFFER target='blocks.3.3.bn2.num_batches_tracked' persistent=True
#             b_blocks_3_3_bn3_running_mean: BUFFER target='blocks.3.3.bn3.running_mean' persistent=True
#             b_blocks_3_3_bn3_running_var: BUFFER target='blocks.3.3.bn3.running_var' persistent=True
#             b_blocks_3_3_bn3_num_batches_tracked: BUFFER target='blocks.3.3.bn3.num_batches_tracked' persistent=True
#             b_blocks_4_0_bn1_running_mean: BUFFER target='blocks.4.0.bn1.running_mean' persistent=True
#             b_blocks_4_0_bn1_running_var: BUFFER target='blocks.4.0.bn1.running_var' persistent=True
#             b_blocks_4_0_bn1_num_batches_tracked: BUFFER target='blocks.4.0.bn1.num_batches_tracked' persistent=True
#             b_blocks_4_0_bn2_running_mean: BUFFER target='blocks.4.0.bn2.running_mean' persistent=True
#             b_blocks_4_0_bn2_running_var: BUFFER target='blocks.4.0.bn2.running_var' persistent=True
#             b_blocks_4_0_bn2_num_batches_tracked: BUFFER target='blocks.4.0.bn2.num_batches_tracked' persistent=True
#             b_blocks_4_0_bn3_running_mean: BUFFER target='blocks.4.0.bn3.running_mean' persistent=True
#             b_blocks_4_0_bn3_running_var: BUFFER target='blocks.4.0.bn3.running_var' persistent=True
#             b_blocks_4_0_bn3_num_batches_tracked: BUFFER target='blocks.4.0.bn3.num_batches_tracked' persistent=True
#             b_blocks_4_1_bn1_running_mean: BUFFER target='blocks.4.1.bn1.running_mean' persistent=True
#             b_blocks_4_1_bn1_running_var: BUFFER target='blocks.4.1.bn1.running_var' persistent=True
#             b_blocks_4_1_bn1_num_batches_tracked: BUFFER target='blocks.4.1.bn1.num_batches_tracked' persistent=True
#             b_blocks_4_1_bn2_running_mean: BUFFER target='blocks.4.1.bn2.running_mean' persistent=True
#             b_blocks_4_1_bn2_running_var: BUFFER target='blocks.4.1.bn2.running_var' persistent=True
#             b_blocks_4_1_bn2_num_batches_tracked: BUFFER target='blocks.4.1.bn2.num_batches_tracked' persistent=True
#             b_blocks_4_1_bn3_running_mean: BUFFER target='blocks.4.1.bn3.running_mean' persistent=True
#             b_blocks_4_1_bn3_running_var: BUFFER target='blocks.4.1.bn3.running_var' persistent=True
#             b_blocks_4_1_bn3_num_batches_tracked: BUFFER target='blocks.4.1.bn3.num_batches_tracked' persistent=True
#             b_blocks_4_2_bn1_running_mean: BUFFER target='blocks.4.2.bn1.running_mean' persistent=True
#             b_blocks_4_2_bn1_running_var: BUFFER target='blocks.4.2.bn1.running_var' persistent=True
#             b_blocks_4_2_bn1_num_batches_tracked: BUFFER target='blocks.4.2.bn1.num_batches_tracked' persistent=True
#             b_blocks_4_2_bn2_running_mean: BUFFER target='blocks.4.2.bn2.running_mean' persistent=True
#             b_blocks_4_2_bn2_running_var: BUFFER target='blocks.4.2.bn2.running_var' persistent=True
#             b_blocks_4_2_bn2_num_batches_tracked: BUFFER target='blocks.4.2.bn2.num_batches_tracked' persistent=True
#             b_blocks_4_2_bn3_running_mean: BUFFER target='blocks.4.2.bn3.running_mean' persistent=True
#             b_blocks_4_2_bn3_running_var: BUFFER target='blocks.4.2.bn3.running_var' persistent=True
#             b_blocks_4_2_bn3_num_batches_tracked: BUFFER target='blocks.4.2.bn3.num_batches_tracked' persistent=True
#             b_blocks_4_3_bn1_running_mean: BUFFER target='blocks.4.3.bn1.running_mean' persistent=True
#             b_blocks_4_3_bn1_running_var: BUFFER target='blocks.4.3.bn1.running_var' persistent=True
#             b_blocks_4_3_bn1_num_batches_tracked: BUFFER target='blocks.4.3.bn1.num_batches_tracked' persistent=True
#             b_blocks_4_3_bn2_running_mean: BUFFER target='blocks.4.3.bn2.running_mean' persistent=True
#             b_blocks_4_3_bn2_running_var: BUFFER target='blocks.4.3.bn2.running_var' persistent=True
#             b_blocks_4_3_bn2_num_batches_tracked: BUFFER target='blocks.4.3.bn2.num_batches_tracked' persistent=True
#             b_blocks_4_3_bn3_running_mean: BUFFER target='blocks.4.3.bn3.running_mean' persistent=True
#             b_blocks_4_3_bn3_running_var: BUFFER target='blocks.4.3.bn3.running_var' persistent=True
#             b_blocks_4_3_bn3_num_batches_tracked: BUFFER target='blocks.4.3.bn3.num_batches_tracked' persistent=True
#             b_blocks_5_0_bn1_running_mean: BUFFER target='blocks.5.0.bn1.running_mean' persistent=True
#             b_blocks_5_0_bn1_running_var: BUFFER target='blocks.5.0.bn1.running_var' persistent=True
#             b_blocks_5_0_bn1_num_batches_tracked: BUFFER target='blocks.5.0.bn1.num_batches_tracked' persistent=True
#             b_blocks_5_0_bn2_running_mean: BUFFER target='blocks.5.0.bn2.running_mean' persistent=True
#             b_blocks_5_0_bn2_running_var: BUFFER target='blocks.5.0.bn2.running_var' persistent=True
#             b_blocks_5_0_bn2_num_batches_tracked: BUFFER target='blocks.5.0.bn2.num_batches_tracked' persistent=True
#             b_blocks_5_0_bn3_running_mean: BUFFER target='blocks.5.0.bn3.running_mean' persistent=True
#             b_blocks_5_0_bn3_running_var: BUFFER target='blocks.5.0.bn3.running_var' persistent=True
#             b_blocks_5_0_bn3_num_batches_tracked: BUFFER target='blocks.5.0.bn3.num_batches_tracked' persistent=True
#             b_blocks_5_1_bn1_running_mean: BUFFER target='blocks.5.1.bn1.running_mean' persistent=True
#             b_blocks_5_1_bn1_running_var: BUFFER target='blocks.5.1.bn1.running_var' persistent=True
#             b_blocks_5_1_bn1_num_batches_tracked: BUFFER target='blocks.5.1.bn1.num_batches_tracked' persistent=True
#             b_blocks_5_1_bn2_running_mean: BUFFER target='blocks.5.1.bn2.running_mean' persistent=True
#             b_blocks_5_1_bn2_running_var: BUFFER target='blocks.5.1.bn2.running_var' persistent=True
#             b_blocks_5_1_bn2_num_batches_tracked: BUFFER target='blocks.5.1.bn2.num_batches_tracked' persistent=True
#             b_blocks_5_1_bn3_running_mean: BUFFER target='blocks.5.1.bn3.running_mean' persistent=True
#             b_blocks_5_1_bn3_running_var: BUFFER target='blocks.5.1.bn3.running_var' persistent=True
#             b_blocks_5_1_bn3_num_batches_tracked: BUFFER target='blocks.5.1.bn3.num_batches_tracked' persistent=True
#             b_blocks_5_2_bn1_running_mean: BUFFER target='blocks.5.2.bn1.running_mean' persistent=True
#             b_blocks_5_2_bn1_running_var: BUFFER target='blocks.5.2.bn1.running_var' persistent=True
#             b_blocks_5_2_bn1_num_batches_tracked: BUFFER target='blocks.5.2.bn1.num_batches_tracked' persistent=True
#             b_blocks_5_2_bn2_running_mean: BUFFER target='blocks.5.2.bn2.running_mean' persistent=True
#             b_blocks_5_2_bn2_running_var: BUFFER target='blocks.5.2.bn2.running_var' persistent=True
#             b_blocks_5_2_bn2_num_batches_tracked: BUFFER target='blocks.5.2.bn2.num_batches_tracked' persistent=True
#             b_blocks_5_2_bn3_running_mean: BUFFER target='blocks.5.2.bn3.running_mean' persistent=True
#             b_blocks_5_2_bn3_running_var: BUFFER target='blocks.5.2.bn3.running_var' persistent=True
#             b_blocks_5_2_bn3_num_batches_tracked: BUFFER target='blocks.5.2.bn3.num_batches_tracked' persistent=True
#             b_blocks_5_3_bn1_running_mean: BUFFER target='blocks.5.3.bn1.running_mean' persistent=True
#             b_blocks_5_3_bn1_running_var: BUFFER target='blocks.5.3.bn1.running_var' persistent=True
#             b_blocks_5_3_bn1_num_batches_tracked: BUFFER target='blocks.5.3.bn1.num_batches_tracked' persistent=True
#             b_blocks_5_3_bn2_running_mean: BUFFER target='blocks.5.3.bn2.running_mean' persistent=True
#             b_blocks_5_3_bn2_running_var: BUFFER target='blocks.5.3.bn2.running_var' persistent=True
#             b_blocks_5_3_bn2_num_batches_tracked: BUFFER target='blocks.5.3.bn2.num_batches_tracked' persistent=True
#             b_blocks_5_3_bn3_running_mean: BUFFER target='blocks.5.3.bn3.running_mean' persistent=True
#             b_blocks_5_3_bn3_running_var: BUFFER target='blocks.5.3.bn3.running_var' persistent=True
#             b_blocks_5_3_bn3_num_batches_tracked: BUFFER target='blocks.5.3.bn3.num_batches_tracked' persistent=True
#             b_blocks_5_4_bn1_running_mean: BUFFER target='blocks.5.4.bn1.running_mean' persistent=True
#             b_blocks_5_4_bn1_running_var: BUFFER target='blocks.5.4.bn1.running_var' persistent=True
#             b_blocks_5_4_bn1_num_batches_tracked: BUFFER target='blocks.5.4.bn1.num_batches_tracked' persistent=True
#             b_blocks_5_4_bn2_running_mean: BUFFER target='blocks.5.4.bn2.running_mean' persistent=True
#             b_blocks_5_4_bn2_running_var: BUFFER target='blocks.5.4.bn2.running_var' persistent=True
#             b_blocks_5_4_bn2_num_batches_tracked: BUFFER target='blocks.5.4.bn2.num_batches_tracked' persistent=True
#             b_blocks_5_4_bn3_running_mean: BUFFER target='blocks.5.4.bn3.running_mean' persistent=True
#             b_blocks_5_4_bn3_running_var: BUFFER target='blocks.5.4.bn3.running_var' persistent=True
#             b_blocks_5_4_bn3_num_batches_tracked: BUFFER target='blocks.5.4.bn3.num_batches_tracked' persistent=True
#             b_blocks_6_0_bn1_running_mean: BUFFER target='blocks.6.0.bn1.running_mean' persistent=True
#             b_blocks_6_0_bn1_running_var: BUFFER target='blocks.6.0.bn1.running_var' persistent=True
#             b_blocks_6_0_bn1_num_batches_tracked: BUFFER target='blocks.6.0.bn1.num_batches_tracked' persistent=True
#             b_blocks_6_0_bn2_running_mean: BUFFER target='blocks.6.0.bn2.running_mean' persistent=True
#             b_blocks_6_0_bn2_running_var: BUFFER target='blocks.6.0.bn2.running_var' persistent=True
#             b_blocks_6_0_bn2_num_batches_tracked: BUFFER target='blocks.6.0.bn2.num_batches_tracked' persistent=True
#             b_blocks_6_0_bn3_running_mean: BUFFER target='blocks.6.0.bn3.running_mean' persistent=True
#             b_blocks_6_0_bn3_running_var: BUFFER target='blocks.6.0.bn3.running_var' persistent=True
#             b_blocks_6_0_bn3_num_batches_tracked: BUFFER target='blocks.6.0.bn3.num_batches_tracked' persistent=True
#             b_blocks_6_1_bn1_running_mean: BUFFER target='blocks.6.1.bn1.running_mean' persistent=True
#             b_blocks_6_1_bn1_running_var: BUFFER target='blocks.6.1.bn1.running_var' persistent=True
#             b_blocks_6_1_bn1_num_batches_tracked: BUFFER target='blocks.6.1.bn1.num_batches_tracked' persistent=True
#             b_blocks_6_1_bn2_running_mean: BUFFER target='blocks.6.1.bn2.running_mean' persistent=True
#             b_blocks_6_1_bn2_running_var: BUFFER target='blocks.6.1.bn2.running_var' persistent=True
#             b_blocks_6_1_bn2_num_batches_tracked: BUFFER target='blocks.6.1.bn2.num_batches_tracked' persistent=True
#             b_blocks_6_1_bn3_running_mean: BUFFER target='blocks.6.1.bn3.running_mean' persistent=True
#             b_blocks_6_1_bn3_running_var: BUFFER target='blocks.6.1.bn3.running_var' persistent=True
#             b_blocks_6_1_bn3_num_batches_tracked: BUFFER target='blocks.6.1.bn3.num_batches_tracked' persistent=True
#             b_bn2_running_mean: BUFFER target='bn2.running_mean' persistent=True
#             b_bn2_running_var: BUFFER target='bn2.running_var' persistent=True
#             b_bn2_num_batches_tracked: BUFFER target='bn2.num_batches_tracked' persistent=True
#             b_classifier_1_running_mean: BUFFER target='classifier.1.running_mean' persistent=True
#             b_classifier_1_running_var: BUFFER target='classifier.1.running_var' persistent=True
#             b_classifier_1_num_batches_tracked: BUFFER target='classifier.1.num_batches_tracked' persistent=True
#             b_classifier_5_running_mean: BUFFER target='classifier.5.running_mean' persistent=True
#             b_classifier_5_running_var: BUFFER target='classifier.5.running_var' persistent=True
#             b_classifier_5_num_batches_tracked: BUFFER target='classifier.5.num_batches_tracked' persistent=True
#             x: USER_INPUT
#
#             # outputs
#             linear_2: USER_OUTPUT
#
#         Range constraints: {s77: VR[0, 65535]}
#
# )

# %% [markdown]
# ## Testing the model

# %%
import onnx

# Load the ONNX model
loaded_model = onnx.load("model_v5.onnx")

# Check that the IR is well formed
onnx.checker.check_model(loaded_model)

# Print a human readable representation of the graph
print(onnx.helper.printable_graph(loaded_model.graph))

print(loaded_model.graph.input[0].type.tensor_type.shape)
# Out:
# graph main_graph (
#   %x[FLOAT, batch_sizex6x310x310]
# ) initializers (
#   %blocks.0.0.conv_dw.weight[FLOAT, 32x1x3x3]
#   %blocks.0.0.se.conv_reduce.weight[FLOAT, 8x32x1x1]
#   %blocks.0.0.se.conv_reduce.bias[FLOAT, 8]
#   %blocks.0.0.se.conv_expand.weight[FLOAT, 32x8x1x1]
#   %blocks.0.0.se.conv_expand.bias[FLOAT, 32]
#   %blocks.0.0.conv_pw.weight[FLOAT, 16x32x1x1]
#   %blocks.0.1.conv_dw.weight[FLOAT, 16x1x3x3]
#   %blocks.0.1.se.conv_reduce.weight[FLOAT, 4x16x1x1]
#   %blocks.0.1.se.conv_reduce.bias[FLOAT, 4]
#   %blocks.0.1.se.conv_expand.weight[FLOAT, 16x4x1x1]
#   %blocks.0.1.se.conv_expand.bias[FLOAT, 16]
#   %blocks.0.1.conv_pw.weight[FLOAT, 16x16x1x1]
#   %blocks.1.0.conv_dw.weight[FLOAT, 96x1x3x3]
#   %blocks.1.0.se.conv_reduce.weight[FLOAT, 4x96x1x1]
#   %blocks.1.0.se.conv_reduce.bias[FLOAT, 4]
#   %blocks.1.0.se.conv_expand.weight[FLOAT, 96x4x1x1]
#   %blocks.1.0.se.conv_expand.bias[FLOAT, 96]
#   %blocks.1.1.se.conv_reduce.weight[FLOAT, 6x144x1x1]
#   %blocks.1.1.se.conv_reduce.bias[FLOAT, 6]
#   %blocks.1.1.se.conv_expand.weight[FLOAT, 144x6x1x1]
#   %blocks.1.1.se.conv_expand.bias[FLOAT, 144]
#   %blocks.1.2.se.conv_reduce.weight[FLOAT, 6x144x1x1]
#   %blocks.1.2.se.conv_reduce.bias[FLOAT, 6]
#   %blocks.1.2.se.conv_expand.weight[FLOAT, 144x6x1x1]
#   %blocks.1.2.se.conv_expand.bias[FLOAT, 144]
#   %blocks.2.0.se.conv_reduce.weight[FLOAT, 6x144x1x1]
#   %blocks.2.0.se.conv_reduce.bias[FLOAT, 6]
#   %blocks.2.0.se.conv_expand.weight[FLOAT, 144x6x1x1]
#   %blocks.2.0.se.conv_expand.bias[FLOAT, 144]
#   %blocks.2.1.se.conv_reduce.bias[FLOAT, 12]
#   %blocks.2.1.se.conv_expand.bias[FLOAT, 288]
#   %blocks.2.2.se.conv_reduce.bias[FLOAT, 12]
#   %blocks.2.2.se.conv_expand.bias[FLOAT, 288]
#   %blocks.3.0.se.conv_reduce.bias[FLOAT, 12]
#   %blocks.3.0.se.conv_expand.bias[FLOAT, 288]
#   %blocks.3.1.se.conv_reduce.bias[FLOAT, 22]
#   %blocks.3.1.se.conv_expand.bias[FLOAT, 528]
#   %blocks.3.2.se.conv_reduce.bias[FLOAT, 22]
#   %blocks.3.2.se.conv_expand.bias[FLOAT, 528]
#   %blocks.3.3.se.conv_reduce.bias[FLOAT, 22]
#   %blocks.3.3.se.conv_expand.bias[FLOAT, 528]
#   %blocks.4.0.se.conv_reduce.bias[FLOAT, 22]
#   %blocks.4.0.se.conv_expand.bias[FLOAT, 528]
#   %blocks.4.1.se.conv_reduce.bias[FLOAT, 30]
#   %blocks.4.1.se.conv_expand.bias[FLOAT, 720]
#   %blocks.4.2.se.conv_reduce.bias[FLOAT, 30]
#   %blocks.4.2.se.conv_expand.bias[FLOAT, 720]
#   %blocks.4.3.se.conv_reduce.bias[FLOAT, 30]
#   %blocks.4.3.se.conv_expand.bias[FLOAT, 720]
#   %blocks.5.0.se.conv_reduce.bias[FLOAT, 30]
#   %blocks.5.0.se.conv_expand.bias[FLOAT, 720]
#   %blocks.5.1.se.conv_reduce.bias[FLOAT, 52]
#   %blocks.5.2.se.conv_reduce.bias[FLOAT, 52]
#   %blocks.5.3.se.conv_reduce.bias[FLOAT, 52]
#   %blocks.5.4.se.conv_reduce.bias[FLOAT, 52]
#   %blocks.6.0.se.conv_reduce.bias[FLOAT, 52]
#   %blocks.6.1.se.conv_reduce.bias[FLOAT, 88]
#   %classifier.0.bias[FLOAT, 512]
#   %classifier.4.bias[FLOAT, 256]
#   %classifier.8.weight[FLOAT, 2x256]
#   %classifier.8.bias[FLOAT, 2]
#   %conv_stem.weight[FLOAT, 32x6x3x3]
#   %blocks.1.0.conv_pw.weight[FLOAT, 96x16x1x1]
#   %blocks.1.0.conv_pwl.weight[FLOAT, 24x96x1x1]
#   %blocks.1.1.conv_pw.weight[FLOAT, 144x24x1x1]
#   %blocks.1.1.conv_dw.weight[FLOAT, 144x1x3x3]
#   %blocks.1.1.conv_pwl.weight[FLOAT, 24x144x1x1]
#   %blocks.1.2.conv_pw.weight[FLOAT, 144x24x1x1]
#   %blocks.1.2.conv_dw.weight[FLOAT, 144x1x3x3]
#   %blocks.1.2.conv_pwl.weight[FLOAT, 24x144x1x1]
#   %blocks.2.0.conv_pw.weight[FLOAT, 144x24x1x1]
#   %blocks.2.0.conv_dw.weight[FLOAT, 144x1x5x5]
#   %blocks.2.0.conv_pwl.weight[FLOAT, 48x144x1x1]
#   %blocks.2.1.conv_pw.weight[FLOAT, 288x48x1x1]
#   %blocks.2.1.conv_dw.weight[FLOAT, 288x1x5x5]
#   %blocks.2.1.se.conv_reduce.weight[FLOAT, 12x288x1x1]
#   %blocks.2.1.se.conv_expand.weight[FLOAT, 288x12x1x1]
#   %blocks.2.1.conv_pwl.weight[FLOAT, 48x288x1x1]
#   %blocks.2.2.conv_pw.weight[FLOAT, 288x48x1x1]
#   %blocks.2.2.conv_dw.weight[FLOAT, 288x1x5x5]
#   %blocks.2.2.se.conv_reduce.weight[FLOAT, 12x288x1x1]
#   %blocks.2.2.se.conv_expand.weight[FLOAT, 288x12x1x1]
#   %blocks.2.2.conv_pwl.weight[FLOAT, 48x288x1x1]
#   %blocks.3.0.conv_pw.weight[FLOAT, 288x48x1x1]
#   %blocks.3.0.conv_dw.weight[FLOAT, 288x1x3x3]
#   %blocks.3.0.se.conv_reduce.weight[FLOAT, 12x288x1x1]
#   %blocks.3.0.se.conv_expand.weight[FLOAT, 288x12x1x1]
#   %blocks.3.0.conv_pwl.weight[FLOAT, 88x288x1x1]
#   %blocks.3.1.conv_pw.weight[FLOAT, 528x88x1x1]
#   %blocks.3.1.conv_dw.weight[FLOAT, 528x1x3x3]
#   %blocks.3.1.se.conv_reduce.weight[FLOAT, 22x528x1x1]
#   %blocks.3.1.se.conv_expand.weight[FLOAT, 528x22x1x1]
#   %blocks.3.1.conv_pwl.weight[FLOAT, 88x528x1x1]
#   %blocks.3.2.conv_pw.weight[FLOAT, 528x88x1x1]
#   %blocks.3.2.conv_dw.weight[FLOAT, 528x1x3x3]
#   %blocks.3.2.se.conv_reduce.weight[FLOAT, 22x528x1x1]
#   %blocks.3.2.se.conv_expand.weight[FLOAT, 528x22x1x1]
#   %blocks.3.2.conv_pwl.weight[FLOAT, 88x528x1x1]
#   %blocks.3.3.conv_pw.weight[FLOAT, 528x88x1x1]
#   %blocks.3.3.conv_dw.weight[FLOAT, 528x1x3x3]
#   %blocks.3.3.se.conv_reduce.weight[FLOAT, 22x528x1x1]
#   %blocks.3.3.se.conv_expand.weight[FLOAT, 528x22x1x1]
#   %blocks.3.3.conv_pwl.weight[FLOAT, 88x528x1x1]
#   %blocks.4.0.conv_pw.weight[FLOAT, 528x88x1x1]
#   %blocks.4.0.conv_dw.weight[FLOAT, 528x1x5x5]
#   %blocks.4.0.se.conv_reduce.weight[FLOAT, 22x528x1x1]
#   %blocks.4.0.se.conv_expand.weight[FLOAT, 528x22x1x1]
#   %blocks.4.0.conv_pwl.weight[FLOAT, 120x528x1x1]
#   %blocks.4.1.conv_pw.weight[FLOAT, 720x120x1x1]
#   %blocks.4.1.conv_dw.weight[FLOAT, 720x1x5x5]
#   %blocks.4.1.se.conv_reduce.weight[FLOAT, 30x720x1x1]
#   %blocks.4.1.se.conv_expand.weight[FLOAT, 720x30x1x1]
#   %blocks.4.1.conv_pwl.weight[FLOAT, 120x720x1x1]
#   %blocks.4.2.conv_pw.weight[FLOAT, 720x120x1x1]
#   %blocks.4.2.conv_dw.weight[FLOAT, 720x1x5x5]
#   %blocks.4.2.se.conv_reduce.weight[FLOAT, 30x720x1x1]
#   %blocks.4.2.se.conv_expand.weight[FLOAT, 720x30x1x1]
#   %blocks.4.2.conv_pwl.weight[FLOAT, 120x720x1x1]
#   %blocks.4.3.conv_pw.weight[FLOAT, 720x120x1x1]
#   %blocks.4.3.conv_dw.weight[FLOAT, 720x1x5x5]
#   %blocks.4.3.se.conv_reduce.weight[FLOAT, 30x720x1x1]
#   %blocks.4.3.se.conv_expand.weight[FLOAT, 720x30x1x1]
#   %blocks.4.3.conv_pwl.weight[FLOAT, 120x720x1x1]
#   %blocks.5.0.conv_pw.weight[FLOAT, 720x120x1x1]
#   %blocks.5.0.conv_dw.weight[FLOAT, 720x1x5x5]
#   %blocks.5.0.se.conv_reduce.weight[FLOAT, 30x720x1x1]
#   %blocks.5.0.se.conv_expand.weight[FLOAT, 720x30x1x1]
#   %blocks.5.0.conv_pwl.weight[FLOAT, 208x720x1x1]
#   %blocks.5.1.conv_pw.weight[FLOAT, 1248x208x1x1]
#   %blocks.5.1.conv_dw.weight[FLOAT, 1248x1x5x5]
#   %blocks.5.1.se.conv_reduce.weight[FLOAT, 52x1248x1x1]
#   %blocks.5.1.se.conv_expand.weight[FLOAT, 1248x52x1x1]
#   %blocks.5.1.se.conv_expand.bias[FLOAT, 1248]
#   %blocks.5.1.conv_pwl.weight[FLOAT, 208x1248x1x1]
#   %blocks.5.2.conv_pw.weight[FLOAT, 1248x208x1x1]
#   %blocks.5.2.conv_dw.weight[FLOAT, 1248x1x5x5]
#   %blocks.5.2.se.conv_reduce.weight[FLOAT, 52x1248x1x1]
#   %blocks.5.2.se.conv_expand.weight[FLOAT, 1248x52x1x1]
#   %blocks.5.2.se.conv_expand.bias[FLOAT, 1248]
#   %blocks.5.2.conv_pwl.weight[FLOAT, 208x1248x1x1]
#   %blocks.5.3.conv_pw.weight[FLOAT, 1248x208x1x1]
#   %blocks.5.3.conv_dw.weight[FLOAT, 1248x1x5x5]
#   %blocks.5.3.se.conv_reduce.weight[FLOAT, 52x1248x1x1]
#   %blocks.5.3.se.conv_expand.weight[FLOAT, 1248x52x1x1]
#   %blocks.5.3.se.conv_expand.bias[FLOAT, 1248]
#   %blocks.5.3.conv_pwl.weight[FLOAT, 208x1248x1x1]
#   %blocks.5.4.conv_pw.weight[FLOAT, 1248x208x1x1]
#   %blocks.5.4.conv_dw.weight[FLOAT, 1248x1x5x5]
#   %blocks.5.4.se.conv_reduce.weight[FLOAT, 52x1248x1x1]
#   %blocks.5.4.se.conv_expand.weight[FLOAT, 1248x52x1x1]
#   %blocks.5.4.se.conv_expand.bias[FLOAT, 1248]
#   %blocks.5.4.conv_pwl.weight[FLOAT, 208x1248x1x1]
#   %blocks.6.0.conv_pw.weight[FLOAT, 1248x208x1x1]
#   %blocks.6.0.conv_dw.weight[FLOAT, 1248x1x3x3]
#   %blocks.6.0.se.conv_reduce.weight[FLOAT, 52x1248x1x1]
#   %blocks.6.0.se.conv_expand.weight[FLOAT, 1248x52x1x1]
#   %blocks.6.0.se.conv_expand.bias[FLOAT, 1248]
#   %blocks.6.0.conv_pwl.weight[FLOAT, 352x1248x1x1]
#   %blocks.6.1.conv_pw.weight[FLOAT, 2112x352x1x1]
#   %blocks.6.1.conv_dw.weight[FLOAT, 2112x1x3x3]
#   %blocks.6.1.se.conv_reduce.weight[FLOAT, 88x2112x1x1]
#   %blocks.6.1.se.conv_expand.weight[FLOAT, 2112x88x1x1]
#   %blocks.6.1.se.conv_expand.bias[FLOAT, 2112]
#   %blocks.6.1.conv_pwl.weight[FLOAT, 352x2112x1x1]
#   %conv_head.weight[FLOAT, 1408x352x1x1]
#   %classifier.0.weight[FLOAT, 512x1408]
#   %classifier.4.weight[FLOAT, 256x512]
#   %val_72[INT64, 2]
#   %val_789[INT64, 2]
#   %x_bias[FLOAT, 32]
#   %silu_bias[FLOAT, 32]
#   %mul_128_bias[FLOAT, 16]
#   %getitem_6_bias[FLOAT, 16]
#   %mul_184_bias[FLOAT, 16]
#   %add_208_bias[FLOAT, 96]
#   %silu_5_bias[FLOAT, 96]
#   %mul_266_bias[FLOAT, 24]
#   %getitem_21_bias[FLOAT, 144]
#   %silu_8_bias[FLOAT, 144]
#   %mul_346_bias[FLOAT, 24]
#   %add_390_bias[FLOAT, 144]
#   %silu_11_bias[FLOAT, 144]
#   %mul_428_bias[FLOAT, 24]
#   %add_484_bias[FLOAT, 144]
#   %silu_14_bias[FLOAT, 144]
#   %mul_510_bias[FLOAT, 48]
#   %getitem_48_bias[FLOAT, 288]
#   %silu_17_bias[FLOAT, 288]
#   %mul_590_bias[FLOAT, 48]
#   %add_666_bias[FLOAT, 288]
#   %silu_20_bias[FLOAT, 288]
#   %mul_672_bias[FLOAT, 48]
#   %add_760_bias[FLOAT, 288]
#   %silu_23_bias[FLOAT, 288]
#   %mul_754_bias[FLOAT, 88]
#   %getitem_75_bias[FLOAT, 528]
#   %silu_26_bias[FLOAT, 528]
#   %mul_834_bias[FLOAT, 88]
#   %add_942_bias[FLOAT, 528]
#   %silu_29_bias[FLOAT, 528]
#   %mul_916_bias[FLOAT, 88]
#   %add_1036_bias[FLOAT, 528]
#   %silu_32_bias[FLOAT, 528]
#   %mul_998_bias[FLOAT, 88]
#   %add_1130_bias[FLOAT, 528]
#   %silu_35_bias[FLOAT, 528]
#   %mul_1080_bias[FLOAT, 120]
#   %getitem_111_bias[FLOAT, 720]
#   %silu_38_bias[FLOAT, 720]
#   %mul_1160_bias[FLOAT, 120]
#   %add_1312_bias[FLOAT, 720]
#   %silu_41_bias[FLOAT, 720]
#   %mul_1242_bias[FLOAT, 120]
#   %add_1406_bias[FLOAT, 720]
#   %silu_44_bias[FLOAT, 720]
#   %mul_1324_bias[FLOAT, 120]
#   %add_1500_bias[FLOAT, 720]
#   %silu_47_bias[FLOAT, 720]
#   %mul_1406_bias[FLOAT, 208]
#   %getitem_147_bias[FLOAT, 1248]
#   %silu_50_bias[FLOAT, 1248]
#   %mul_1486_bias[FLOAT, 208]
#   %add_1682_bias[FLOAT, 1248]
#   %silu_53_bias[FLOAT, 1248]
#   %mul_1568_bias[FLOAT, 208]
#   %add_1776_bias[FLOAT, 1248]
#   %silu_56_bias[FLOAT, 1248]
#   %mul_1650_bias[FLOAT, 208]
#   %add_1870_bias[FLOAT, 1248]
#   %silu_59_bias[FLOAT, 1248]
#   %mul_1732_bias[FLOAT, 208]
#   %add_1964_bias[FLOAT, 1248]
#   %silu_62_bias[FLOAT, 1248]
#   %mul_1814_bias[FLOAT, 352]
#   %getitem_192_bias[FLOAT, 2112]
#   %silu_65_bias[FLOAT, 2112]
#   %mul_1894_bias[FLOAT, 352]
#   %add_2146_bias[FLOAT, 1408]
#   %val_792[INT64, 1]
# ) {
#   %val_0 = Shape[end = 1, start = 0](%x)
#   %getitem = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [1, 1, 1, 1], strides = [2, 2]](%x, %conv_stem.weight, %x_bias)
#   %val_59 = Sigmoid(%getitem)
#   %silu = Mul(%getitem, %val_59)
#   %getitem_3 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 32, pads = [1, 1, 1, 1], strides = [1, 1]](%silu, %blocks.0.0.conv_dw.weight, %silu_bias)
#   %val_69 = Sigmoid(%getitem_3)
#   %silu_1 = Mul(%getitem_3, %val_69)
#   %mean = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_1, %val_72)
#   %conv2d_2 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean, %blocks.0.0.se.conv_reduce.weight, %blocks.0.0.se.conv_reduce.bias)
#   %val_73 = Sigmoid(%conv2d_2)
#   %silu_2 = Mul(%conv2d_2, %val_73)
#   %conv2d_3 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_2, %blocks.0.0.se.conv_expand.weight, %blocks.0.0.se.conv_expand.bias)
#   %sigmoid = Sigmoid(%conv2d_3)
#   %mul_128 = Mul(%silu_1, %sigmoid)
#   %getitem_6 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_128, %blocks.0.0.conv_pw.weight, %mul_128_bias)
#   %getitem_9 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 16, pads = [1, 1, 1, 1], strides = [1, 1]](%getitem_6, %blocks.0.1.conv_dw.weight, %getitem_6_bias)
#   %val_92 = Sigmoid(%getitem_9)
#   %silu_3 = Mul(%getitem_9, %val_92)
#   %mean_1 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_3, %val_72)
#   %conv2d_6 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_1, %blocks.0.1.se.conv_reduce.weight, %blocks.0.1.se.conv_reduce.bias)
#   %val_95 = Sigmoid(%conv2d_6)
#   %silu_4 = Mul(%conv2d_6, %val_95)
#   %conv2d_7 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_4, %blocks.0.1.se.conv_expand.weight, %blocks.0.1.se.conv_expand.bias)
#   %sigmoid_1 = Sigmoid(%conv2d_7)
#   %mul_184 = Mul(%silu_3, %sigmoid_1)
#   %getitem_12 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_184, %blocks.0.1.conv_pw.weight, %mul_184_bias)
#   %add_208 = Add(%getitem_12, %getitem_6)
#   %getitem_15 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_208, %blocks.1.0.conv_pw.weight, %add_208_bias)
#   %val_114 = Sigmoid(%getitem_15)
#   %silu_5 = Mul(%getitem_15, %val_114)
#   %getitem_18 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 96, pads = [1, 1, 1, 1], strides = [2, 2]](%silu_5, %blocks.1.0.conv_dw.weight, %silu_5_bias)
#   %val_124 = Sigmoid(%getitem_18)
#   %silu_6 = Mul(%getitem_18, %val_124)
#   %mean_2 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_6, %val_72)
#   %conv2d_11 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_2, %blocks.1.0.se.conv_reduce.weight, %blocks.1.0.se.conv_reduce.bias)
#   %val_127 = Sigmoid(%conv2d_11)
#   %silu_7 = Mul(%conv2d_11, %val_127)
#   %conv2d_12 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_7, %blocks.1.0.se.conv_expand.weight, %blocks.1.0.se.conv_expand.bias)
#   %sigmoid_2 = Sigmoid(%conv2d_12)
#   %mul_266 = Mul(%silu_6, %sigmoid_2)
#   %getitem_21 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_266, %blocks.1.0.conv_pwl.weight, %mul_266_bias)
#   %getitem_24 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%getitem_21, %blocks.1.1.conv_pw.weight, %getitem_21_bias)
#   %val_146 = Sigmoid(%getitem_24)
#   %silu_8 = Mul(%getitem_24, %val_146)
#   %getitem_27 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 144, pads = [1, 1, 1, 1], strides = [1, 1]](%silu_8, %blocks.1.1.conv_dw.weight, %silu_8_bias)
#   %val_156 = Sigmoid(%getitem_27)
#   %silu_9 = Mul(%getitem_27, %val_156)
#   %mean_3 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_9, %val_72)
#   %conv2d_16 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_3, %blocks.1.1.se.conv_reduce.weight, %blocks.1.1.se.conv_reduce.bias)
#   %val_159 = Sigmoid(%conv2d_16)
#   %silu_10 = Mul(%conv2d_16, %val_159)
#   %conv2d_17 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_10, %blocks.1.1.se.conv_expand.weight, %blocks.1.1.se.conv_expand.bias)
#   %sigmoid_3 = Sigmoid(%conv2d_17)
#   %mul_346 = Mul(%silu_9, %sigmoid_3)
#   %getitem_30 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_346, %blocks.1.1.conv_pwl.weight, %mul_346_bias)
#   %add_390 = Add(%getitem_30, %getitem_21)
#   %getitem_33 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_390, %blocks.1.2.conv_pw.weight, %add_390_bias)
#   %val_178 = Sigmoid(%getitem_33)
#   %silu_11 = Mul(%getitem_33, %val_178)
#   %getitem_36 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 144, pads = [1, 1, 1, 1], strides = [1, 1]](%silu_11, %blocks.1.2.conv_dw.weight, %silu_11_bias)
#   %val_188 = Sigmoid(%getitem_36)
#   %silu_12 = Mul(%getitem_36, %val_188)
#   %mean_4 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_12, %val_72)
#   %conv2d_21 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_4, %blocks.1.2.se.conv_reduce.weight, %blocks.1.2.se.conv_reduce.bias)
#   %val_191 = Sigmoid(%conv2d_21)
#   %silu_13 = Mul(%conv2d_21, %val_191)
#   %conv2d_22 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_13, %blocks.1.2.se.conv_expand.weight, %blocks.1.2.se.conv_expand.bias)
#   %sigmoid_4 = Sigmoid(%conv2d_22)
#   %mul_428 = Mul(%silu_12, %sigmoid_4)
#   %getitem_39 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_428, %blocks.1.2.conv_pwl.weight, %mul_428_bias)
#   %add_484 = Add(%getitem_39, %add_390)
#   %getitem_42 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_484, %blocks.2.0.conv_pw.weight, %add_484_bias)
#   %val_210 = Sigmoid(%getitem_42)
#   %silu_14 = Mul(%getitem_42, %val_210)
#   %getitem_45 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 144, pads = [2, 2, 2, 2], strides = [2, 2]](%silu_14, %blocks.2.0.conv_dw.weight, %silu_14_bias)
#   %val_220 = Sigmoid(%getitem_45)
#   %silu_15 = Mul(%getitem_45, %val_220)
#   %mean_5 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_15, %val_72)
#   %conv2d_26 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_5, %blocks.2.0.se.conv_reduce.weight, %blocks.2.0.se.conv_reduce.bias)
#   %val_223 = Sigmoid(%conv2d_26)
#   %silu_16 = Mul(%conv2d_26, %val_223)
#   %conv2d_27 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_16, %blocks.2.0.se.conv_expand.weight, %blocks.2.0.se.conv_expand.bias)
#   %sigmoid_5 = Sigmoid(%conv2d_27)
#   %mul_510 = Mul(%silu_15, %sigmoid_5)
#   %getitem_48 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_510, %blocks.2.0.conv_pwl.weight, %mul_510_bias)
#   %getitem_51 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%getitem_48, %blocks.2.1.conv_pw.weight, %getitem_48_bias)
#   %val_242 = Sigmoid(%getitem_51)
#   %silu_17 = Mul(%getitem_51, %val_242)
#   %getitem_54 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 288, pads = [2, 2, 2, 2], strides = [1, 1]](%silu_17, %blocks.2.1.conv_dw.weight, %silu_17_bias)
#   %val_252 = Sigmoid(%getitem_54)
#   %silu_18 = Mul(%getitem_54, %val_252)
#   %mean_6 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_18, %val_72)
#   %conv2d_31 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_6, %blocks.2.1.se.conv_reduce.weight, %blocks.2.1.se.conv_reduce.bias)
#   %val_255 = Sigmoid(%conv2d_31)
#   %silu_19 = Mul(%conv2d_31, %val_255)
#   %conv2d_32 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_19, %blocks.2.1.se.conv_expand.weight, %blocks.2.1.se.conv_expand.bias)
#   %sigmoid_6 = Sigmoid(%conv2d_32)
#   %mul_590 = Mul(%silu_18, %sigmoid_6)
#   %getitem_57 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_590, %blocks.2.1.conv_pwl.weight, %mul_590_bias)
#   %add_666 = Add(%getitem_57, %getitem_48)
#   %getitem_60 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_666, %blocks.2.2.conv_pw.weight, %add_666_bias)
#   %val_274 = Sigmoid(%getitem_60)
#   %silu_20 = Mul(%getitem_60, %val_274)
#   %getitem_63 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 288, pads = [2, 2, 2, 2], strides = [1, 1]](%silu_20, %blocks.2.2.conv_dw.weight, %silu_20_bias)
#   %val_284 = Sigmoid(%getitem_63)
#   %silu_21 = Mul(%getitem_63, %val_284)
#   %mean_7 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_21, %val_72)
#   %conv2d_36 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_7, %blocks.2.2.se.conv_reduce.weight, %blocks.2.2.se.conv_reduce.bias)
#   %val_287 = Sigmoid(%conv2d_36)
#   %silu_22 = Mul(%conv2d_36, %val_287)
#   %conv2d_37 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_22, %blocks.2.2.se.conv_expand.weight, %blocks.2.2.se.conv_expand.bias)
#   %sigmoid_7 = Sigmoid(%conv2d_37)
#   %mul_672 = Mul(%silu_21, %sigmoid_7)
#   %getitem_66 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_672, %blocks.2.2.conv_pwl.weight, %mul_672_bias)
#   %add_760 = Add(%getitem_66, %add_666)
#   %getitem_69 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_760, %blocks.3.0.conv_pw.weight, %add_760_bias)
#   %val_306 = Sigmoid(%getitem_69)
#   %silu_23 = Mul(%getitem_69, %val_306)
#   %getitem_72 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 288, pads = [1, 1, 1, 1], strides = [2, 2]](%silu_23, %blocks.3.0.conv_dw.weight, %silu_23_bias)
#   %val_316 = Sigmoid(%getitem_72)
#   %silu_24 = Mul(%getitem_72, %val_316)
#   %mean_8 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_24, %val_72)
#   %conv2d_41 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_8, %blocks.3.0.se.conv_reduce.weight, %blocks.3.0.se.conv_reduce.bias)
#   %val_319 = Sigmoid(%conv2d_41)
#   %silu_25 = Mul(%conv2d_41, %val_319)
#   %conv2d_42 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_25, %blocks.3.0.se.conv_expand.weight, %blocks.3.0.se.conv_expand.bias)
#   %sigmoid_8 = Sigmoid(%conv2d_42)
#   %mul_754 = Mul(%silu_24, %sigmoid_8)
#   %getitem_75 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_754, %blocks.3.0.conv_pwl.weight, %mul_754_bias)
#   %getitem_78 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%getitem_75, %blocks.3.1.conv_pw.weight, %getitem_75_bias)
#   %val_338 = Sigmoid(%getitem_78)
#   %silu_26 = Mul(%getitem_78, %val_338)
#   %getitem_81 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 528, pads = [1, 1, 1, 1], strides = [1, 1]](%silu_26, %blocks.3.1.conv_dw.weight, %silu_26_bias)
#   %val_348 = Sigmoid(%getitem_81)
#   %silu_27 = Mul(%getitem_81, %val_348)
#   %mean_9 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_27, %val_72)
#   %conv2d_46 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_9, %blocks.3.1.se.conv_reduce.weight, %blocks.3.1.se.conv_reduce.bias)
#   %val_351 = Sigmoid(%conv2d_46)
#   %silu_28 = Mul(%conv2d_46, %val_351)
#   %conv2d_47 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_28, %blocks.3.1.se.conv_expand.weight, %blocks.3.1.se.conv_expand.bias)
#   %sigmoid_9 = Sigmoid(%conv2d_47)
#   %mul_834 = Mul(%silu_27, %sigmoid_9)
#   %getitem_84 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_834, %blocks.3.1.conv_pwl.weight, %mul_834_bias)
#   %add_942 = Add(%getitem_84, %getitem_75)
#   %getitem_87 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_942, %blocks.3.2.conv_pw.weight, %add_942_bias)
#   %val_370 = Sigmoid(%getitem_87)
#   %silu_29 = Mul(%getitem_87, %val_370)
#   %getitem_90 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 528, pads = [1, 1, 1, 1], strides = [1, 1]](%silu_29, %blocks.3.2.conv_dw.weight, %silu_29_bias)
#   %val_380 = Sigmoid(%getitem_90)
#   %silu_30 = Mul(%getitem_90, %val_380)
#   %mean_10 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_30, %val_72)
#   %conv2d_51 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_10, %blocks.3.2.se.conv_reduce.weight, %blocks.3.2.se.conv_reduce.bias)
#   %val_383 = Sigmoid(%conv2d_51)
#   %silu_31 = Mul(%conv2d_51, %val_383)
#   %conv2d_52 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_31, %blocks.3.2.se.conv_expand.weight, %blocks.3.2.se.conv_expand.bias)
#   %sigmoid_10 = Sigmoid(%conv2d_52)
#   %mul_916 = Mul(%silu_30, %sigmoid_10)
#   %getitem_93 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_916, %blocks.3.2.conv_pwl.weight, %mul_916_bias)
#   %add_1036 = Add(%getitem_93, %add_942)
#   %getitem_96 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_1036, %blocks.3.3.conv_pw.weight, %add_1036_bias)
#   %val_402 = Sigmoid(%getitem_96)
#   %silu_32 = Mul(%getitem_96, %val_402)
#   %getitem_99 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 528, pads = [1, 1, 1, 1], strides = [1, 1]](%silu_32, %blocks.3.3.conv_dw.weight, %silu_32_bias)
#   %val_412 = Sigmoid(%getitem_99)
#   %silu_33 = Mul(%getitem_99, %val_412)
#   %mean_11 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_33, %val_72)
#   %conv2d_56 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_11, %blocks.3.3.se.conv_reduce.weight, %blocks.3.3.se.conv_reduce.bias)
#   %val_415 = Sigmoid(%conv2d_56)
#   %silu_34 = Mul(%conv2d_56, %val_415)
#   %conv2d_57 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_34, %blocks.3.3.se.conv_expand.weight, %blocks.3.3.se.conv_expand.bias)
#   %sigmoid_11 = Sigmoid(%conv2d_57)
#   %mul_998 = Mul(%silu_33, %sigmoid_11)
#   %getitem_102 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_998, %blocks.3.3.conv_pwl.weight, %mul_998_bias)
#   %add_1130 = Add(%getitem_102, %add_1036)
#   %getitem_105 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_1130, %blocks.4.0.conv_pw.weight, %add_1130_bias)
#   %val_434 = Sigmoid(%getitem_105)
#   %silu_35 = Mul(%getitem_105, %val_434)
#   %getitem_108 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 528, pads = [2, 2, 2, 2], strides = [1, 1]](%silu_35, %blocks.4.0.conv_dw.weight, %silu_35_bias)
#   %val_444 = Sigmoid(%getitem_108)
#   %silu_36 = Mul(%getitem_108, %val_444)
#   %mean_12 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_36, %val_72)
#   %conv2d_61 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_12, %blocks.4.0.se.conv_reduce.weight, %blocks.4.0.se.conv_reduce.bias)
#   %val_447 = Sigmoid(%conv2d_61)
#   %silu_37 = Mul(%conv2d_61, %val_447)
#   %conv2d_62 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_37, %blocks.4.0.se.conv_expand.weight, %blocks.4.0.se.conv_expand.bias)
#   %sigmoid_12 = Sigmoid(%conv2d_62)
#   %mul_1080 = Mul(%silu_36, %sigmoid_12)
#   %getitem_111 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1080, %blocks.4.0.conv_pwl.weight, %mul_1080_bias)
#   %getitem_114 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%getitem_111, %blocks.4.1.conv_pw.weight, %getitem_111_bias)
#   %val_466 = Sigmoid(%getitem_114)
#   %silu_38 = Mul(%getitem_114, %val_466)
#   %getitem_117 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 720, pads = [2, 2, 2, 2], strides = [1, 1]](%silu_38, %blocks.4.1.conv_dw.weight, %silu_38_bias)
#   %val_476 = Sigmoid(%getitem_117)
#   %silu_39 = Mul(%getitem_117, %val_476)
#   %mean_13 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_39, %val_72)
#   %conv2d_66 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_13, %blocks.4.1.se.conv_reduce.weight, %blocks.4.1.se.conv_reduce.bias)
#   %val_479 = Sigmoid(%conv2d_66)
#   %silu_40 = Mul(%conv2d_66, %val_479)
#   %conv2d_67 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_40, %blocks.4.1.se.conv_expand.weight, %blocks.4.1.se.conv_expand.bias)
#   %sigmoid_13 = Sigmoid(%conv2d_67)
#   %mul_1160 = Mul(%silu_39, %sigmoid_13)
#   %getitem_120 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1160, %blocks.4.1.conv_pwl.weight, %mul_1160_bias)
#   %add_1312 = Add(%getitem_120, %getitem_111)
#   %getitem_123 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_1312, %blocks.4.2.conv_pw.weight, %add_1312_bias)
#   %val_498 = Sigmoid(%getitem_123)
#   %silu_41 = Mul(%getitem_123, %val_498)
#   %getitem_126 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 720, pads = [2, 2, 2, 2], strides = [1, 1]](%silu_41, %blocks.4.2.conv_dw.weight, %silu_41_bias)
#   %val_508 = Sigmoid(%getitem_126)
#   %silu_42 = Mul(%getitem_126, %val_508)
#   %mean_14 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_42, %val_72)
#   %conv2d_71 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_14, %blocks.4.2.se.conv_reduce.weight, %blocks.4.2.se.conv_reduce.bias)
#   %val_511 = Sigmoid(%conv2d_71)
#   %silu_43 = Mul(%conv2d_71, %val_511)
#   %conv2d_72 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_43, %blocks.4.2.se.conv_expand.weight, %blocks.4.2.se.conv_expand.bias)
#   %sigmoid_14 = Sigmoid(%conv2d_72)
#   %mul_1242 = Mul(%silu_42, %sigmoid_14)
#   %getitem_129 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1242, %blocks.4.2.conv_pwl.weight, %mul_1242_bias)
#   %add_1406 = Add(%getitem_129, %add_1312)
#   %getitem_132 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_1406, %blocks.4.3.conv_pw.weight, %add_1406_bias)
#   %val_530 = Sigmoid(%getitem_132)
#   %silu_44 = Mul(%getitem_132, %val_530)
#   %getitem_135 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 720, pads = [2, 2, 2, 2], strides = [1, 1]](%silu_44, %blocks.4.3.conv_dw.weight, %silu_44_bias)
#   %val_540 = Sigmoid(%getitem_135)
#   %silu_45 = Mul(%getitem_135, %val_540)
#   %mean_15 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_45, %val_72)
#   %conv2d_76 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_15, %blocks.4.3.se.conv_reduce.weight, %blocks.4.3.se.conv_reduce.bias)
#   %val_543 = Sigmoid(%conv2d_76)
#   %silu_46 = Mul(%conv2d_76, %val_543)
#   %conv2d_77 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_46, %blocks.4.3.se.conv_expand.weight, %blocks.4.3.se.conv_expand.bias)
#   %sigmoid_15 = Sigmoid(%conv2d_77)
#   %mul_1324 = Mul(%silu_45, %sigmoid_15)
#   %getitem_138 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1324, %blocks.4.3.conv_pwl.weight, %mul_1324_bias)
#   %add_1500 = Add(%getitem_138, %add_1406)
#   %getitem_141 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_1500, %blocks.5.0.conv_pw.weight, %add_1500_bias)
#   %val_562 = Sigmoid(%getitem_141)
#   %silu_47 = Mul(%getitem_141, %val_562)
#   %getitem_144 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 720, pads = [2, 2, 2, 2], strides = [2, 2]](%silu_47, %blocks.5.0.conv_dw.weight, %silu_47_bias)
#   %val_572 = Sigmoid(%getitem_144)
#   %silu_48 = Mul(%getitem_144, %val_572)
#   %mean_16 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_48, %val_72)
#   %conv2d_81 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_16, %blocks.5.0.se.conv_reduce.weight, %blocks.5.0.se.conv_reduce.bias)
#   %val_575 = Sigmoid(%conv2d_81)
#   %silu_49 = Mul(%conv2d_81, %val_575)
#   %conv2d_82 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_49, %blocks.5.0.se.conv_expand.weight, %blocks.5.0.se.conv_expand.bias)
#   %sigmoid_16 = Sigmoid(%conv2d_82)
#   %mul_1406 = Mul(%silu_48, %sigmoid_16)
#   %getitem_147 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1406, %blocks.5.0.conv_pwl.weight, %mul_1406_bias)
#   %getitem_150 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%getitem_147, %blocks.5.1.conv_pw.weight, %getitem_147_bias)
#   %val_594 = Sigmoid(%getitem_150)
#   %silu_50 = Mul(%getitem_150, %val_594)
#   %getitem_153 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1248, pads = [2, 2, 2, 2], strides = [1, 1]](%silu_50, %blocks.5.1.conv_dw.weight, %silu_50_bias)
#   %val_604 = Sigmoid(%getitem_153)
#   %silu_51 = Mul(%getitem_153, %val_604)
#   %mean_17 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_51, %val_72)
#   %conv2d_86 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_17, %blocks.5.1.se.conv_reduce.weight, %blocks.5.1.se.conv_reduce.bias)
#   %val_607 = Sigmoid(%conv2d_86)
#   %silu_52 = Mul(%conv2d_86, %val_607)
#   %conv2d_87 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_52, %blocks.5.1.se.conv_expand.weight, %blocks.5.1.se.conv_expand.bias)
#   %sigmoid_17 = Sigmoid(%conv2d_87)
#   %mul_1486 = Mul(%silu_51, %sigmoid_17)
#   %getitem_156 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1486, %blocks.5.1.conv_pwl.weight, %mul_1486_bias)
#   %add_1682 = Add(%getitem_156, %getitem_147)
#   %getitem_159 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_1682, %blocks.5.2.conv_pw.weight, %add_1682_bias)
#   %val_626 = Sigmoid(%getitem_159)
#   %silu_53 = Mul(%getitem_159, %val_626)
#   %getitem_162 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1248, pads = [2, 2, 2, 2], strides = [1, 1]](%silu_53, %blocks.5.2.conv_dw.weight, %silu_53_bias)
#   %val_636 = Sigmoid(%getitem_162)
#   %silu_54 = Mul(%getitem_162, %val_636)
#   %mean_18 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_54, %val_72)
#   %conv2d_91 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_18, %blocks.5.2.se.conv_reduce.weight, %blocks.5.2.se.conv_reduce.bias)
#   %val_639 = Sigmoid(%conv2d_91)
#   %silu_55 = Mul(%conv2d_91, %val_639)
#   %conv2d_92 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_55, %blocks.5.2.se.conv_expand.weight, %blocks.5.2.se.conv_expand.bias)
#   %sigmoid_18 = Sigmoid(%conv2d_92)
#   %mul_1568 = Mul(%silu_54, %sigmoid_18)
#   %getitem_165 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1568, %blocks.5.2.conv_pwl.weight, %mul_1568_bias)
#   %add_1776 = Add(%getitem_165, %add_1682)
#   %getitem_168 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_1776, %blocks.5.3.conv_pw.weight, %add_1776_bias)
#   %val_658 = Sigmoid(%getitem_168)
#   %silu_56 = Mul(%getitem_168, %val_658)
#   %getitem_171 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1248, pads = [2, 2, 2, 2], strides = [1, 1]](%silu_56, %blocks.5.3.conv_dw.weight, %silu_56_bias)
#   %val_668 = Sigmoid(%getitem_171)
#   %silu_57 = Mul(%getitem_171, %val_668)
#   %mean_19 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_57, %val_72)
#   %conv2d_96 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_19, %blocks.5.3.se.conv_reduce.weight, %blocks.5.3.se.conv_reduce.bias)
#   %val_671 = Sigmoid(%conv2d_96)
#   %silu_58 = Mul(%conv2d_96, %val_671)
#   %conv2d_97 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_58, %blocks.5.3.se.conv_expand.weight, %blocks.5.3.se.conv_expand.bias)
#   %sigmoid_19 = Sigmoid(%conv2d_97)
#   %mul_1650 = Mul(%silu_57, %sigmoid_19)
#   %getitem_174 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1650, %blocks.5.3.conv_pwl.weight, %mul_1650_bias)
#   %add_1870 = Add(%getitem_174, %add_1776)
#   %getitem_177 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_1870, %blocks.5.4.conv_pw.weight, %add_1870_bias)
#   %val_690 = Sigmoid(%getitem_177)
#   %silu_59 = Mul(%getitem_177, %val_690)
#   %getitem_180 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1248, pads = [2, 2, 2, 2], strides = [1, 1]](%silu_59, %blocks.5.4.conv_dw.weight, %silu_59_bias)
#   %val_700 = Sigmoid(%getitem_180)
#   %silu_60 = Mul(%getitem_180, %val_700)
#   %mean_20 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_60, %val_72)
#   %conv2d_101 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_20, %blocks.5.4.se.conv_reduce.weight, %blocks.5.4.se.conv_reduce.bias)
#   %val_703 = Sigmoid(%conv2d_101)
#   %silu_61 = Mul(%conv2d_101, %val_703)
#   %conv2d_102 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_61, %blocks.5.4.se.conv_expand.weight, %blocks.5.4.se.conv_expand.bias)
#   %sigmoid_20 = Sigmoid(%conv2d_102)
#   %mul_1732 = Mul(%silu_60, %sigmoid_20)
#   %getitem_183 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1732, %blocks.5.4.conv_pwl.weight, %mul_1732_bias)
#   %add_1964 = Add(%getitem_183, %add_1870)
#   %getitem_186 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_1964, %blocks.6.0.conv_pw.weight, %add_1964_bias)
#   %val_722 = Sigmoid(%getitem_186)
#   %silu_62 = Mul(%getitem_186, %val_722)
#   %getitem_189 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1248, pads = [1, 1, 1, 1], strides = [1, 1]](%silu_62, %blocks.6.0.conv_dw.weight, %silu_62_bias)
#   %val_732 = Sigmoid(%getitem_189)
#   %silu_63 = Mul(%getitem_189, %val_732)
#   %mean_21 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_63, %val_72)
#   %conv2d_106 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_21, %blocks.6.0.se.conv_reduce.weight, %blocks.6.0.se.conv_reduce.bias)
#   %val_735 = Sigmoid(%conv2d_106)
#   %silu_64 = Mul(%conv2d_106, %val_735)
#   %conv2d_107 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_64, %blocks.6.0.se.conv_expand.weight, %blocks.6.0.se.conv_expand.bias)
#   %sigmoid_21 = Sigmoid(%conv2d_107)
#   %mul_1814 = Mul(%silu_63, %sigmoid_21)
#   %getitem_192 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1814, %blocks.6.0.conv_pwl.weight, %mul_1814_bias)
#   %getitem_195 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%getitem_192, %blocks.6.1.conv_pw.weight, %getitem_192_bias)
#   %val_754 = Sigmoid(%getitem_195)
#   %silu_65 = Mul(%getitem_195, %val_754)
#   %getitem_198 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 2112, pads = [1, 1, 1, 1], strides = [1, 1]](%silu_65, %blocks.6.1.conv_dw.weight, %silu_65_bias)
#   %val_764 = Sigmoid(%getitem_198)
#   %silu_66 = Mul(%getitem_198, %val_764)
#   %mean_22 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_66, %val_72)
#   %conv2d_111 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mean_22, %blocks.6.1.se.conv_reduce.weight, %blocks.6.1.se.conv_reduce.bias)
#   %val_767 = Sigmoid(%conv2d_111)
#   %silu_67 = Mul(%conv2d_111, %val_767)
#   %conv2d_112 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%silu_67, %blocks.6.1.se.conv_expand.weight, %blocks.6.1.se.conv_expand.bias)
#   %sigmoid_22 = Sigmoid(%conv2d_112)
#   %mul_1894 = Mul(%silu_66, %sigmoid_22)
#   %getitem_201 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%mul_1894, %blocks.6.1.conv_pwl.weight, %mul_1894_bias)
#   %add_2146 = Add(%getitem_201, %getitem_192)
#   %getitem_204 = Conv[auto_pad = 'NOTSET', dilations = [1, 1], group = 1, pads = [0, 0, 0, 0], strides = [1, 1]](%add_2146, %conv_head.weight, %add_2146_bias)
#   %val_786 = Sigmoid(%getitem_204)
#   %silu_68 = Mul(%getitem_204, %val_786)
#   %mean_23 = ReduceMean[keepdims = 1, noop_with_empty_axes = 0](%silu_68, %val_789)
#   %val_793 = Concat[axis = 0](%val_0, %val_792)
#   %view = Reshape[allowzero = 1](%mean_23, %val_793)
#   %getitem_207 = Gemm[alpha = 1, beta = 1, transA = 0, transB = 1](%view, %classifier.0.weight, %classifier.0.bias)
#   %mish = Mish(%getitem_207)
#   %getitem_210 = Gemm[alpha = 1, beta = 1, transA = 0, transB = 1](%mish, %classifier.4.weight, %classifier.4.bias)
#   %mish_1 = Mish(%getitem_210)
#   %linear = Gemm[alpha = 1, beta = 1, transA = 0, transB = 1](%mish_1, %classifier.8.weight, %classifier.8.bias)
#   return %linear
# }
# dim {
#   dim_param: "batch_size"
# }
# dim {
#   dim_value: 6
# }
# dim {
#   dim_value: 310
# }
# dim {
#   dim_value: 310
# }

# %%
import onnx
from onnx import numpy_helper
import onnxruntime as ort
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import average_precision_score, precision_recall_curve

onnx_path_in = "model_v5.onnx"
onnx_path_out = "model_v5_patched.onnx"

model = onnx.load(onnx_path_in)

patched = False

for node in model.graph.node:
    if node.op_type == "Reshape":
        shape_name = node.input[1]   # second input is the shape tensor

        for i, init in enumerate(model.graph.initializer):
            if init.name == shape_name:
                arr = numpy_helper.to_array(init)

                print(f"Found Reshape shape initializer: {shape_name}")
                print("Original shape:", arr)

                if len(arr) == 2 and arr[0] == 1:
                    arr[0] = -1   # ✅ make batch dimension dynamic
                    new_init = numpy_helper.from_array(arr.astype(np.int64), name=shape_name)
                    model.graph.initializer[i].CopyFrom(new_init)

                    print("✅ Patched shape to:", arr)
                    patched = True
                break

if not patched:
    print("⚠️ No static [1, N] reshape found. Model may already be dynamic.")

onnx.save(model, onnx_path_out)
print(f"\n✅ Saved patched ONNX model as: {onnx_path_out}")


# ---------- 2) CREATE ONNX RUNTIME SESSION ----------
ort_session = ort.InferenceSession(
    onnx_path_out,
    providers=["CUDAExecutionProvider", "CPUExecutionProvider"]
)

input_name = ort_session.get_inputs()[0].name
output_name = ort_session.get_outputs()[0].name

print("ONNX Input Name :", input_name)
print("ONNX Output Name:", output_name)

# ---------- 3) RUN INFERENCE ON TEST LOADER (BATCHED, e.g. batch_size=10) ----------
all_probs = []
all_labels = []

for images, labels in test_loader:
    images_np = images.cpu().numpy()   # (B, 6, 310, 310)
    labels_np = labels.cpu().numpy()

    outputs = ort_session.run(
        [output_name],
        {input_name: images_np}
    )[0]  # (B, 2)

    # Softmax over class dim
    exp_logits = np.exp(outputs)
    probs = exp_logits / exp_logits.sum(axis=1, keepdims=True)
    probs_pos = probs[:, 1]  # positive class

    all_probs.extend(probs_pos)
    all_labels.extend(labels_np)

all_probs = np.array(all_probs)
all_labels = np.array(all_labels)

# ---------- 4) METRICS & PLOT ----------
auc_pr = average_precision_score(all_labels, all_probs)
print(f"\n✅ AUC-PR (ONNX, batched): {auc_pr:.4f}")

precision, recall, thresholds = precision_recall_curve(all_labels, all_probs)

plt.figure()
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision-Recall Curve (AUC = {auc_pr:.4f})")
plt.grid(True)
plt.show()

print("\nLabels distribution:", np.bincount(all_labels.astype(int)))
print("Probabilities min/max:", all_probs.min(), all_probs.max())
print("Total samples:", len(all_probs))
# Out:
# ⚠️ No static [1, N] reshape found. Model may already be dynamic.
#
# ✅ Saved patched ONNX model as: model_v5_patched.onnx
# ONNX Input Name : x
# ONNX Output Name: linear
#
# ✅ AUC-PR (ONNX, batched): 0.6568
# Labels distribution: [78 47]
# Probabilities min/max: 0.16796266 0.9163737
# Total samples: 125
